# %%
import twitter
import os
from config import *
import time

# initialize api instance
twitter_api = twitter.Api(consumer_key=consumer_key,
                         consumer_secret=consumer_secret,
                         access_token_key=access_token_key,
                         access_token_secret=access_token_secret,
                        cache=None,tweet_mode='compat')

#print(consumer_key,consumer_secret,access_token_key,access_token_secret)

# test authentication
print(twitter_api.VerifyCredentials())
# print(twitter_api.GetStatus(126402758403305000))
# Out:
# {"created_at": "Wed Jul 20 02:34:27 +0000 2016", "description": "I am Al and I am passionate about technology.", "followers_count": 5, "friends_count": 52, "id": 755591669194514432, "id_str": "755591669194514432", "location": "Tustin, CA", "name": "Al", "profile_background_color": "000000", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "profile_banner_url": "https://pbs.twimg.com/profile_banners/755591669194514432/1469041661", "profile_image_url": "http://pbs.twimg.com/profile_images/755843006062694401/2JikSpJq_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/755843006062694401/2JikSpJq_normal.jpg", "profile_link_color": "1B95E0", "profile_sidebar_border_color": "000000", "profile_sidebar_fill_color": "000000", "profile_text_color": "000000", "screen_name": "alknowstech", "status": {"created_at": "Mon Jul 31 21:38:46 +0000 2017", "favorite_count": 1, "id": 892137484921978880, "id_str": "892137484921978880", "in_reply_to_screen_name": "TechYESCity", "in_reply_to_status_id": 891577872384638976, "in_reply_to_user_id": 1021097054, "lang": "en", "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>", "text": "@TechYESCity thanks for the reply.. is it stable enough to OC to 4ghz on 1700? i plan to use AIO cpu cooler"}, "statuses_count": 5}

# %%
def buildTestSet(search_keyword):
    try:
        tweets_fetched = twitter_api.GetSearch(search_keyword, count = 100,
                                               lang='en',result_type='recent')
        
        print("Fetched " + str(len(tweets_fetched)) + " tweets for the term " + search_keyword)
        
        return [{"text":status.text, "label":None, "user":status.user.screen_name, "time":status.created_at} for status in tweets_fetched]
    except:
        print("Unfortunately, something went wrong..")
        return None

# %%
# test search function
search_term = input("Enter a search keyword:")
testDataSet = buildTestSet(search_term)

print(testDataSet[0:10])
# Out:
# Enter a search keyword:kfc
# Fetched 100 tweets for the term kfc
# [{'text': 'I’m sorry @kfc but this ain’t it 💀 https://t.co/EzUWyMGwUF', 'label': None, 'user': 'AESTHET72408809', 'time': 'Tue Feb 18 03:15:31 +0000 2020'}, {'text': "RT @WPatriot2: Watching History channel waiting for the George Washington special to come on... \nThey are talking bout McDonald's and KFC..…", 'label': None, 'user': 'TombStoneWyatt', 'time': 'Tue Feb 18 03:15:23 +0000 2020'}, {'text': 'I see here lol that was throwing a came out', 'label': None, 'user': 'KFC_Grace', 'time': 'Tue Feb 18 03:15:00 +0000 2020'}, {'text': 'RT @l0rdadrean: #WWEFOREVER WHY IS @EdgeRatedR IN @KFC😂😂😂😂😂😂 #explore #viral #wwe #wweraw https://t.co/nigx0cE53q', 'label': None, 'user': 'chris052', 'time': 'Tue Feb 18 03:14:58 +0000 2020'}, {'text': '@MysterySolvent Running out of KFC', 'label': None, 'user': 'markglenndavie4', 'time': 'Tue Feb 18 03:14:55 +0000 2020'}, {'text': 'KFC SuperCoach Podcast 🎙️\nIs an emerging Swan the reason not to pick Lloyd? \nTom Mitchell too cheap to pass up? \nJo… https://t.co/NT0KaTZBZb', 'label': None, 'user': 'Supercoach', 'time': 'Tue Feb 18 03:14:51 +0000 2020'}, {'text': 'RT @l0rdadrean: #WWEFOREVER WHY IS @EdgeRatedR IN @KFC😂😂😂😂😂😂 #explore #viral #wwe #wweraw https://t.co/nigx0cE53q', 'label': None, 'user': 'yk_shake', 'time': 'Tue Feb 18 03:14:50 +0000 2020'}, {'text': 'RT @yungry2015: when you on your way to get a salad, but smell KFC:', 'label': None, 'user': 'H4VK_TNOTTZ', 'time': 'Tue Feb 18 03:14:09 +0000 2020'}, {'text': 'RT @CHARLENEMAXIMUM: white folks fr be like "check out those juicy cheeks she mad thicc bro 💦💦💦" staring at a half eaten chicken wing from…', 'label': None, 'user': 'SeriousTyberius', 'time': 'Tue Feb 18 03:14:06 +0000 2020'}, {'text': 'Love Fried Chicken? This KFC Crocs (Fried Chicken Shoe) Might Just Be For You - https://t.co/P7vPAKaPe4', 'label': None, 'user': 'TrendingAtoZ', 'time': 'Tue Feb 18 03:13:54 +0000 2020'}]

# %% [markdown]
# # Use to test twitter api

# %%
tweets_fetched = twitter_api.GetSearch('disney', count = 100, lang='en')
[{"text":status.text, "label":None, "user":status.user.screen_name} for status in tweets_fetched]

# %% [markdown]
# # Start preprocessing of training data

# %%
import pandas as pd
import numpy as np

traindata140 = os.path.join(".","trainingandtestdata_sentiment140","training.csv")
testdata140 = os.path.join(".","trainingandtestdata_sentiment140","test.csv")

# %%
#read the csv file command
train_df = pd.read_csv(traindata140, header=None, usecols=[0,5], names=['polarity of the tweet','text'], 
                       encoding="ISO-8859-1")
train_df.head()
# (0 = negative, 2 = neutral, 4 = positive)
# Out:
#    polarity of the tweet                                               text
# 0                      0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1                      0  is upset that he can't update his Facebook by ...
# 2                      0  @Kenichan I dived many times for the ball. Man...
# 3                      0    my whole body feels itchy and like its on fire
# 4                      0  @nationwideclass no, it's not behaving at all....

# %% [markdown]
# # Test Df Validation

# %%
test_df = pd.read_csv(testdata140, header=None, usecols=[0,5],
                      names=['polarity of the tweet', 'text'],encoding="ISO-8859-1")
conditions_test = [
    (test_df['polarity of the tweet'] == 0),
    (test_df['polarity of the tweet'] == 2),
    (test_df['polarity of the tweet'] == 4)]
choices_test = ['negative', 'neutral', 'positive']
test_df['label'] = np.select(conditions_test, choices_test)
test_df.head()
# Out:
#    polarity of the tweet                                               text  \
# 0                      4  @stellargirl I loooooooovvvvvveee my Kindle2. ...
# 1                      4  Reading my kindle2...  Love it... Lee childs i...
# 2                      4  Ok, first assesment of the #kindle2 ...it fuck...
# 3                      4  @kenburbary You'll love your Kindle2. I've had...
# 4                      4  @mikefish  Fair enough. But i have the Kindle2...
#
#       label
# 0  positive
# 1  positive
# 2  positive
# 3  positive
# 4  positive

# %%
test_ls = test_df.to_dict('records')

# %%
train_df_negative = train_df.loc[train_df['polarity of the tweet']==0]

# %%
train_df_positive = train_df.loc[train_df['polarity of the tweet']==4]

# %%
frames = [train_df_negative.iloc[0:12500,:],train_df_positive.iloc[0:12500,:]]

# %%
result = pd.concat(frames)

# %%
conditions = [
    (result['polarity of the tweet'] == 0),
    (result['polarity of the tweet'] == 2),
    (result['polarity of the tweet'] == 4)]
choices = ['negative', 'neutral', 'positive']
result['label'] = np.select(conditions, choices)
result.head()
# Out:
#    polarity of the tweet                                               text  \
# 0                      0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1                      0  is upset that he can't update his Facebook by ...
# 2                      0  @Kenichan I dived many times for the ball. Man...
# 3                      0    my whole body feels itchy and like its on fire
# 4                      0  @nationwideclass no, it's not behaving at all....
#
#       label
# 0  negative
# 1  negative
# 2  negative
# 3  negative
# 4  negative

# %%
train_ls = result.to_dict('records')

# %%
import re
from nltk.tokenize import word_tokenize
from string import punctuation 
from nltk.corpus import stopwords 
import nltk
# nltk.download('punkt')

class PreProcessTweets:
    def __init__(self):
        self._stopwords = set(stopwords.words('english') + list(punctuation) + ['AT_USER','URL'])
        
    def processTweets(self, list_of_tweets):
        processedTweets=[]
        for tweet in list_of_tweets:
            processedTweets.append((self._processTweet(tweet["text"]),tweet["label"]))
        return processedTweets
    
    def _processTweet(self, tweet):
        tweet = tweet.lower() # convert text to lower-case
        tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+))', 'URL', tweet) # remove URLs
        tweet = re.sub('@[^\s]+', 'AT_USER', tweet) # remove usernames
        tweet = re.sub(r'#([^\s]+)', r'\1', tweet) # remove the # in #hashtag
        tweet = word_tokenize(tweet) # remove repeated characters (helloooooooo into hello)
        return [word for word in tweet if word not in self._stopwords]
    
tweetProcessor = PreProcessTweets()

# %%
# Process Training Set
preprocessedTrainingSet = tweetProcessor.processTweets(train_ls)

# %%
# Process Test Set
preprocessedTestSet = tweetProcessor.processTweets(testDataSet)

# %%
import nltk 

def buildVocabulary(preprocessedTrainingData):
    all_words = []
    
    for (words, sentiment) in preprocessedTrainingData:
        all_words.extend(words)

    wordlist = nltk.FreqDist(all_words)
    word_features = wordlist.keys()
    
    return word_features

# %%
def extract_features(tweet):
    tweet_words = set(tweet)
    features = {}
    for word in word_features:
        features['contains(%s)' % word] = (word in tweet_words)
    return features

# %%
word_features = buildVocabulary(preprocessedTrainingSet)
trainingFeatures = nltk.classify.apply_features(extract_features, preprocessedTrainingSet)

# %%
from nltk.classify import SklearnClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.svm import SVC

SKLearnClassifier = SklearnClassifier(BernoulliNB()).train(trainingFeatures)
# SKLearnClassifier = SklearnClassifier(SVC(), sparse=False).train(trainingFeatures)

# %%
SKLearnResultLabels = [SKLearnClassifier.classify(extract_features(tweet[0])) for tweet in preprocessedTestSet]

# %%
# Save Pickle
import pickle
save_classifier = open("sklearn_nbayes_train_25k.pickle","wb")
pickle.dump(SKLearnClassifier, save_classifier)
save_classifier.close()

# %%
# Load Pickle
import pickle
classifier_f = open("sklearn_nbayes_train_25k.pickle", "rb")
classifier = pickle.load(classifier_f)
classifier_f.close()

# %%
# when using Pickle
SKLearnResultLabels = [classifier.classify(extract_features(tweet[0])) for tweet in preprocessedTestSet]

# %%
# had to add space before tweet text to eliminate csv issue with tweets that begins with @
# list comprehension
test_list_text = [' '+test['text'] for test in testDataSet]
# convert twitter time output to real time output
test_list_time = [time.strftime('%Y-%m-%d %H:%M:%S', time.strptime(test['time'],'%a %b %d %H:%M:%S +0000 %Y')) 
for test in testDataSet]

# %%
output_list = pd.DataFrame(
    {'Tweet': test_list_text,
     'Time': test_list_time,
     'Result': SKLearnResultLabels,
     'Search_Term': 'kfc'
    })

# %%
output_list
# Out:
#                                                 Tweet                 Time  \
# 0    I’m sorry @kfc but this ain’t it 💀 https://t....  2020-02-18 03:15:31
# 1    RT @WPatriot2: Watching History channel waiti...  2020-02-18 03:15:23
# 2         I see here lol that was throwing a came out  2020-02-18 03:15:00
# 3    RT @l0rdadrean: #WWEFOREVER WHY IS @EdgeRated...  2020-02-18 03:14:58
# 4                  @MysterySolvent Running out of KFC  2020-02-18 03:14:55
# 5    KFC SuperCoach Podcast 🎙️\nIs an emerging Swa...  2020-02-18 03:14:51
# 6    RT @l0rdadrean: #WWEFOREVER WHY IS @EdgeRated...  2020-02-18 03:14:50
# 7    RT @yungry2015: when you on your way to get a...  2020-02-18 03:14:09
# 8    RT @CHARLENEMAXIMUM: white folks fr be like "...  2020-02-18 03:14:06
# 9    Love Fried Chicken? This KFC Crocs (Fried Chi...  2020-02-18 03:13:54
# 10   @saleintothe90s Was it Gloria Pitzer? I met h...  2020-02-18 03:13:42
# 11   RT @CatalystNB: I just went to order a big cr...  2020-02-18 03:13:35
# 12   RT @l0rdadrean: #WWEFOREVER WHY IS @EdgeRated...  2020-02-18 03:13:35
# 13   @windsoriteDOTca Make no wonder KFC shutting ...  2020-02-18 03:13:22
# 14   RT @unSANItary_: Anyway, I'm grateful for it....  2020-02-18 03:13:07
# 15   RT @iii_am_mee: And never, I mean never, forg...  2020-02-18 03:13:05
# 16   RT @l0rdadrean: #WWEFOREVER WHY IS @EdgeRated...  2020-02-18 03:12:54
# 17   China ain’t got any chickens 🐓, trust me $BYN...  2020-02-18 03:12:46
# 18   @parpyfn Wtf\nI rhought they were like kfc or...  2020-02-18 03:12:18
# 19   RT @ChillGates69: Every somellier knows that ...  2020-02-18 03:12:18
# 20   Popeyes has a better biscuit than KFC and tha...  2020-02-18 03:12:17
# 21   out of of the places we went to get some food...  2020-02-18 03:11:29
# 22   @Yousaphzai @mishamasood29 But but kfc is lov...  2020-02-18 03:11:15
# 23   RT @iii_am_mee: And never, I mean never, forg...  2020-02-18 03:11:10
# 24   RT @iii_am_mee: And never, I mean never, forg...  2020-02-18 03:10:48
# 25   RT @l0rdadrean: #WWEFOREVER WHY IS @EdgeRated...  2020-02-18 03:10:47
# 26   @kfc @Crocs @destineeijeoma oh she gettin DEA...  2020-02-18 03:10:17
# 27   RT @CHARLENEMAXIMUM: white folks fr be like "...  2020-02-18 03:09:42
# 28   @dsoltesz @kfc @WaffleHouse lol..believe me, ...  2020-02-18 03:09:35
# 29   RT @dj3rdeye1: Any Black person that prefers ...  2020-02-18 03:09:15
# ..                                                ...                  ...
# 70   Did April fools day come early?\n https://t.c...  2020-02-18 03:00:30
# 71                oh my heart goes on I don't need to  2020-02-18 03:00:00
# 72   RT @ChillGates69: Every somellier knows that ...  2020-02-18 02:59:57
# 73   Limo had cheeseburgers and KFC chicken on one...  2020-02-18 02:59:31
# 74   RT @RetryGuy: Cute how KFC thinks one moist t...  2020-02-18 02:59:22
# 75   RT @CatalystNB: I just went to order a big cr...  2020-02-18 02:59:20
# 76   RT @CatalystNB: I just went to order a big cr...  2020-02-18 02:58:42
# 77   RT @l0rdadrean: #WWEFOREVER WHY IS @EdgeRated...  2020-02-18 02:58:42
# 78   RT @CatalystNB: I just went to order a big cr...  2020-02-18 02:58:33
# 79   RT @l0rdadrean: #WWEFOREVER WHY IS @EdgeRated...  2020-02-18 02:58:23
# 80   And never, I mean never, forget Trini KFC bei...  2020-02-18 02:58:07
# 81    @ikesCG A MAN IS IN THE A&amp;W KFC COMBINATION  2020-02-18 02:58:01
# 82   RT @Off_Blck: Croc lovers, wtf is this??? KFC...  2020-02-18 02:58:00
# 83   RT @l0rdadrean: #WWEFOREVER WHY IS @EdgeRated...  2020-02-18 02:57:48
# 84   RT @CatalystNB: I just went to order a big cr...  2020-02-18 02:57:33
# 85   RT @abike1999: I used to like KFC better, but...  2020-02-18 02:57:30
# 86           Soo Crocs x KFC are making a shoe...KFC?  2020-02-18 02:57:28
# 87   white folks fr be like "check out those juicy...  2020-02-18 02:57:23
# 88   RT @l0rdadrean: #WWEFOREVER WHY IS @EdgeRated...  2020-02-18 02:57:14
# 89   RT @CatalystNB: I just went to order a big cr...  2020-02-18 02:57:00
# 90   RT @CatalystNB: I just went to order a big cr...  2020-02-18 02:56:42
# 91   RT @CatalystNB: I just went to order a big cr...  2020-02-18 02:56:35
# 92   RT @IIIM_G_W_VIII: 👀\n👅 Retweet &amp; like if...  2020-02-18 02:56:19
# 93                           anyone wanna eat kfc hmu  2020-02-18 02:56:17
# 94   Things I'm ready to eat in Trinidad: Doubles,...  2020-02-18 02:55:57
# 95   RT @Paul_KeatingPM: They “want to be there” 1...  2020-02-18 02:55:51
# 96            @thejoekelley808 @EdgeRatedR @kfc FACTS  2020-02-18 02:55:48
# 97          timeline pls stop https://t.co/dOcidFeCk8  2020-02-18 02:55:45
# 98           @KFCBarstool Kfc. What?????? The fucj???  2020-02-18 02:55:31
# 99   @l0rdadrean @EdgeRatedR @kfc That spear was OD😂😂  2020-02-18 02:55:22
#
#       Result Search_Term
# 0   negative         kfc
# 1   negative         kfc
# 2   positive         kfc
# 3   positive         kfc
# 4   negative         kfc
# 5   positive         kfc
# 6   positive         kfc
# 7   negative         kfc
# 8   negative         kfc
# 9   positive         kfc
# 10  positive         kfc
# 11  negative         kfc
# 12  positive         kfc
# 13  negative         kfc
# 14  negative         kfc
# 15  negative         kfc
# 16  positive         kfc
# 17  negative         kfc
# 18  negative         kfc
# 19  negative         kfc
# 20  negative         kfc
# 21  negative         kfc
# 22  negative         kfc
# 23  negative         kfc
# 24  negative         kfc
# 25  positive         kfc
# 26  negative         kfc
# 27  negative         kfc
# 28  positive         kfc
# 29  negative         kfc
# ..       ...         ...
# 70  negative         kfc
# 71  negative         kfc
# 72  negative         kfc
# 73  negative         kfc
# 74  negative         kfc
# 75  negative         kfc
# 76  negative         kfc
# 77  positive         kfc
# 78  negative         kfc
# 79  positive         kfc
# 80  negative         kfc
# 81  negative         kfc
# 82  negative         kfc
# 83  positive         kfc
# 84  negative         kfc
# 85  negative         kfc
# 86  negative         kfc
# 87  negative         kfc
# 88  positive         kfc
# 89  negative         kfc
# 90  negative         kfc
# 91  negative         kfc
# 92  positive         kfc
# 93  negative         kfc
# 94  positive         kfc
# 95  negative         kfc
# 96  positive         kfc
# 97  negative         kfc
# 98  negative         kfc
# 99  positive         kfc
#
# [100 rows x 4 columns]

# %%
output_list.to_csv('./2020-02-17_kfc.csv',header=True,
                              index=False,encoding="utf-8")
