# %%
import twitter
import os
from config import *
import time

# initialize api instance
twitter_api = twitter.Api(consumer_key=consumer_key,
                         consumer_secret=consumer_secret,
                         access_token_key=access_token_key,
                         access_token_secret=access_token_secret,
                        cache=None,tweet_mode='compat')

#print(consumer_key,consumer_secret,access_token_key,access_token_secret)

# test authentication
print(twitter_api.VerifyCredentials())
# print(twitter_api.GetStatus(126402758403305000))
# Out:
# {"created_at": "Wed Jul 20 02:34:27 +0000 2016", "description": "I am Al and I am passionate about technology.", "followers_count": 5, "friends_count": 52, "id": 755591669194514432, "id_str": "755591669194514432", "location": "Tustin, CA", "name": "Al", "profile_background_color": "000000", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "profile_banner_url": "https://pbs.twimg.com/profile_banners/755591669194514432/1469041661", "profile_image_url": "http://pbs.twimg.com/profile_images/755843006062694401/2JikSpJq_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/755843006062694401/2JikSpJq_normal.jpg", "profile_link_color": "1B95E0", "profile_sidebar_border_color": "000000", "profile_sidebar_fill_color": "000000", "profile_text_color": "000000", "screen_name": "alknowstech", "status": {"created_at": "Mon Jul 31 21:38:46 +0000 2017", "favorite_count": 1, "id": 892137484921978880, "id_str": "892137484921978880", "in_reply_to_screen_name": "TechYESCity", "in_reply_to_status_id": 891577872384638976, "in_reply_to_user_id": 1021097054, "lang": "en", "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>", "text": "@TechYESCity thanks for the reply.. is it stable enough to OC to 4ghz on 1700? i plan to use AIO cpu cooler"}, "statuses_count": 5}

# %%
def buildTestSet(search_keyword):
    try:
        tweets_fetched = twitter_api.GetSearch(search_keyword, count = 100,
                                               lang='en',result_type='recent')
        
        print("Fetched " + str(len(tweets_fetched)) + " tweets for the term " + search_keyword)
        
        return [{"text":status.text, "label":None, "user":status.user.screen_name, "time":status.created_at} for status in tweets_fetched]
    except:
        print("Unfortunately, something went wrong..")
        return None

# %%
# test search function
search_term = input("Enter a search keyword:")
testDataSet = buildTestSet(search_term)

print(testDataSet[0:10])
# Out:
# Enter a search keyword:mcdonalds
# Fetched 100 tweets for the term mcdonalds
# [{'text': "RT @wchs8fox11: Good news for fans of McDonald's soft serve ice cream! \nCertain locations are using a device that will make their ice cream…", 'label': None, 'user': 'Jjesleigh', 'time': 'Fri Feb 14 04:01:38 +0000 2020'}, {'text': 'RT @icedoutomnitrix: teejayx6 b saying shit like\n\nshot a n*gga at mcdonalds over a DOUBLE QUARTER POUNDER\n\nthis n*gga say he the plug he ai…', 'label': None, 'user': 'theonlyvango', 'time': 'Fri Feb 14 04:01:33 +0000 2020'}, {'text': 'RT @ProPlan: Fueled by the advanced nutrition of Purina Pro Plan (with some occasional help from @McDonalds).', 'label': None, 'user': 'DianaMNorth1', 'time': 'Fri Feb 14 04:01:29 +0000 2020'}, {'text': 'RT @PinkLights: Vacation @vinceoftexas just wants Sprite from McDonalds LMFAO', 'label': None, 'user': 'vinceoftexas', 'time': 'Fri Feb 14 04:01:16 +0000 2020'}, {'text': 'RT @theycall_me_d: How does @McDonalds only give me the bun and the patty for my burger ... wtf lol https://t.co/PZ972f0hlh', 'label': None, 'user': 'WOLVEROmusic', 'time': 'Fri Feb 14 04:01:15 +0000 2020'}, {'text': '@ringslut but mcdonalds .. 😔', 'label': None, 'user': 'torzier', 'time': 'Fri Feb 14 04:01:07 +0000 2020'}, {'text': 'RT @ProPlan: Fueled by the advanced nutrition of Purina Pro Plan (with some occasional help from @McDonalds).', 'label': None, 'user': 'tisonlyme143', 'time': 'Fri Feb 14 04:01:03 +0000 2020'}, {'text': "McDonald's Print Advert By TBWA: Lovin' is Lovin' | Ads of the World™ https://t.co/FLrg8VYy5W #McDonalds", 'label': None, 'user': 'itshotshit', 'time': 'Fri Feb 14 04:00:53 +0000 2020'}, {'text': 'So many proclaim not to eat McDonalds but they still are boomin making billions a year, so somebody CAPPIN', 'label': None, 'user': 'GameChangerNick', 'time': 'Fri Feb 14 04:00:46 +0000 2020'}, {'text': '@Rueben_Rodd Neither can we, Rueben! 😋', 'label': None, 'user': 'McDonalds', 'time': 'Fri Feb 14 04:00:42 +0000 2020'}]

# %% [markdown]
# # Use to test twitter api

# %%
tweets_fetched = twitter_api.GetSearch('disney', count = 100, lang='en')
[{"text":status.text, "label":None, "user":status.user.screen_name} for status in tweets_fetched]

# %% [markdown]
# # Start preprocessing of training data

# %%
import pandas as pd
import numpy as np

traindata140 = os.path.join(".","trainingandtestdata_sentiment140","training.csv")
testdata140 = os.path.join(".","trainingandtestdata_sentiment140","test.csv")

# %%
#read the csv file command
train_df = pd.read_csv(traindata140, header=None, usecols=[0,5], names=['polarity of the tweet','text'], 
                       encoding="ISO-8859-1")
train_df.head()
# (0 = negative, 2 = neutral, 4 = positive)
# Out:
#    polarity of the tweet                                               text
# 0                      0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1                      0  is upset that he can't update his Facebook by ...
# 2                      0  @Kenichan I dived many times for the ball. Man...
# 3                      0    my whole body feels itchy and like its on fire
# 4                      0  @nationwideclass no, it's not behaving at all....

# %% [markdown]
# # Test code

# %%
test_df = pd.read_csv(testdata140, header=None, usecols=[0,5],
                      names=['polarity of the tweet', 'text'],encoding="ISO-8859-1")
conditions_test = [
    (test_df['polarity of the tweet'] == 0),
    (test_df['polarity of the tweet'] == 2),
    (test_df['polarity of the tweet'] == 4)]
choices_test = ['negative', 'neutral', 'positive']
test_df['label'] = np.select(conditions_test, choices_test)
test_df.head()
# Out:
#    polarity of the tweet                                               text  \
# 0                      4  @stellargirl I loooooooovvvvvveee my Kindle2. ...
# 1                      4  Reading my kindle2...  Love it... Lee childs i...
# 2                      4  Ok, first assesment of the #kindle2 ...it fuck...
# 3                      4  @kenburbary You'll love your Kindle2. I've had...
# 4                      4  @mikefish  Fair enough. But i have the Kindle2...
#
#       label
# 0  positive
# 1  positive
# 2  positive
# 3  positive
# 4  positive

# %%
test_ls = test_df.to_dict('records')

# %%
train_df_negative = train_df.loc[train_df['polarity of the tweet']==0]

# %%
train_df_positive = train_df.loc[train_df['polarity of the tweet']==4]

# %%
frames = [train_df_negative.iloc[0:500,:],train_df_positive.iloc[0:500,:]]

# %%
result = pd.concat(frames)

# %%
conditions = [
    (result['polarity of the tweet'] == 0),
    (result['polarity of the tweet'] == 2),
    (result['polarity of the tweet'] == 4)]
choices = ['negative', 'neutral', 'positive']
result['label'] = np.select(conditions, choices)
result.head()
# Out:
#    polarity of the tweet                                               text  \
# 0                      0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1                      0  is upset that he can't update his Facebook by ...
# 2                      0  @Kenichan I dived many times for the ball. Man...
# 3                      0    my whole body feels itchy and like its on fire
# 4                      0  @nationwideclass no, it's not behaving at all....
#
#       label
# 0  negative
# 1  negative
# 2  negative
# 3  negative
# 4  negative

# %%
train_ls = result.to_dict('records')

# %%
import re
from nltk.tokenize import word_tokenize
from string import punctuation 
from nltk.corpus import stopwords 
import nltk
# nltk.download('punkt')

class PreProcessTweets:
    def __init__(self):
        self._stopwords = set(stopwords.words('english') + list(punctuation) + ['AT_USER','URL'])
        
    def processTweets(self, list_of_tweets):
        processedTweets=[]
        for tweet in list_of_tweets:
            processedTweets.append((self._processTweet(tweet["text"]),tweet["label"]))
        return processedTweets
    
    def _processTweet(self, tweet):
        tweet = tweet.lower() # convert text to lower-case
        tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+))', 'URL', tweet) # remove URLs
        tweet = re.sub('@[^\s]+', 'AT_USER', tweet) # remove usernames
        tweet = re.sub(r'#([^\s]+)', r'\1', tweet) # remove the # in #hashtag
#         tweet = word_tokenize(tweet) # remove repeated characters (helloooooooo into hello)
        return [word for word in tweet if word not in self._stopwords]
    
tweetProcessor = PreProcessTweets()

# %%
# Process Training Set
preprocessedTrainingSet = tweetProcessor.processTweets(train_ls)

# %%
preprocessedTrainingSet
# Out:
# [(['awww', "'s", 'bummer', 'shoulda', 'got', 'david', 'carr', 'third', 'day'],
#   'negative'),
#  (['upset',
#    'ca',
#    "n't",
#    'update',
#    'facebook',
#    'texting',
#    '...',
#    'might',
#    'cry',
#    'result',
#    'school',
#    'today',
#    'also',
#    'blah'],
#   'negative'),
#  (['dived',
#    'many',
#    'times',
#    'ball',
#    'managed',
#    'save',
#    '50',
#    'rest',
#    'go',
#    'bounds'],
#   'negative'),
#  (['whole', 'body', 'feels', 'itchy', 'like', 'fire'], 'negative'),
#  (["'s", 'behaving', "'m", 'mad', 'ca', "n't", 'see'], 'negative'),
#  (['whole', 'crew'], 'negative'),
#  (['need', 'hug'], 'negative'),
#  (['hey',
#    'long',
#    'time',
#    'see',
#    'yes..',
#    'rains',
#    'bit',
#    'bit',
#    'lol',
#    "'m",
#    'fine',
#    'thanks',
#    "'s"],
#   'negative'),
#  (['nope', "n't"], 'negative'),
#  (['que', 'muera'], 'negative'),
#  (['spring', 'break', 'plain', 'city', '...', "'s", 'snowing'], 'negative'),
#  (['re-pierced', 'ears'], 'negative'),
#  (['could', "n't", 'bear', 'watch', 'thought', 'ua', 'loss', 'embarrassing'],
#   'negative'),
#  (['counts', 'idk', 'either', 'never', 'talk', 'anymore'], 'negative'),
#  (['would',
#    "'ve",
#    'first',
#    "n't",
#    'gun',
#    'really',
#    'though',
#    'zac',
#    'snyder',
#    "'s",
#    'doucheclown'],
#   'negative'),
#  (['wish', 'got', 'watch', 'miss', 'premiere'], 'negative'),
#  (['hollis',
#    'death',
#    'scene',
#    'hurt',
#    'severely',
#    'watch',
#    'film',
#    'wry',
#    'directors',
#    'cut'],
#   'negative'),
#  (['file', 'taxes'], 'negative'),
#  (['ahh', 'ive', 'always', 'wanted', 'see', 'rent', 'love', 'soundtrack'],
#   'negative'),
#  (['oh', 'dear', 'drinking', 'forgotten', 'table', 'drinks'], 'negative'),
#  (['day', "n't", 'get', 'much', 'done'], 'negative'),
#  (['one',
#    'friend',
#    'called',
#    'asked',
#    'meet',
#    'mid',
#    'valley',
#    'today',
#    '...',
#    "'ve",
#    'time',
#    '*sigh*'],
#   'negative'),
#  (['baked', 'cake', 'ated'], 'negative'),
#  (['week', 'going', 'hoped'], 'negative'),
#  (['blagh', 'class', '8', 'tomorrow'], 'negative'),
#  (['hate', 'call', 'wake', 'people'], 'negative'),
#  (['going', 'cry', 'sleep', 'watching', 'marley'], 'negative'),
#  (['im', 'sad', 'miss.lilly'], 'negative'),
#  (['ooooh',
#    '...',
#    'lol',
#    'leslie',
#    '...',
#    'ok',
#    'wo',
#    "n't",
#    'leslie',
#    'wo',
#    "n't",
#    'get',
#    'mad'],
#   'negative'),
#  (['meh',
#    '...',
#    'almost',
#    'lover',
#    'exception',
#    '...',
#    'track',
#    'gets',
#    'depressed',
#    'every',
#    'time'],
#   'negative'),
#  (['some1', 'hacked', 'account', 'aim', 'make', 'new', 'one'], 'negative'),
#  (['want',
#    'go',
#    'promote',
#    'gear',
#    'groove',
#    'unfornately',
#    'ride',
#    'may',
#    'b',
#    'going',
#    'one',
#    'anaheim',
#    'may',
#    'though'],
#   'negative'),
#  (['thought',
#    'sleeping',
#    'option',
#    'tomorrow',
#    'realizing',
#    'evaluations',
#    'morning',
#    'work',
#    'afternoon'],
#   'negative'),
#  (['awe', 'love', '1', 'miss'], 'negative'),
#  (['cry', 'asian', 'eyes', 'sleep', 'night'], 'negative'),
#  (['ok',
#    "'m",
#    'sick',
#    'spent',
#    'hour',
#    'sitting',
#    'shower',
#    'cause',
#    'sick',
#    'stand',
#    'held',
#    'back',
#    'puke',
#    'like',
#    'champ',
#    'bed'],
#   'negative'),
#  (['ill',
#    'tell',
#    'ya',
#    'story',
#    'later',
#    'good',
#    'day',
#    'ill',
#    'workin',
#    'like',
#    'three',
#    'hours',
#    '...'],
#   'negative'),
#  (['sorry', 'bed', 'time', 'came', 'gmt+1'], 'negative'),
#  (["n't",
#    'either',
#    'depressing',
#    "n't",
#    'think',
#    'even',
#    'want',
#    'know',
#    'kids',
#    'suitcases'],
#   'negative'),
#  (['bed',
#    'class',
#    '8-12.',
#    'work',
#    '12-3.',
#    'gym',
#    '3-5',
#    '6.',
#    'class',
#    '6-10.',
#    'another',
#    'day',
#    "'s",
#    'gon',
#    'na',
#    'fly',
#    'miss',
#    'girlfriend'],
#   'negative'),
#  (['really',
#    "n't",
#    'feel',
#    'like',
#    'getting',
#    'today',
#    '...',
#    'got',
#    'study',
#    'tomorrows',
#    'practical',
#    'exam',
#    '...'],
#   'negative'),
#  (["'s", 'reason', 'teardrops', 'guitar', 'one', 'enough', 'break', 'heart'],
#   'negative'),
#  (['sad',
#    'sad',
#    'sad',
#    "n't",
#    'know',
#    'hate',
#    'feeling',
#    'wan',
#    'na',
#    'sleep',
#    'still',
#    'ca',
#    "n't"],
#   'negative'),
#  (['awww',
#    'soo',
#    'wish',
#    'see',
#    'finally',
#    'comfortable',
#    'im',
#    'sad',
#    'missed'],
#   'negative'),
#  (['falling',
#    'asleep',
#    'heard',
#    'tracy',
#    'girl',
#    "'s",
#    'body',
#    'found',
#    'sad',
#    'heart',
#    'breaks',
#    'family'],
#   'negative'),
#  (['yay', "'m", 'happy', 'job', 'also', 'means', 'less', 'time', '...'],
#   'negative'),
#  (['checked',
#    'user',
#    'timeline',
#    'blackberry',
#    'looks',
#    'like',
#    'twanking',
#    'still',
#    'happening',
#    'ppl',
#    'still',
#    'probs',
#    'w/',
#    'bgs',
#    'uids'],
#   'negative'),
#  (['oh', 'man', '...', 'ironing', 'fave', 'top', 'wear', 'meeting', 'burnt'],
#   'negative'),
#  (['strangely', 'sad', 'lilo', 'samro', 'breaking'], 'negative'),
#  (['oh', "'m", 'sorry', "n't", 'think', 'retweeting'], 'negative'),
#  (['broadband',
#    'plan',
#    'massive',
#    'broken',
#    'promise',
#    'via',
#    'still',
#    'waiting',
#    'broadband'],
#   'negative'),
#  (['wow',
#    'tons',
#    'replies',
#    'may',
#    'unfollow',
#    'see',
#    'friends',
#    'tweets',
#    "'re",
#    'scrolling',
#    'feed',
#    'lot'],
#   'negative'),
#  (['duck', 'chicken', 'taking', 'wayyy', 'long', 'hatch'], 'negative'),
#  (['put',
#    'vacation',
#    'photos',
#    'online',
#    'yrs',
#    'ago',
#    'pc',
#    'crashed',
#    'forget',
#    'name',
#    'site'],
#   'negative'),
#  (['need', 'hug'], 'negative'),
#  (['sure',
#    'pos',
#    'much',
#    'want',
#    'dont',
#    'think',
#    'trade',
#    'away',
#    'company',
#    'assets',
#    'sorry',
#    'andy'],
#   'negative'),
#  (['hate', 'happens', '...'], 'negative'),
#  (['sad',
#    'feeling',
#    'dallas',
#    'going',
#    'show',
#    'got',
#    'ta',
#    'say',
#    'though',
#    "'d",
#    'think',
#    'shows',
#    'would',
#    'use',
#    'music',
#    'game',
#    'mmm'],
#   'negative'),
#  (['ugh', '...', '.92', 'degrees', 'tomorrow'], 'negative'),
#  (['u',
#    'move',
#    'thought',
#    'u',
#    'already',
#    'sd',
#    'hmmm',
#    'random',
#    'u',
#    'found',
#    'glad',
#    'hear',
#    'yer',
#    'well'],
#   'negative'),
#  (['miss',
#    'ps3',
#    "'s",
#    'commission',
#    'wutcha',
#    'playing',
#    'copped',
#    "'blood",
#    'sand'],
#   'negative'),
#  (['leaving', 'parking', 'lot', 'work'], 'negative'),
#  (['life', 'cool'], 'negative'),
#  (['sadly',
#    'though',
#    "'ve",
#    'never',
#    'gotten',
#    'experience',
#    'post',
#    'coitus',
#    'cigarette',
#    'never'],
#   'negative'),
#  (['nice', 'day', 'bad', 'rain', 'comes', 'tomorrow', '5am'], 'negative'),
#  (['bad',
#    'wo',
#    "n't",
#    'around',
#    'lost',
#    'job',
#    'ca',
#    "n't",
#    'even',
#    'pay',
#    'phone',
#    'bill',
#    'lmao',
#    'aw',
#    'shucks'],
#   'negative'),
#  (['damm', 'back', 'school', 'tomorrow'], 'negative'),
#  (['mo',
#    'jobs',
#    'money',
#    'hell',
#    'min',
#    'wage',
#    '4',
#    'f',
#    'n',
#    'clams',
#    'hour'],
#   'negative'),
#  (['forever', '...', 'see', 'soon'], 'negative'),
#  (['agreed', 'saw', 'failwhale', 'allllll', 'day', 'today'], 'negative'),
#  (['oh',
#    'haha',
#    '...',
#    'dude',
#    'dont',
#    'really',
#    'look',
#    'em',
#    'unless',
#    'someone',
#    'says',
#    'hey',
#    'added',
#    'sorry',
#    "'m",
#    'terrible',
#    'need',
#    'pop'],
#   'negative'),
#  (["'m",
#    'sure',
#    "'re",
#    'right',
#    '...',
#    'need',
#    'start',
#    'working',
#    'nikster',
#    '...',
#    'jared',
#    'least'],
#   'negative'),
#  (['really', 'hate', 'people', 'diss', 'bands', 'trace', 'clearly', 'ugly'],
#   'negative'),
#  (['gym',
#    'attire',
#    'today',
#    'puma',
#    'singlet',
#    'adidas',
#    'shorts',
#    '...',
#    '...',
#    '.and',
#    'black',
#    'business',
#    'socks',
#    'leather',
#    'shoes',
#    'lucky',
#    'run',
#    'cute',
#    'girls'],
#   'negative'),
#  (['wo', "n't", 'show', 'location'], 'negative'),
#  (['picnic', 'phone', 'smells', 'like', 'citrus'], 'negative'),
#  (['donkey',
#    'sensitive',
#    'comments',
#    'nevertheless',
#    "'d",
#    "'d",
#    'glad',
#    'see',
#    'mug',
#    'asap',
#    'charger',
#    'still',
#    'awol'],
#   'negative'),
#  (['new', 'csi', 'tonight', 'fml'], 'negative'),
#  (['think', 'arms', 'sore', 'tennis'], 'negative'),
#  (['wonders',
#    'someone',
#    'u',
#    'like',
#    'much',
#    'make',
#    'unhappy',
#    'split',
#    'seccond',
#    'depressed'],
#   'negative'),
#  (['sleep',
#    'soon',
#    '...',
#    'hate',
#    'saying',
#    'bye',
#    'see',
#    'tomorrow',
#    'night'],
#   'negative'),
#  (['got',
#    'ur',
#    'newsletter',
#    'fares',
#    'really',
#    'unbelievable',
#    'shame',
#    'already',
#    'booked',
#    'paid',
#    'mine'],
#   'negative'),
#  (['missin', 'boo'], 'negative'),
#  (['itm'], 'negative'),
#  (['damn', '...', "n't", 'chalk', 'chalkboard', 'useless'], 'negative'),
#  (['blast',
#    'getty',
#    'villa',
#    'hates',
#    "'s",
#    'sore',
#    'throat',
#    'day',
#    "'s",
#    'getting',
#    'worse'],
#   'negative'),
#  (['hey', 'missed', 'ya', 'meeting', 'sup', 'mama'], 'negative'),
#  (['tummy',
#    'hurts',
#    'wonder',
#    'hypnosis',
#    'anything',
#    "'s",
#    'working',
#    'get',
#    'stop',
#    'smoking'],
#   'negative'),
#  (['always', 'fat', 'ones'], 'negative'),
#  (['sorry',
#    'babe',
#    'fam',
#    'annoys',
#    'thankfully',
#    "'re",
#    'asleep',
#    'right',
#    'muahaha',
#    '*evil',
#    'laugh*'],
#   'negative'),
#  (['paid',
#    'attention',
#    'covered',
#    'photoshop',
#    'webpage',
#    'design',
#    'class',
#    'undergrad'],
#   'negative'),
#  (['wednesday', 'b-day', "n't", 'know', '2'], 'negative'),
#  (['poor', 'cameron', 'hills'], 'negative'),
#  (['pray',
#    'please',
#    'ex',
#    'threatening',
#    'start',
#    'sh**',
#    'my/our',
#    'babies',
#    '1st',
#    'birthday',
#    'party',
#    'jerk',
#    'still',
#    'headache'],
#   'negative'),
#  (['hmm',
#    'u',
#    'really',
#    'enjoy',
#    'problems',
#    'constants',
#    'u',
#    'think',
#    'things',
#    'find',
#    'someone',
#    'ulike'],
#   'negative'),
#  (['strider', 'sick', 'little', 'puppy'], 'negative'),
#  (['rylee',
#    'grace',
#    '...',
#    'wana',
#    'go',
#    'steve',
#    "'s",
#    'party',
#    'sadly',
#    'since',
#    'easter',
#    'wnt',
#    'b',
#    'able',
#    '2',
#    'much',
#    'ohh',
#    'well',
#    '...',
#    '..'],
#   'negative'),
#  (['hey', 'actually', 'one', 'bracket', 'pools', 'bad', "n't", 'one', 'money'],
#   'negative'),
#  (["n't", 'follow', 'either', 'work'], 'negative'),
#  (['bad',
#    'nite',
#    'favorite',
#    'teams',
#    'astros',
#    'spartans',
#    'lose',
#    'nite',
#    't.w',
#    'good'],
#   'negative'),
#  (['body',
#    'missing',
#    'northern',
#    'calif.',
#    'girl',
#    'found',
#    'police',
#    'found',
#    'remains',
#    'missing',
#    'northern',
#    'california',
#    'girl',
#    '..'],
#   'negative'),
#  (['hope',
#    'increase',
#    'capacity',
#    'fast',
#    'yesterday',
#    'pain',
#    'got',
#    'fail',
#    'whale',
#    '+15',
#    'times',
#    '2',
#    'hours',
#    '...'],
#   'negative'),
#  (['behind', 'classes', 'work'], 'negative'),
#  (['watching', 'quot', 'house', 'quot'], 'negative'),
#  (['remember', 'bum', 'leg', 'strikes', 'back', 'time', 'serious'],
#   'negative'),
#  (['cool',
#    'kinds',
#    'complaints',
#    'laptop',
#    'online',
#    'overheating',
#    'recalls'],
#   'negative'),
#  (['emily', 'glad', 'mommy', 'done', 'training', 'new', 'job', 'misses'],
#   'negative'),
#  (['would',
#    'rather',
#    'first',
#    'party',
#    'send',
#    'bad',
#    'messages',
#    '3rd',
#    'party',
#    'send',
#    'mixed',
#    'ones',
#    'sophmore',
#    'year'],
#   'negative'),
#  (["'s", 'overrated'], 'negative'),
#  (['know',
#    'heard',
#    'afternoon',
#    'wondered',
#    'thing',
#    'moscow',
#    'behind',
#    'times'],
#   'negative'),
#  (['laying', 'bed', 'voice..'], 'negative'),
#  (["'m", 'sooo', 'sad', 'killed', 'kutner', 'house', 'whyyyyyyyy'],
#   'negative'),
#  (['sorry', 'tell', 'mea', 'culpa', 'really', 'sorry'], 'negative'),
#  (["n't",
#    'make',
#    'sense',
#    'suicide',
#    'thing',
#    'refuse',
#    'believe',
#    'actually',
#    'happened'],
#   'negative'),
#  (['hope', 'ok'], 'negative'),
#  (['damn',
#    'grind',
#    'inspirational',
#    'saddening',
#    'time',
#    "n't",
#    'want',
#    'stop',
#    'cuz',
#    'like',
#    'u',
#    'much',
#    'love'],
#   'negative'),
#  (['yeah', 'aw', 'know', 'wudnt', 'stand', 'chance'], 'negative'),
#  (['ugh', 'cant', 'sleep', '1:30am'], 'negative'),
#  (['hanging', 'crooners', 'wan', 'na', 'sing', 'ca', "n't", 'sucks'],
#   'negative'),
#  (['aaw',
#    'miss',
#    'ya',
#    'too..',
#    'im',
#    'leaving',
#    'bh',
#    'tomorrow',
#    'quot',
#    'morning',
#    'quot',
#    'think..',
#    'aww',
#    'wan',
#    'na',
#    'go',
#    'beach',
#    'w',
#    'u',
#    'girls'],
#   'negative'),
#  (['pissed', "'s", 'asba', "'s", 'radio', 'station'], 'negative'),
#  (['wednesday', 'b-day', 'n', "n't", 'know', '2'], 'negative'),
#  (['know',
#    'life',
#    'flipped',
#    'upside',
#    'thought',
#    'head',
#    'ramen',
#    'sounds',
#    'good'],
#   'negative'),
#  (['pain', 'back', 'sides', 'hurt', 'mention', 'crying', 'made', 'fail'],
#   'negative'),
#  (['late',
#    'night',
#    'snack',
#    'glass',
#    'oj',
#    'b/c',
#    "'m",
#    'quot',
#    'sickness',
#    'quot',
#    'back',
#    'sleep',
#    '...',
#    'ugh',
#    'hate',
#    'getting',
#    'sick',
#    '...'],
#   'negative'),
#  (['but..', 'but..', 'but..', "'m", 'big', 'fan', 'camilla', 'belle'],
#   'negative'),
#  (['wah',
#    'ca',
#    "n't",
#    'see',
#    'clip',
#    'must',
#    'el-stupido',
#    'work',
#    'filters',
#    'ca',
#    "n't",
#    'wait',
#    "'till",
#    'get',
#    "'puter",
#    'something',
#    'else',
#    '2',
#    'blame',
#    'ex',
#    '4.',
#    'broke',
#    'mine'],
#   'negative'),
#  (['week',
#    'seems',
#    'get',
#    'longer',
#    'longer',
#    'terms',
#    'much',
#    'need',
#    'do..',
#    'much',
#    "'m",
#    'actually',
#    'going',
#    'get',
#    'done'],
#   'negative'),
#  (["'m", 'cold'], 'negative'),
#  (['ehhh',
#    "n't",
#    'weather',
#    "'s",
#    'gon',
#    'na',
#    'take',
#    'turn',
#    'ugly',
#    'tomorrow'],
#   'negative'),
#  (['haha', 'cooooold', 'still', 'go', 'show', 'incredible', 'stuff'],
#   'negative'),
#  (['hoping', 'tummy', 'rumbles', 'go', 'away', 'soon'], 'negative'),
#  (['notice',
#    'told',
#    "'d",
#    'working',
#    'tomorrow',
#    'called',
#    'agency',
#    'follow',
#    'said'],
#   'negative'),
#  (['almost', 'bedtime'], 'negative'),
#  (["'m",
#    'missing',
#    'babe..',
#    'long',
#    'alive',
#    "'m",
#    'happy..',
#    'yawwwnn..',
#    "'m",
#    'tired',
#    'love',
#    'imma',
#    'try',
#    'sleep',
#    'hopefully',
#    'headstart'],
#   'negative'),
#  (['agh', '...', 'snow'], 'negative'),
#  (['miss', 'kenny', 'powers'], 'negative'),
#  (['thank',
#    'letting',
#    'people',
#    'know',
#    "'m",
#    'sad',
#    'direct',
#    'message',
#    'got',
#    "n't",
#    'actually',
#    'bridget'],
#   'negative'),
#  (['...',
#    'india',
#    'missed',
#    '100th',
#    'test',
#    'victory',
#    'n',
#    '10th',
#    'consecutive',
#    'win',
#    'without',
#    'loss'],
#   'negative'),
#  (['guess', "'s"], 'negative'),
#  (['sadly', 'going', 'bed'], 'negative'),
#  (['shame', 'hear', 'stephan'], 'negative'),
#  (['hey', "'m", 'leavin', 'morning', '...'], 'negative'),
#  (['intending',
#    'finish',
#    'editing',
#    '536-page',
#    'novel',
#    'manuscript',
#    'tonight',
#    'probably',
#    'happen',
#    '12',
#    'pages',
#    'left'],
#   'negative'),
#  (['laid', 'around', 'much', 'today', '...', 'head', 'hurts'], 'negative'),
#  (['still',
#    "n't",
#    'read',
#    '9th',
#    'amp',
#    '10th',
#    'princess',
#    'diaries',
#    'saving',
#    'francesca',
#    'made',
#    'cry',
#    'end',
#    'hmm',
#    'easy',
#    'books'],
#   'negative'),
#  (['nokia', '1110', 'died..'], 'negative'),
#  (['mom',
#    'might',
#    'breast',
#    'cancer',
#    'wo',
#    "n't",
#    'find',
#    'anything',
#    'like',
#    'week',
#    "'m",
#    'worried'],
#   'negative'),
#  (['going', 'sleep', 'hoping', 'tomorrow', 'better', 'day'], 'negative'),
#  (['lol..',
#    'wish',
#    'understood',
#    'daylight',
#    'savings',
#    'ended',
#    'though',
#    'breakfast',
#    'hour',
#    'later',
#    'keep',
#    'waking',
#    'kids'],
#   'negative'),
#  (['lame'], 'negative'),
#  (["n't", 'understand', '...', 'really', "n't"], 'negative'),
#  (['heroes', "n't", 'season', '...'], 'negative'),
#  (['living', 'downtown', 'sure', "n't", 'much', 'fun'], 'negative'),
#  (['calorie',
#    'wise',
#    'wish',
#    'junk',
#    'food',
#    'calorie',
#    'free',
#    'ate',
#    'thing',
#    'sour',
#    'skittles',
#    'big',
#    'ass',
#    'cherry',
#    'coke'],
#   'negative'),
#  (['man', 'work', 'hard'], 'negative'),
#  (['getting', 'sick', 'time', 'hot', 'tea', 'studying', 'sleeeep'],
#   'negative'),
#  (['getting', 'eyebrows', 'waxed', 'pain'], 'negative'),
#  (['phantasy', 'star', 'yesterday', 'going', 'work', '...'], 'negative'),
#  (['oh',
#    'got',
#    'macheist',
#    '3.0',
#    'apps',
#    'sweet',
#    "n't",
#    'get',
#    'espresso',
#    'serial',
#    'though',
#    'although',
#    'said',
#    'sent',
#    'oh',
#    'well'],
#   'negative'),
#  (['picked',
#    'mich',
#    'st',
#    'win',
#    'get',
#    'go',
#    'feeling',
#    'pretty',
#    'good',
#    'pick',
#    'way',
#    '...',
#    '...',
#    'tonight',
#    "'s",
#    'lost'],
#   'negative'),
#  (['alone', 'downstairs', '...', 'working'], 'negative'),
#  (['feel', 'bad'], 'negative'),
#  (['hates', 'anoop', 'mean', 'seriously', "'s", 'kinda', 'mean'], 'negative'),
#  (['yes', 'sprint', '4g', 'baltimore', 'chicago', 'far'], 'negative'),
#  (["'m",
#    'stuck',
#    'awake',
#    'middle',
#    'night',
#    'second',
#    'day',
#    'row',
#    'felt',
#    'terrible',
#    'yesterday'],
#   'negative'),
#  (['thanks', 'bursting', 'bubble'], 'negative'),
#  (['going',
#    'school',
#    'soon',
#    '...',
#    'ca',
#    "n't",
#    'find',
#    'anything',
#    'wear',
#    'gosh',
#    "'s",
#    'hard'],
#   'negative'),
#  (['serious', 'lol'], 'negative'),
#  (['page', 'sooooo', 'long', 'got', 'deleted', 'sad', 'day', 'history'],
#   'negative'),
#  (['crazy', 'wind', 'today', 'birding'], 'negative'),
#  (['currently', 'work..'], 'negative'),
#  (['grrr..',
#    'ipods',
#    'acting',
#    'weird',
#    'jai',
#    'ho',
#    'thinking',
#    "n't",
#    'playing',
#    'full',
#    'songs..',
#    'ughh'],
#   'negative'),
#  (['send', 'dvd', 'cos', 'missed', 'heaps', 'happy'], 'negative'),
#  (["n't", 'see', 'big', 'deal', 'website'], 'negative'),
#  (["'m", 'sorry', "'re", 'go', 'therapyfail'], 'negative'),
#  (['far', 'way', 'rail', 'tips'], 'negative'),
#  (["'m",
#    'still',
#    'swear',
#    'keep',
#    'losing',
#    'gaining',
#    'losing',
#    'gaining',
#    'tweeps',
#    'heart',
#    'wrenching'],
#   'negative'),
#  (['today',
#    'realized',
#    'good',
#    'hiding',
#    'things',
#    'even',
#    'ca',
#    "n't",
#    'find'],
#   'negative'),
#  (['staying',
#    'friends',
#    'house',
#    '...',
#    'house',
#    'sitting',
#    'neighbors',
#    'loud-having',
#    'party'],
#   'negative'),
#  (['danny',
#    'im',
#    'upset',
#    'wasnt',
#    'watch',
#    'live',
#    'chat',
#    'car',
#    '3',
#    'hours',
#    'trip',
#    'im',
#    'soooo',
#    'upset'],
#   'negative'),
#  (['check', 'mug'], 'negative'),
#  (['borders', 'closed', '10'], 'negative'),
#  (['downloading',
#    'nin',
#    "'s",
#    'new',
#    'album',
#    'quot',
#    'slip',
#    'quot',
#    'hell',
#    'come',
#    "'m",
#    'behind',
#    'times',
#    'days'],
#   'negative'),
#  (['woke',
#    'already',
#    'written',
#    'e-mail',
#    '...',
#    "'ve",
#    'go',
#    'early',
#    'university',
#    'today',
#    'teach',
#    '8:30'],
#   'negative'),
#  (['watching', 'hill', '.and', 'making', 'sad'], 'negative'),
#  (['many',
#    'channels',
#    '...',
#    'yet',
#    'boring',
#    '...',
#    'lazy',
#    'day',
#    'may',
#    'find',
#    'hobby'],
#   'negative'),
#  (['miss', 'buddy', 'ill', 'ny', '25th'], 'negative'),
#  (['love',
#    'french',
#    'tell',
#    'people',
#    'south',
#    "'m",
#    'qtr',
#    'french',
#    'snarl',
#    'french',
#    'beautiful',
#    'people'],
#   'negative'),
#  (['opps..',
#    'said..',
#    'still',
#    'got',
#    'one',
#    'day',
#    'remain',
#    'problem',
#    'come'],
#   'negative'),
#  (['activated',
#    'selfcontrol',
#    'block',
#    'early',
#    'meaning',
#    'ca',
#    "n't",
#    'check',
#    'new',
#    'qc',
#    'regularizing',
#    'internal',
#    'clock',
#    'might',
#    'difficult',
#    'fb'],
#   'negative'),
#  (['oh'], 'negative'),
#  (['spencer', 'good', 'guy'], 'negative'),
#  (['reese',
#    'dying',
#    'ttsc',
#    'season',
#    'finale',
#    'next',
#    'week',
#    '24',
#    'boring',
#    'madame',
#    'president',
#    'crazy',
#    'woman'],
#   'negative'),
#  (['hate',
#    'limited',
#    'letters',
#    'too.hope',
#    'guys',
#    'fine',
#    'pray',
#    'dog',
#    'sheï¿½s',
#    'well'],
#   'negative'),
#  (["n't", 'get', 'shit', 'done', 'today', "'m", 'screwed'], 'negative'),
#  (['wanttss', 'go'], 'negative'),
#  (['going', 'sleep', 'tonite'], 'negative'),
#  (['worried', 'tired', 'post', 'tonight'], 'negative'),
#  (['could', "n't", 'get', 'shit', 'done', 'today', "'m", 'screwed'],
#   'negative'),
#  (['job',
#    'interview',
#    'cardiff',
#    'today',
#    'wish',
#    'luck',
#    'got',
#    '3',
#    'hours',
#    'sleep'],
#   'negative'),
#  (['show', 'whack', 'way', 'worse', 'whack', "'s", 'wiggety-whack'],
#   'negative'),
#  (['really',
#    "n't",
#    'think',
#    'people',
#    'choose',
#    'way',
#    'think',
#    'chose',
#    'accept',
#    'family',
#    "'s",
#    'help',
#    'might',
#    'dead'],
#   'negative'),
#  (["'re",
#    'going',
#    'kill',
#    "'ve",
#    'seen',
#    'ds9',
#    "'ve",
#    'waiting',
#    'till',
#    'one',
#    'solid',
#    'week',
#    'sitting'],
#   'negative'),
#  (['think', 'ur', 'right', 'hahaha', '4.5', 'hrs'], 'negative'),
#  (['hate', 'see', 'spartans', 'sad'], 'negative'),
#  (['mind',
#    'body',
#    'severely',
#    'protesting',
#    'quot',
#    'getting',
#    'quot',
#    'thing',
#    'nightmares',
#    'boot'],
#   'negative'),
#  (["'m", 'goin', 'follow', 'u', 'since', 'u', "n't", 'lol', 'go', 'angels'],
#   'negative'),
#  ([], 'negative'),
#  (['think', 'want', 'read', 'books', 'library', "n't"], 'negative'),
#  (['nap',
#    'interrupted',
#    'many',
#    'times',
#    'today',
#    'going',
#    'japanese',
#    "'rents",
#    '...'],
#   'negative'),
#  (['kind', 'longs', 'bus', 'shows', 'end', 'ghost', 'world', 'right', 'ugh'],
#   'negative'),
#  (['canada',
#    'canada',
#    'weird',
#    "'re",
#    'supposed',
#    'get',
#    'snow',
#    'wednesday',
#    'ugh'],
#   'negative'),
#  (['awwh',
#    'babs',
#    '...',
#    'look',
#    'sad',
#    'underneith',
#    'shop',
#    'entrance',
#    'quot',
#    'yesterday',
#    "'s",
#    'musik',
#    'quot',
#    'o-',
#    'like',
#    'look',
#    'new',
#    'transformer',
#    'movie'],
#   'negative'),
#  (['sad', "'feet", 'macbook', 'fell'], 'negative'),
#  (["'m",
#    'gon',
#    'na',
#    'get',
#    'late',
#    'tomorrow',
#    "'s",
#    '132am',
#    'gon',
#    'na',
#    'get',
#    'tipsy',
#    'lonesome',
#    "'s",
#    '...',
#    "'s",
#    'sad'],
#   'negative'),
#  (["'m",
#    'sweating',
#    'forthcoming',
#    'trip',
#    'e3',
#    'ca',
#    "n't",
#    'find',
#    'someone',
#    'crash',
#    "'m",
#    'may',
#    'screwed'],
#   'negative'),
#  (['gotten', 'somebody', 'read', 'tweets', 'cant', 'get', 'make', 'account'],
#   'negative'),
#  (['omgawd', 'couldnt', 'handle', 'cat', 'heat', 'time'], 'negative'),
#  (['hope', 'make', 'auburn', 'show', 'looking', 'good'], 'negative'),
#  (['*thats',
#    'people',
#    'mag',
#    'haha',
#    'couldnt',
#    'fit',
#    'in..',
#    'dont',
#    'think',
#    'pictures',
#    'ever',
#    'made',
#    'magazine',
#    'tho',
#    'haha'],
#   'negative'),
#  (['congrats', 'totally', 'forgot', 'submit', 'photos'], 'negative'),
#  (['awww',
#    'good',
#    'luck',
#    'paula',
#    'please',
#    "n't",
#    'work',
#    'hard',
#    'hope',
#    'fun',
#    'new',
#    'album',
#    'gon',
#    'na',
#    'amazing',
#    'xxx'],
#   'negative'),
#  (['leaving', '...', '-gets', 'sad-'], 'negative'),
#  (['miss',
#    'twitter',
#    'phone',
#    'broke',
#    "'m",
#    'using',
#    'stupid',
#    'nokia',
#    'phone',
#    'ughhh',
#    'miss',
#    'advance',
#    'phone'],
#   'negative'),
#  (['shooting', 'outside', 'house', 'kidding', 'scared'], 'negative'),
#  (['tuesdayï¿½ll',
#    'start',
#    'reflection',
#    'ï¿½n',
#    'lecture',
#    'stress',
#    'reducing',
#    'techniques',
#    'sure',
#    'might',
#    'become',
#    'useful',
#    'us',
#    'accompaniers'],
#   'negative'),
#  (['tragedy', 'disaster', 'news', 'week'], 'negative'),
#  (['yes',
#    'yes',
#    'still',
#    'trying',
#    'find',
#    'picture',
#    'upload',
#    'correclty..'],
#   'negative'),
#  (['oh',
#    'red',
#    'sox',
#    'game',
#    'rained',
#    'looking',
#    'forward',
#    'opening',
#    'day'],
#   'negative'),
#  (['still', 'ca', "n't", 'find', 'keys'], 'negative'),
#  (['know', 'right', 'dunno', 'going', 'twitter'], 'negative'),
#  (['might', 'getting', 'sore', 'throat'], 'negative'),
#  (['home',
#    'town',
#    'mammy',
#    'called',
#    'depressd',
#    'pls',
#    'explain',
#    'parent',
#    'let',
#    '8yr',
#    'old',
#    'child',
#    'walk',
#    'alone',
#    'hello',
#    '2009'],
#   'negative'),
#  (['think',
#    'need',
#    'find',
#    'better',
#    'anti-depressants',
#    'think',
#    'paxil/wellbutrin',
#    'combo',
#    'losing',
#    'efficacy'],
#   'negative'),
#  (['restaurant',
#    'called',
#    'woodntap',
#    'competitive',
#    'eating',
#    'tourney',
#    'round',
#    'tourney',
#    'time',
#    'place',
#    '2nd'],
#   'negative'),
#  (['bathroom', '...', 'wake', 'lakin'], 'negative'),
#  (['want', 'tacos', 'margarhitas', 'telll', 'gay', 'say', 'hello', 'lt', '3'],
#   'negative'),
#  (['im', 'lonely', 'keep', 'company', '22', 'female', 'california'],
#   'negative'),
#  (['bad', 'day', 'betfair', 'office'], 'negative'),
#  (['miss',
#    'ca',
#    "n't",
#    'wait',
#    'celebrate',
#    'tar',
#    'heel',
#    'win',
#    'weekend',
#    'though'],
#   'negative'),
#  (["'m",
#    'really',
#    'cold',
#    "n't",
#    'want',
#    'go',
#    'sleep',
#    'yet',
#    "'s",
#    'nothing'],
#   'negative'),
#  (['4', 'u', 'officially', '4', 'go', 'round'], 'negative'),
#  (['monkeys',
#    'found',
#    'twin',
#    'wont',
#    'even',
#    'write',
#    'back',
#    "'m",
#    'heartbroken'],
#   'negative'),
#  (['aww', 'know', 'felt', 'like', 'yesterday', 'work'], 'negative'),
#  (['treaty', "n't", 'defined'], 'negative'),
#  (['missed',
#    'brent',
#    'praise',
#    'band',
#    'fun',
#    'lead',
#    'guitarist',
#    'lt',
#    'pout',
#    'gt'],
#   'negative'),
#  (['poor',
#    'john',
#    'happens',
#    'play',
#    'fruit',
#    'microwave',
#    'seriously',
#    'though',
#    'seen',
#    'doctor',
#    'xxx'],
#   'negative'),
#  (['missing',
#    'bff',
#    'watching',
#    'home',
#    'away',
#    'reminds',
#    'lt',
#    '3',
#    'shout',
#    'u',
#    'courts'],
#   'negative'),
#  ([], 'negative'),
#  (['new', 'video', 'card', 'doa'], 'negative'),
#  (['feeling',
#    'lost',
#    'naked',
#    'confused',
#    'jk',
#    'sort',
#    '...',
#    '..no',
#    'iphone'],
#   'negative'),
#  (['damn',
#    'late',
#    'filling',
#    'appraisal',
#    'form',
#    'people',
#    'almost',
#    'sent',
#    '..',
#    'occupied',
#    'work'],
#   'negative'),
#  (['missed',
#    'brent',
#    'praise',
#    'band',
#    'fun',
#    'lead',
#    'guitarist',
#    'lt',
#    'pout',
#    'gt'],
#   'negative'),
#  (['think',
#    'much',
#    'past',
#    'cant',
#    'change',
#    'deserved',
#    'much',
#    'wat',
#    'got',
#    '..but',
#    'still',
#    'thinking',
#    'gah'],
#   'negative'),
#  (['lost', 'ring', "'s", 'no-where', 'seen'], 'negative'),
#  (['ooooooh',
#    '*sealclap*',
#    'see',
#    'download',
#    'shitloads',
#    'zip',
#    'folders',
#    '4chan',
#    'internet',
#    'moneys',
#    'fuck',
#    'yeah',
#    'alicia',
#    'amp',
#    'mikey'],
#   'negative'),
#  (['still',
#    'nursing',
#    'nile',
#    'glad',
#    'feeling',
#    'better',
#    'hate',
#    'baby',
#    'sick'],
#   'negative'),
#  (['fucked', 'go', 'back', 'ic'], 'negative'),
#  (['yoyoyo', 'internet', 'rude', 'tonight', 'reconnected', "'m", 'go', 'bed'],
#   'negative'),
#  (['well', 'uni', 'stuff', 'netball', 'netbal', "'ve", 'done', 'uni', 'stuff'],
#   'negative'),
#  (['poor'], 'negative'),
#  (['help', 'forget', '8th', 'april', 'amp', '13th', 'july'], 'negative'),
#  (['dierks', 'bentley', 'comin', 'columbus', 'oh', 'wan', 'na', 'go', 'bad'],
#   'negative'),
#  (['take', 'sidekick', 'back'], 'negative'),
#  (['congrats', "'m", 'totally', 'jealous', 'wish', 'xm', 'working'],
#   'negative'),
#  (['gr8t', 'face', 'itchy'], 'negative'),
#  (['poor',
#    'socks',
#    'luvvvvv',
#    'golden',
#    'retriever',
#    'want',
#    'one',
#    'sighhhh'],
#   'negative'),
#  (['saw',
#    'found',
#    'tracy',
#    'girl',
#    'piece',
#    'luggage',
#    '...',
#    'fucking',
#    'terrible'],
#   'negative'),
#  (['aaaaand', 'nausea', 'back'], 'negative'),
#  (['ooh', 'iï¿½m', 'excited', 'even', 'going', '2', 'long', 'love', 'youtube'],
#   'negative'),
#  (['spent',
#    '1',
#    'hour',
#    'reach',
#    'axis',
#    'bank',
#    'find',
#    'today',
#    'holiday',
#    'mahavir',
#    'jayanti',
#    'contd..'],
#   'negative'),
#  (['agree', '...', 'jobros', 'dont', 'update', 'theres', 'often'], 'negative'),
#  (['hilarious',
#    'linked',
#    'clip',
#    'lj',
#    'time',
#    'ago',
#    'went',
#    'back',
#    'dead',
#    'link'],
#   'negative'),
#  (['oooooooo', 'im', 'neither', 'thats', 'need', 'study'], 'negative'),
#  (["n't",
#    'tweeted',
#    'nearly',
#    'day',
#    'posted',
#    'website',
#    'tonight',
#    'hopefully',
#    'goes',
#    'well',
#    'night',
#    'time'],
#   'negative'),
#  (['miss', 'bentley'], 'negative'),
#  (['seriously', 'needs', 'finish', 'job', 'applications'], 'negative'),
#  (['son',
#    'vincas',
#    'sick',
#    'stay',
#    'home',
#    'three',
#    'tense',
#    'days',
#    'work',
#    'back',
#    'holiday',
#    'kids'],
#   'negative'),
#  (['whinging',
#    'client',
#    'amp',
#    'boss',
#    "n't",
#    'understand',
#    'english',
#    'well',
#    'rewrote',
#    'text',
#    'unreadable',
#    "'s",
#    'written',
#    'v.',
#    'good',
#    'writer',
#    'amp',
#    'reviewed',
#    'correctly'],
#   'negative'),
#  (["n't", 'want', 'ever', 'punch'], 'negative'),
#  (['sooo', 'sick', 'snow', 'ughh'], 'negative'),
#  (['--', '--', '--'], 'negative'),
#  (["n't", 'work', 'fan', 'upset'], 'negative'),
#  (['would',
#    'like',
#    'apologize',
#    'repeated',
#    'video',
#    'games',
#    'live',
#    'related',
#    'tweets',
#    'going',
#    'stern',
#    'discussion',
#    'koodo',
#    'soon',
#    'stern'],
#   'negative'),
#  (['cant', 'figure', 'get', 'back', 'pay', 'hotel', 'etc'], 'negative'),
#  (['fml',
#    'much',
#    'seniority',
#    'bc',
#    'technological',
#    'ineptness',
#    'quot',
#    'register',
#    'quot',
#    'classes'],
#   'negative'),
#  (['feels',
#    'like',
#    'slept',
#    'day',
#    'away',
#    'looking',
#    'forward',
#    'bouts',
#    'gallbladder',
#    'least',
#    'pills',
#    'pain'],
#   'negative'),
#  (['really', 'want', 'old', 'bass', 'back'], 'negative'),
#  (['mad',
#    'tired',
#    'today',
#    '...',
#    'callin',
#    'early',
#    'tonight',
#    'nighty',
#    'night',
#    'twittas'],
#   'negative'),
#  (['take', 'easy', 'good'], 'negative'),
#  (["'m", 'afraid', 'bad', 'code'], 'negative'),
#  (['think', "'m", 'going', 'bed', 'goodniight', 'hate'], 'negative'),
#  (["'m", 'friend', 'love'], 'negative'),
#  (['time', "n't", 'notice', 'gone', '...', 'needed', 'db2'], 'negative'),
#  (['bathroom', 'pee'], 'negative'),
#  (['wanted', 'margarita'], 'negative'),
#  (['yup',
#    'night',
#    'workouts',
#    'r',
#    'worst',
#    'unfortunetly',
#    'work',
#    'schedule',
#    'allows',
#    'go',
#    'night',
#    'tough'],
#   'negative'),
#  (['called',
#    'hillsong',
#    'said',
#    'could',
#    "n't",
#    'tell',
#    'waiting',
#    'list',
#    "n't",
#    'know',
#    "'s",
#    'looking',
#    'good'],
#   'negative'),
#  (['0g', 'milky', 'bar', 'left', 'around', '200ml', 'coke'], 'negative'),
#  (['stillllll', "n't", 'arrived'], 'negative'),
#  (['mraow',
#    'feel',
#    'like',
#    'dancing',
#    'first',
#    'art',
#    'school',
#    'wants',
#    'rape'],
#   'negative'),
#  (['ah',
#    'bet',
#    "'ve",
#    'like',
#    'craving',
#    'play',
#    'softball',
#    'basketball',
#    'noo',
#    'time'],
#   'negative'),
#  (['terrified',
#    'accidentally',
#    'deleted',
#    'reference',
#    'management',
#    'assignment',
#    'hopes',
#    'doesnt',
#    'get',
#    'trouble',
#    'gets',
#    'back'],
#   'negative'),
#  (['amazon',
#    's3',
#    'plugin',
#    'worked',
#    'website',
#    'need',
#    'php',
#    '5',
#    'hosting',
#    'provider',
#    'php',
#    '4.4',
#    'sad'],
#   'negative'),
#  (['argh',
#    'suuuper',
#    'sleepy',
#    'hour',
#    'ago',
#    "'m",
#    'wide',
#    'awake',
#    'hope',
#    "n't",
#    'stay',
#    'night',
#    '-/'],
#   'negative'),
#  (['wish', 'sold', 'time', 'let', 'know', 'would', 'love', 'hear'],
#   'negative'),
#  (['watched', 'tropic', 'thunder', 'dreading', 'tomorrow'], 'negative'),
#  (['...', "'s", 'still', 'miss', 'n', '...'], 'negative'),
#  (['chiefdelphi'], 'negative'),
#  (['according',
#    'bro',
#    'new',
#    'puppy',
#    'poo',
#    'fight',
#    'covered',
#    'poop',
#    'picture',
#    'stolen'],
#   'negative'),
#  (['playing', 'game', 'home', 'new', 'boss', "n't", 'call', 'yet', '...'],
#   'negative'),
#  (['su',
#    'yin',
#    'huen',
#    'tweeted',
#    'feel',
#    'unbearable',
#    'guilt',
#    'made',
#    'staff',
#    'cry'],
#   'negative'),
#  (['poor', 'joshy', 'sick', 'damn', 'tejanos'], 'negative'),
#  (['thoughts', 'sandra', 'cantu', "'s", 'family', 'difficult', 'sad', 'time'],
#   'negative'),
#  (['know', 'wanted', 'let', 'everybody', 'know', 'happening'], 'negative'),
#  (['michigan', "n't", 'know', '*sigh*', 'shameful'], 'negative'),
#  (['fill', 'two', 'hours'], 'negative'),
#  (['cuuute', 'hey', 'miss', 'na', 'seeing', 'girls', 'everyday'], 'negative'),
#  (['oh',
#    'mention',
#    'quot',
#    'gooooood',
#    'moooorniiiiiiing',
#    'quot',
#    'germany',
#    'im',
#    'back',
#    'cage',
#    '...',
#    '.or',
#    'better',
#    '...',
#    'office'],
#   'negative'),
#  (['throat', 'closing', 'string', 'cheese', 'good', 'idea'], 'negative'),
#  (['aww',
#    'sandra',
#    'cantu',
#    'found',
#    'dead',
#    'suitcase',
#    'missing',
#    'children',
#    'stories',
#    'never',
#    'seem',
#    'go',
#    'good',
#    'poor',
#    'family'],
#   'negative'),
#  (['wishing', 'home', 'underneath', 'covers'], 'negative'),
#  (['walking', 'home', 'school', 'drains', 'energy'], 'negative'),
#  (['agree',
#    'shapeshifting',
#    'copout',
#    'excited',
#    'angela',
#    "'s",
#    'ep',
#    'thought',
#    'week',
#    'noah',
#    'awesome',
#    'tho'],
#   'negative'),
#  (['dang', 'would', 'done', 'knew', 'earlier', 'outings', 'planned'],
#   'negative'),
#  (['wish', 'better', 'writing', "'s", 'taking', 'long', 'write', 'paper'],
#   'negative'),
#  (['..and',
#    'course',
#    '...',
#    'access',
#    'halo',
#    '3',
#    'mythic',
#    'map',
#    'pack',
#    're-download..',
#    'bad',
#    'news..',
#    'legendary',
#    'map',
#    'pack',
#    '...',
#    'ugh..',
#    '600ms',
#    '...'],
#   'negative'),
#  (['...',
#    'yet',
#    'unfortunately',
#    'another',
#    'weeks',
#    "'ve",
#    'told',
#    "'ve",
#    'little',
#    'bit',
#    'busy',
#    'latest',
#    'project'],
#   'negative'),
#  (['ha', 'sun', "'s", 'already', 'gone'], 'negative'),
#  (['day',
#    '2.',
#    'lot',
#    'harder',
#    'day',
#    '1.',
#    'let',
#    "'s",
#    'see',
#    'day',
#    '3',
#    'goes',
#    'tomorrow'],
#   'negative'),
#  (['man', 'crush', 'jake', 'peavy', 'let', 'gayforpeavy'], 'negative'),
#  (['megafast',
#    'trip',
#    'time',
#    'day',
#    'tom/weds',
#    'going',
#    'tonight',
#    'want',
#    'see',
#    'bad',
#    'tried',
#    'warn',
#    'tech',
#    'fail'],
#   'negative'),
#  (['michigan', 'state', 'make', 'sad'], 'negative'),
#  (['omg',
#    'mouth',
#    'much',
#    'pain',
#    'wan',
#    'na',
#    'sleep',
#    'untill',
#    'time',
#    'take',
#    'braces'],
#   'negative'),
#  (['getting',
#    'annoyed',
#    'easily',
#    'today',
#    'gt',
#    'gt',
#    'gt',
#    'biofuel',
#    'proposal',
#    'getting',
#    'annoyed',
#    'easily',
#    'today',
#    'gt',
#    'gt',
#    'gt',
#    'biof..'],
#   'negative'),
#  (['hey', 'girl', 'site', 'back', 'girlyvue', 'back', 'even', 'videos'],
#   'negative'),
#  (["'m",
#    'spending',
#    'time',
#    'grandma',
#    'early',
#    'tomorrow',
#    'ca',
#    "n't",
#    'leave',
#    'skittles'],
#   'negative'),
#  (['got', 'home', 'watching', 'michigan', 'state', 'get', 'tromped'],
#   'negative'),
#  (['oh',
#    'jew-bus',
#    'two',
#    'years',
#    'worth',
#    'classes',
#    'work',
#    'alot',
#    'organize',
#    'gt',
#    'lt',
#    "'m",
#    'finishing',
#    'tonight',
#    "'s",
#    'possible',
#    '...',
#    'bones',
#    'ache'],
#   'negative'),
#  (['exchanging', 'laptop', "n't", 'arrived'], 'negative'),
#  (['hope', "n't", 'last', 'long', 'feel', 'miserable'], 'negative'),
#  (['rachel',
#    'hang',
#    'outage',
#    'neccessary',
#    'gon',
#    'na',
#    'home',
#    'wekend',
#    'dumb',
#    'folk',
#    'make',
#    'work',
#    'im',
#    'free',
#    'f',
#    'sat',
#    '4',
#    '...'],
#   'negative'),
#  (['fun',
#    'amp',
#    'furious',
#    'new',
#    'mantra',
#    'bay',
#    '2',
#    'breakers',
#    'getting',
#    '2',
#    'rambunctious',
#    'city',
#    'overreacted',
#    'amp',
#    'clamped'],
#   'negative'),
#  (['hubby',
#    'reason',
#    'thinks',
#    "'s",
#    'important',
#    'good',
#    'spot',
#    'red',
#    'carpet',
#    'trek',
#    'movie',
#    'premiere',
#    'sod'],
#   'negative'),
#  (['swear',
#    'matter',
#    'long',
#    "'ve",
#    'getting',
#    '5am',
#    'never',
#    'gets',
#    'easier',
#    'man',
#    'eyes',
#    'hurts',
#    'wah'],
#   'negative'),
#  (['jeffree',
#    'keep',
#    'hair',
#    'one',
#    'color',
#    'permanent',
#    'dye',
#    'fades',
#    'within',
#    'week'],
#   'negative'),
#  (['reaction', 'whoa', "n't", 'see', 'coming'], 'negative'),
#  (['still',
#    'sick',
#    'feeling',
#    'bit',
#    'better',
#    'got',
#    'new',
#    'medicine',
#    '...',
#    'hope',
#    'feel',
#    'good',
#    'night',
#    'sleep',
#    'ohh',
#    "'s",
#    'suppose',
#    'snow',
#    'wtf'],
#   'negative'),
#  (['think',
#    'maybe',
#    'get',
#    'couple',
#    'hours',
#    'sleep',
#    'hon',
#    'productive',
#    'right',
#    'ur',
#    'dog',
#    'tired',
#    'worry'],
#   'negative'),
#  (['thanks',
#    'lot',
#    'learned',
#    'lot',
#    'new',
#    'words',
#    "n't",
#    'find',
#    'looking'],
#   'negative'),
#  (['wish',
#    'xblm',
#    'downloads',
#    'gamertag',
#    "'hitokyri",
#    '5',
#    'gamertag',
#    'thing',
#    'nonsense',
#    '...',
#    "'m",
#    'tired'],
#   'negative'),
#  (['new', 'testament', 'test', '9:30'], 'negative'),
#  (['tons', 'hay', 'troll', 'ahhhh'], 'negative'),
#  (['stupid',
#    'movies',
#    'watched',
#    '...',
#    'mirrors',
#    'ugggggh',
#    '...',
#    'stooopeeed',
#    'rip'],
#   'negative'),
#  (['love', 'buck'], 'negative'),
#  (['last', 'one', 'still', 'done'], 'negative'),
#  (['homework', '...'], 'negative'),
#  (["n't",
#    'understand',
#    'things',
#    'get',
#    'taken',
#    'away',
#    "n't",
#    'enough',
#    'time',
#    'unfair',
#    'want',
#    'back',
#    'like',
#    'baby'],
#   'negative'),
#  (['scratch',
#    'du',
#    'heif',
#    'two',
#    'half',
#    'cookies',
#    'tum',
#    'ca',
#    "n't",
#    'take',
#    'anymore',
#    'shoog',
#    'poots'],
#   'negative'),
#  (['listening',
#    'sweets',
#    'first',
#    'time',
#    'forever',
#    'miss',
#    'much',
#    'go',
#    'chi',
#    'town',
#    'visits',
#    'plz'],
#   'negative'),
#  (['geez',
#    'busy',
#    'afternoon',
#    'meetings',
#    'emails',
#    'meetings',
#    'email',
#    'meetings',
#    '6pm',
#    'day',
#    'still',
#    'going',
#    'ah',
#    'dark'],
#   'negative'),
#  (['dang',
#    'another',
#    'spring',
#    'break',
#    'cool',
#    'bad',
#    'work',
#    'week',
#    'oh',
#    'well',
#    'money',
#    'phone',
#    'ttyl',
#    'everbody'],
#   'negative'),
#  (['im', 'afraid', 'ur', 'reply', 'uni', 'ages', 'ago'], 'negative'),
#  (['feeling'], 'negative'),
#  (['lol',
#    'emotional',
#    'ass',
#    'men',
#    'omg',
#    'late',
#    'night',
#    'eating..',
#    'us',
#    'broke'],
#   'negative'),
#  (['aww', 'nick', 'like', 'hair', 'longer', 'cut', 'break', 'heart'],
#   'negative'),
#  (['wonder', 'jon', 'lost', 'net'], 'negative'),
#  (['wow',
#    'depressing',
#    'thing',
#    'world',
#    'losing',
#    'video',
#    "'ve",
#    'created',
#    'matter',
#    'seconds',
#    'fml'],
#   'negative'),
#  (['says', 'stock'], 'negative'),
#  (['lmao', 'im', 'sorry', 'poohpot', 'ate'], 'negative'),
#  (['chance', 'softbelly', "n't", 'loud'], 'negative'),
#  (['time',
#    'move',
#    'posterior',
#    'lose',
#    'fat',
#    'articulation',
#    'creaking',
#    'running',
#    'iï¿½m',
#    'drool',
#    'swimming'],
#   'negative'),
#  (['listening', 'nathan', 'cry', '...'], 'negative'),
#  (['today',
#    'sucked',
#    "'m",
#    'gon',
#    'na',
#    'die',
#    'without',
#    'chris',
#    'callum',
#    'wahhh'],
#   'negative'),
#  (['stou',
#    'site',
#    'update',
#    'info',
#    '2/2552',
#    'exam',
#    'open',
#    'course',
#    'must',
#    'wait',
#    'mail',
#    'notices',
#    'doc',
#    'um',
#    '...'],
#   'negative'),
#  (['sorry',
#    "'m",
#    'feeling',
#    'kinda',
#    'yucky',
#    '5am',
#    'going',
#    'come',
#    'quick'],
#   'negative'),
#  (['love', 'scrappy', 'missin', 'already'], 'negative'),
#  (['wants', 'hear', "'s", 'song', 'myspace', 'messing'], 'negative'),
#  (['bad',
#    'news',
#    'dad',
#    'cancer',
#    'dying',
#    'good',
#    'news',
#    'new',
#    'business',
#    'started',
#    'life',
#    'coach',
#    'practising',
#    'holistic',
#    'weight',
#    'management'],
#   'negative'),
#  (['man', '...', 'intervention', 'soo', 'sad'], 'negative'),
#  (['help', 'need', 'new', 'boyfriend', '...', "'m", 'stuck', 'rut'],
#   'negative'),
#  (['feel',
#    'like',
#    'complete',
#    'idiot',
#    "'m",
#    'one',
#    "n't",
#    'get',
#    'shit',
#    'works',
#    'help'],
#   'negative'),
#  (['saw',
#    'ad',
#    'craigslist',
#    'casting',
#    'call',
#    'female',
#    'host',
#    'g4',
#    'totally',
#    'psyched',
#    'realized',
#    'hoax'],
#   'negative'),
#  (['pepperoni',
#    'rolls',
#    'l.a.',
#    'called',
#    'valentino',
#    "'s",
#    'said',
#    'sausage',
#    'rolls',
#    'pepperoni',
#    'rolls'],
#   'negative'),
#  (['yes', "'s", 'monday'], 'negative'),
#  (['want', 'new', 'gg', 'episode', 'already'], 'negative'),
#  (['miss', 'watching', 'rocko', "'s", 'modern', 'life'], 'negative'),
#  (['rip', 'sandra', '...', '.its', 'sad', 'someone', 'something', 'like'],
#   'negative'),
#  (['keeping', 'fingers', 'crossed', 'buddy', 'feeling', 'well'], 'negative'),
#  (['wait', 'eat', 'skinny', 'vegas', "'m", 'hungry'], 'negative'),
#  (['tried', 'tweetdeck', 'hated', 'passion', 'hated', "'m", 'sure', '...'],
#   'negative'),
#  (['btw',
#    'iphone',
#    'acting',
#    'funny',
#    'dying',
#    'quickly',
#    'freezing',
#    'bs',
#    "'m",
#    'admitting',
#    'anything',
#    'sayin'],
#   'negative'),
#  (['sitting', 'wondering', 'quot', 'ed', 'quot', 'still', 'strong', 'hold'],
#   'negative'),
#  (['im', 'sorry', 'got', 'sick', 'lol', 'going', 'bed', 'night'], 'negative'),
#  (['internet', 'home', 'drive', 'ox', 'use', 'internet', 'builders'],
#   'negative'),
#  (['weather', 'canada', 'freezing'], 'negative'),
#  (['twiggassssssss', 'range', 'day', "'m", 'back', 'hopefully', 'good'],
#   'negative'),
#  ([], 'negative'),
#  (['anyone', 'reads', 'pray', 'grandma', "'s", 'pain'], 'negative'),
#  (['3',
#    'woke',
#    'accident',
#    'quot',
#    "'s",
#    'pushing',
#    "'s",
#    'pushing',
#    'quot',
#    'crying',
#    'could',
#    "n't",
#    'stop',
#    'wetting',
#    'pants'],
#   'negative'),
#  (['home',
#    'franklin',
#    'street',
#    'almost',
#    'jumped',
#    'fire',
#    'someone',
#    'kicked',
#    'could',
#    'jenny',
#    'lost',
#    'shoe'],
#   'negative'),
#  (['hey', 'changed', 'default'], 'negative'),
#  (['finally',
#    'gave',
#    'bored',
#    'enough',
#    'start',
#    'thing',
#    'think',
#    '140',
#    'going',
#    'problem',
#    'tho',
#    'like',
#    'myspace',
#    'status'],
#   'negative'),
#  (['oooonly', 'really', 'lucky', 'eh', 'awh', 'definitely', 'early', 'work'],
#   'negative'),
#  (['buttload', 'homework'], 'negative'),
#  (['needs', 'another', 'copy', 'visual', 'studio', '2008'], 'negative'),
#  (['school',
#    'world',
#    'week.my',
#    'school',
#    'silly',
#    'anyway',
#    '...',
#    'look',
#    'bright',
#    'side',
#    "'m",
#    'u'],
#   'negative'),
#  (['omg',
#    "'ve",
#    'economics',
#    'test',
#    'dont',
#    'know',
#    'things',
#    'know',
#    'omg',
#    'im',
#    'gon',
#    'na',
#    'fail'],
#   'negative'),
#  (['upon',
#    'time',
#    'hundred',
#    'islands',
#    'pride',
#    'philippine',
#    'tourism',
#    'coral/clam/rare',
#    'fish',
#    'poaching',
#    'kinda',
#    'sad'],
#   'negative'),
#  (['yeah', 'apparently', 'really', 'bad', 'taste'], 'negative'),
#  (['know',
#    'really',
#    'surprised',
#    'since',
#    'everyone',
#    'recommends',
#    'youtube',
#    'call',
#    'tomorrow',
#    'figure'],
#   'negative'),
#  (['waiting',
#    'airport',
#    'ride',
#    'get',
#    'harassed',
#    '2',
#    'men',
#    'trying',
#    'sell',
#    'ugly',
#    'hats..',
#    'want',
#    'sleep..'],
#   'negative'),
#  (['left', 'ids', 'location', 'go', 'bars', 'fuckkkkkkkkkkkkk'], 'negative'),
#  (["'m", 'sorry', "n't", 'understand', 'last', 'comment'], 'negative'),
#  (['announcement', 'stayed', 'late', 'last', 'night'], 'negative'),
#  (['strange',
#    'illegal',
#    'torrents',
#    'avlbl',
#    'everywhere',
#    'legal',
#    'dvd',
#    'stock'],
#   'negative'),
#  (['enough', 'say', 'imiss', 'u'], 'negative'),
#  (['trolley',
#    'packed',
#    'like',
#    'sardines',
#    'padre',
#    'game',
#    'remove',
#    'car',
#    'good',
#    'call',
#    'mts'],
#   'negative'),
#  (['jeez', 'trying', 'help', 'haha'], 'negative'),
#  (['happened', 'saturday', 'night', 'along', 'glittery', 'green', 'lighter'],
#   'negative'),
#  (['trying', 'reduce', 'number', 'cigarettes', 'day'], 'negative'),
#  (['yea',
#    'quiet',
#    'around',
#    'cuz',
#    'everyone',
#    'work',
#    'im',
#    'bored',
#    'death',
#    'nobody',
#    'talk'],
#   'negative'),
#  (['got', 'ta', 'cooking', 'assignment', 'hard'], 'negative'),
#  (['okay',
#    'applepears',
#    "'ve",
#    'talked',
#    'people',
#    "'ve",
#    'one',
#    'ever',
#    'told',
#    'never'],
#   'negative'),
#  (['know',
#    "'m",
#    'night',
#    'owl',
#    'nature',
#    'hahaha',
#    'time',
#    'zone',
#    'behind',
#    "'s",
#    'almost',
#    '1'],
#   'negative'),
#  (['lol', 'nope', 'complete', 'camerafail'], 'negative'),
#  (["'m", 'useless', "n't", 'sleep', "'s", 'fair', 'want', 'fun', 'well'],
#   'negative'),
#  (['pookie', 'uti', 'nurse', 'gabbie', 'get', 'back', '100', 'sodas'],
#   'negative'),
#  (['tweet', 'something', 'damn', 'hang', 'please'], 'negative'),
#  ([], 'negative'),
#  (["'m",
#    'behind',
#    'video',
#    'games',
#    'everything',
#    'matter',
#    "'m",
#    'yesterday',
#    "'s",
#    'news'],
#   'negative'),
#  (['one',
#    'left',
#    'got',
#    'tempted',
#    'ate',
#    'soon',
#    'got',
#    'home',
#    'chocolate',
#    'velvet',
#    'amp',
#    'ate',
#    'mocha'],
#   'negative'),
#  (['stressing',
#    'blackberry',
#    'keeps',
#    'flashing',
#    'red',
#    'alert',
#    'status',
#    'reason',
#    'faking',
#    'hate'],
#   'negative'),
#  (['wan', 'na', 'wear', 'doc', 'martens', "n't", 'worn', 'since', 'december'],
#   'negative'),
#  (['shoe',
#    'repair',
#    'shop',
#    'guy',
#    'could',
#    'find',
#    'shoes',
#    'go',
#    'back',
#    'see',
#    'find',
#    'couple',
#    'days'],
#   'negative'),
#  (['really', 'see', 'coming'], 'negative'),
#  (['woke',
#    'vivid',
#    'sketchy',
#    'not-cool',
#    'dreams',
#    'life',
#    'time',
#    'stare',
#    'wall',
#    'lights'],
#   'negative'),
#  (["'ll", 'take', '3', 'days', 'sister', 'get', 'passport'], 'negative'),
#  (['oh', 'yes', 'miss'], 'negative'),
#  (['uh', 'oh', '...', 'think', 'getting', 'sick'], 'negative'),
#  (['good', 'god', 'ruined', 'belly', 'button'], 'negative'),
#  (['watching', 'framed', 'roger', 'rabbit', 'makes', 'miss', 'toon', 'town'],
#   'negative'),
#  (['renting..',
#    'cheap',
#    'renting',
#    'awesome',
#    'house',
#    '3',
#    'buying',
#    'attempts',
#    'fall'],
#   'negative'),
#  (['running', 'nose', 'spinning', 'head', 'good', 'combination', 'meeting'],
#   'negative'),
#  (['negative..', 'lost', 'vote', 'confidence'], 'negative'),
#  (['nasty', 'budget', 'due', 'iphone', 'sent', 'apple', 'today'], 'negative'),
#  (['thatï¿½s', 'bad'], 'negative'),
#  (['dammit',
#    'episode',
#    '3',
#    'kings',
#    'wo',
#    "n't",
#    'play',
#    'reason',
#    'stopped',
#    'middle',
#    'wo',
#    "n't",
#    'anything'],
#   'negative'),
#  (["'m",
#    'upset',
#    'missed',
#    'chat',
#    'quiz',
#    'online',
#    'free',
#    'internet',
#    'ceased'],
#   'negative'),
#  (['ca',
#    "n't",
#    'believe',
#    "'m",
#    'disbelief',
#    'way',
#    'really',
#    'much',
#    'take',
#    'people',
#    'always',
#    'get',
#    'hurt',
#    'others'],
#   'negative'),
#  (['car', 'show', 'season', 'started', 'without'], 'negative'),
#  (['throat', 'raw'], 'negative'),
#  (["n't",
#    'get',
#    'persons',
#    'mind',
#    'could',
#    'even',
#    'ish',
#    'like',
#    'prayers',
#    'fam',
#    'real'],
#   'negative'),
#  (['hate', "n't", 'need', 'see', 'need', 'call', 'therapist'], 'negative'),
#  (['twilight', "n't", 'come', 'yesterday', 'fingers', 'crossed', 'today'],
#   'negative'),
#  (['glad', 'able', 'help', 'feel', 'better', 'hate', 'see', 'sick', 'love'],
#   'negative'),
#  (['tireddddddd',
#    'want',
#    'sleep',
#    'assignment',
#    'finish',
#    'exam',
#    'tomorrow',
#    'study'],
#   'negative'),
#  (['know', 'thinking', '...', 'need', 'money'], 'negative'),
#  (['omg..its', 'jst', 'teusday'], 'negative'),
#  (['ummmmm', 'cant', 'find'], 'negative'),
#  (['heard', 'found', 'sandra', 'cantu', '...', '8', 'yrs', 'old'], 'negative'),
#  (['ive',
#    'forgotten',
#    'snoo-snoo',
#    'wonder',
#    'snoo-snoo',
#    'ever',
#    'meet',
#    '...'],
# ...
#   'positive'),
#  (['media',
#    'trip',
#    'period',
#    'guard',
#    'minds',
#    '...',
#    'along',
#    'hearts',
#    "n't",
#    'fret',
#    'ms.badu',
#    'ur',
#    'best',
#    'true'],
#   'positive'),
#  (['ahh',
#    'tedium',
#    'fixing',
#    'broken',
#    'file',
#    'links',
#    'inventor',
#    'good',
#    'times'],
#   'positive'),
#  ([], 'positive'),
#  (['mondays', 'make'], 'positive'),
#  (['well',
#    'past',
#    'two',
#    'days',
#    '45',
#    'min',
#    'sleep',
#    "'m",
#    'going',
#    'watch',
#    'tv',
#    'laying',
#    'bed',
#    'try',
#    'sleep..',
#    'night',
#    'peepers'],
#   'positive'),
#  (["'m", 'officially', 'going', 'bed', 'goodnight'], 'positive'),
#  (['painting', 'clothes'], 'positive'),
#  (['lol', 'yet', 'brutha', 'anotha', 'mutha'], 'positive'),
#  (['ryanrossfanz', 'lt', '--', 'follow', 'ryan', 'uber'], 'positive'),
#  (['close', 'eyes', 'pick', 'one', 'hit', 'reply'], 'positive'),
#  (['connections',
#    'academy',
#    'great',
#    'family',
#    '...',
#    'thousands',
#    'across',
#    'country',
#    'happy',
#    'tell'],
#   'positive'),
#  (['hum',
#    'nice',
#    '1',
#    'lol',
#    'take',
#    'something..lol',
#    'yeah',
#    'party',
#    'haha',
#    'u',
#    'kno',
#    'drunk',
#    'ass',
#    "'s",
#    'b',
#    'seeing',
#    'janets',
#    'party'],
#   'positive'),
#  (['nightcard',
#    'star',
#    'wonderful',
#    'card',
#    'new',
#    'beginning',
#    'ankie',
#    '1.0',
#    'welcome'],
#   'positive'),
#  (['loves',
#    'german',
#    'bakeries',
#    'sydney',
#    'together',
#    'imported',
#    'honey',
#    'feels',
#    'like',
#    'home'],
#   'positive'),
#  (["'m", 'uncle'], 'positive'),
#  (['levon', '...', 'could', "n't", 'said', 'better', 'self'], 'positive'),
#  (['change',
#    'name',
#    'qoosfr',
#    'queen',
#    'obscure',
#    'science',
#    'fiction',
#    'references',
#    'instead',
#    'cbn2',
#    '1',
#    'person',
#    'understands'],
#   'positive'),
#  (['picnic', 'fabulous'], 'positive'),
#  (['welcome', 'back', 'nyc'], 'positive'),
#  (['sorry', 'talking', 'best', 'friend..', 'havent', 'replied', 'talk'],
#   'positive'),
#  (['oh', 'ok', 'gon', 'na', 'go', 'buy', 'one', 'come'], 'positive'),
#  (['tafe', 'quiz', 'photoshoot', 'sezdawg'], 'positive'),
#  (['good', 'luck', 'challenge'], 'positive'),
#  (['oh', 'oh', 'found', 'clothes', 'love', 'em', 'xd'], 'positive'),
#  (['rocking', 'doubt', 'gon', 'na', 'start', 'neverwinter', 'nights'],
#   'positive'),
#  (['phew', 'hair', 'gyal'], 'positive'),
#  (['keepin', 'real'], 'positive'),
#  (['lt', '--', '--', '--', 'branded'], 'positive'),
#  (["'m", 'adding', 'fellow', 'pfers', 'nice', 'see', 'many', 'us'],
#   'positive'),
#  (['good',
#    'time',
#    'eat',
#    'n',
#    'park',
#    'drinking',
#    'latte',
#    'playing',
#    'munchkin',
#    'impossible'],
#   'positive'),
#  (["'m", 'sure', 'site'], 'positive'),
#  (['good', 'luck', 'cruise', 'gon', 'na', 'need'], 'positive'),
#  (['well',
#    "'m",
#    'whatever',
#    'neighbor',
#    'tells',
#    'us',
#    'produces',
#    'vegetables',
#    "'m",
#    'cooking'],
#   'positive'),
#  (['hi', 'cel', 'today'], 'positive'),
#  (['goooooood', 'morning', 'chubbx', 'today'], 'positive'),
#  (["n't", 'blame', 'like', 'good', 'things'], 'positive'),
#  (['okay', 'think', 'little', 'oven', 'wednesday', '7-9pm'], 'positive'),
#  (["'s", 'excellent', 'lotsa', 'people', 'loving', 'hehe', '*winks*'],
#   'positive'),
#  (["'s",
#    'odd',
#    'little',
#    'thing',
#    "n't",
#    "'is",
#    'another',
#    'planet',
#    '...',
#    'think',
#    'like'],
#   'positive'),
#  (['amidst',
#    'recession',
#    'talks',
#    'friend',
#    'told',
#    'yesterday',
#    'got',
#    'pay',
#    'hike',
#    'sure',
#    'nice',
#    'hear'],
#   'positive'),
#  (['using', 'windows', 'tweetdeck', '...', 'temporarily', '...'], 'positive'),
#  (['joined',
#    'shoedazzle',
#    'society',
#    'excited',
#    'ca',
#    "n't",
#    'wait',
#    'shoe',
#    'selection',
#    'link'],
#   'positive'),
#  (['know',
#    'made',
#    'taken',
#    'meetings',
#    'amp',
#    'foreseen',
#    'sister',
#    'going',
#    '2',
#    'pick',
#    'stray'],
#   'positive'),
#  (['direct', 'message', 'us/me/all', 'us', '...', 'whatever', 'want'],
#   'positive'),
#  ([], 'positive'),
#  (['week',
#    '2',
#    'fitness',
#    'challenge',
#    "'m",
#    'starting',
#    'strong',
#    'submitted',
#    'stats',
#    'night',
#    'ai',
#    "n't",
#    'bad'],
#   'positive'),
#  (['following', 'reason', '...', '..'], 'positive'),
#  (['missed',
#    'twitter',
#    'ym',
#    'multiply',
#    'pet',
#    'society',
#    "n't",
#    'able',
#    'use',
#    'internet',
#    'quite',
#    'busy',
#    'past',
#    'days'],
#   'positive'),
#  (['juz',
#    'watchin',
#    '3',
#    'eps',
#    'show',
#    'hm',
#    'must',
#    'say',
#    'instantly',
#    'became',
#    'fan',
#    'urs',
#    'lovin',
#    'ur',
#    'humor',
#    'mucho',
#    'power',
#    '2',
#    'u'],
#   'positive'),
#  (['new',
#    'background',
#    "n't",
#    'exactly',
#    'work',
#    'wanted',
#    'bored',
#    'old',
#    'one'],
#   'positive'),
#  (['paragon', 'please', 'vote', 'work', 'lol'], 'positive'),
#  (['keep',
#    'forgetting',
#    'different',
#    'time',
#    'zone',
#    'normal',
#    'see',
#    "'tweets",
#    'morning',
#    "'s",
#    '10:45pm'],
#   'positive'),
#  (['example',
#    'animation',
#    'mean',
#    'youtube',
#    'video',
#    'something',
#    "'m",
#    'curious',
#    'see',
#    'work',
#    'snowing'],
#   'positive'),
#  (['need', 'invite', 'hunch'], 'positive'),
#  (['thought', 'mac'], 'positive'),
#  (['maybe', 'jordan', 'could', 'help', 'answer', 'idea..'], 'positive'),
#  (['finally',
#    'made',
#    'map',
#    'panama',
#    'quot',
#    "'s",
#    'panama',
#    'like',
#    'animal',
#    'quot',
#    'haha',
#    'love',
#    'friends'],
#   'positive'),
#  ([], 'positive'),
#  (['gladly',
#    'give',
#    'squirrel',
#    'jenny',
#    "'s",
#    'house',
#    'join',
#    'us',
#    'squirrel',
#    "'ll",
#    'kill',
#    'two',
#    'birds',
#    'one',
#    'stone'],
#   'positive'),
#  (['got',
#    'vocals',
#    'done',
#    'time',
#    'best',
#    'part',
#    'music',
#    'track',
#    'bed',
#    'whichever',
#    'wan',
#    'na',
#    'call',
#    'lol'],
#   'positive'),
#  (['part',
#    'friend',
#    "'s",
#    'wedding',
#    'entourage',
#    'tagalog',
#    'abay',
#    'sa',
#    'kasal',
#    "'ll",
#    'carrying',
#    'veil',
#    'thanks',
#    'mau'],
#   'positive'),
#  (["'s",
#    'weather',
#    'petal',
#    "n't",
#    'sweat',
#    '...',
#    'oh',
#    '...',
#    '...',
#    'sorry',
#    '...'],
#   'positive'),
#  (['hey', 'today'], 'positive'),
#  (['whoops',
#    'sorry',
#    'anyone',
#    'trying',
#    'email',
#    'earlier',
#    'today',
#    'inbox',
#    'full',
#    'empty'],
#   'positive'),
#  (['lol',
#    'wasnt',
#    'complaining',
#    'making',
#    'sure',
#    'wasnt',
#    'getting',
#    'cleared'],
#   'positive'),
#  (['one', 'freaky', 'movie', 'like', 'quot', 'got', 'life', 'quot'],
#   'positive'),
#  (['megan', 'hanging'], 'positive'),
#  (['going', 'bed', 'early', 'prep', 'interview', 'cleveland', 'tomorrow'],
#   'positive'),
#  (['healthy', 'remedy', 'dog', 'dogs'], 'positive'),
#  (['sick', 'soma', 'rocks'], 'positive'),
#  (['yep..lol', 'bored', '...', 'edward', 'hunting', 'guys..'], 'positive'),
#  (['heyyyyyyyyyyy'], 'positive'),
#  (['studying',
#    'philosophy',
#    'math',
#    '...',
#    'lt',
#    '--',
#    '--',
#    'blah',
#    'aka',
#    'listening',
#    'music',
#    'twitter',
#    'facebook',
#    'myspace'],
#   'positive'),
#  (['way',
#    'earth',
#    'answer',
#    'everyone',
#    'ask',
#    'donnie',
#    'got',
#    'gift',
#    '9',
#    'yr',
#    'old',
#    'lastnight'],
#   'positive'),
#  (['psp', 'browser', 'first', 'time', 'year'], 'positive'),
#  (['good', 'luck'], 'positive'),
#  (['glad', 'angels', 'first', 'game', 'season'], 'positive'),
#  (['absolutely', 'doubt', "'s", 'continued', 'success'], 'positive'),
#  (['another', 'day', 'office', '...', '2', 'days', 'go'], 'positive'),
#  (['nice', 'yeah', 'wish', 'could', 'afford', 'things'], 'positive'),
#  (['want', 'see', "'ll", 'take', 'long', 'get', '800', 'friends..'],
#   'positive'),
#  (['uploading',
#    'greatest',
#    'cartoon',
#    'newspaper',
#    'ever',
#    'regarding',
#    'twitter'],
#   'positive'),
#  (['glad', 'liked', 'henry', 'ford', 'good', 'idea', 'every', "n't"],
#   'positive'),
#  (['studying', 'friends', "'s", 'update'], 'positive'),
#  (['im', 'glad', 'everythings', 'going', 'good', 'guys'], 'positive'),
#  (["n't", 'worry', 'happy'], 'positive'),
#  (["'ll",
#    'get',
#    'stuff',
#    'fr',
#    'uk/japan',
#    "'m",
#    'desperate',
#    'enough',
#    'headphones',
#    'us',
#    'might',
#    'jac',
#    'tita',
#    'slow'],
#   'positive'),
#  (['would',
#    "n't",
#    'happen',
#    'still',
#    'nyc',
#    'gigs',
#    'friday',
#    'saturday',
#    'next',
#    'week'],
#   'positive'),
#  (['ty',
#    'soon',
#    'upload',
#    'emmylou',
#    'harris',
#    'ï¿½',
#    "'ll",
#    'baby',
#    'tonight',
#    'gr8fl'],
#   'positive'),
#  (['cheeck',
#    'thiss',
#    'hand',
#    'cuz',
#    'im',
#    'marvelous',
#    'boy..',
#    'idk',
#    'hoow',
#    'im',
#    'gona',
#    'make',
#    'threw',
#    'weeeek'],
#   'positive'),
#  (['watching',
#    'seven',
#    'pounds',
#    'mom',
#    'hope',
#    'dont',
#    'fall',
#    'asleep',
#    'aftermidnightproject',
#    'tomorrow'],
#   'positive'),
#  (['awesome', 'home', 'work', 'around', '430', 'take', 'puppy', 'capones'],
#   'positive'),
#  (['photo', 'vegas'], 'positive'),
#  (['yeah', 'opening', 'day'], 'positive'),
#  (['feel',
#    'hate',
#    'working',
#    'results',
#    'major',
#    'look',
#    'good',
#    'feel',
#    'good'],
#   'positive'),
#  (["'s", 'al', 'team'], 'positive'),
#  (['really', 'good', 'day', 'shoppping'], 'positive'),
#  (['ok..i', '...', 'hope', 'works'], 'positive'),
#  (['good', 'night', 'sweet', 'dreamz'], 'positive'),
#  (['hope', 'scentsational', "n't", 'get', 'dissed'], 'positive'),
#  (['invite', 'people', 'twitter'], 'positive'),
#  (['coming',
#    'soon',
#    'enough',
#    'friends',
#    'big',
#    'project',
#    'works',
#    'good',
#    'new',
#    'good',
#    'news'],
#   'positive'),
#  (['woohoo', 'yeah', 'day', 'rockin', 'hard', 'core'], 'positive'),
#  (['hey', 'jon', 'love', 'ya', 'understand', "'s", 'counts'], 'positive'),
#  (['internship',
#    'yet',
#    'ive',
#    'got',
#    'place',
#    'stay',
#    'w/',
#    'luck',
#    "'ll",
#    'spend',
#    'time',
#    'teaneck',
#    'heading',
#    'back',
#    'utah'],
#   'positive'),
#  (['make', 'bed', 'without', 'running', 'wall', 'tripping', 'feet', 'heh'],
#   'positive'),
#  (['yes', 'using', '3', 'week', 'pretty', 'happy', 'result'], 'positive'),
#  (['exactly'], 'positive'),
#  (['wonder', 'long', 'stay', 'pass', 'wake', '6'], 'positive'),
#  (['great',
#    'words',
#    'wisdom',
#    'd-dub',
#    'tell',
#    'doctor',
#    'let',
#    'alcohol',
#    'amp',
#    'caffeine'],
#   'positive'),
#  (['good', 'knight', 'sleep', 'well', 'know'], 'positive'),
#  (['exhausted', 'glad', 'got', 'see', 'unc', 'become', 'national', 'champs'],
#   'positive'),
#  (['centrelink', 'wasnt', 'bad', 'thought', 'going'], 'positive'),
#  (['would', "n't", 'want', 'way'], 'positive'),
#  (['hella', 'excited', 'cuz', 'italian'], 'positive'),
#  (['love',
#    'access',
#    'research',
#    'machine',
#    '4',
#    'quad',
#    'core',
#    '64',
#    'bit',
#    'opterons',
#    '60',
#    'gigs',
#    'ram'],
#   'positive'),
#  (['quick', 'exhausting', '1', 'day', 'time'], 'positive'),
#  (['jasmine', 'bohdi', 'holidays'], 'positive'),
#  (["'m",
#    'good',
#    'strange',
#    'dreams',
#    'last',
#    'night',
#    'hey',
#    'dreamin',
#    'means',
#    "'m",
#    'sleepin',
#    "'s",
#    'morning'],
#   'positive'),
#  (['going', 'outside', 'jump', 'trampoine', 'wooot'], 'positive'),
#  (['today',
#    'rad',
#    'made',
#    'finals',
#    'cross',
#    'country',
#    'yay',
#    'love',
#    'sophie',
#    'lt',
#    '3',
#    'l',
#    'ps',
#    'everythins',
#    'cool',
#    'mates'],
#   'positive'),
#  (['lol', 'thinking', 'thing'], 'positive'),
#  (["n't",
#    'feel',
#    'pressured',
#    'none',
#    'us',
#    'expect',
#    'reply',
#    'back',
#    "'re",
#    'happy',
#    'able',
#    'listen',
#    'talk'],
#   'positive'),
#  (['oh',
#    'quot',
#    'shooter',
#    'quot',
#    'good',
#    'movie',
#    'seen',
#    'tho',
#    'got',
#    'ta',
#    'put',
#    'back',
#    'quot',
#    'watch',
#    'quot',
#    'list'],
#   'positive'),
#  (['tell',
#    'u',
#    'spoken',
#    'fb',
#    'amp',
#    'twitter',
#    'fire',
#    'right',
#    'hope',
#    'ur',
#    'feelin',
#    'better',
#    'love',
#    'great',
#    'night',
#    '...'],
#   'positive'),
#  (['hate',
#    'morn',
#    'workouts',
#    'bc',
#    'love',
#    'sleep',
#    'late',
#    'ha',
#    'fun',
#    'mexico',
#    'love',
#    'show',
#    'trip',
#    'gon',
#    'na',
#    'air',
#    'keeping'],
#   'positive'),
#  (["'m",
#    'feeling',
#    'somewhat',
#    'artistic',
#    '...',
#    'time',
#    'break',
#    'sketching',
#    'pad',
#    'feel',
#    'new',
#    'dress',
#    'design',
#    'coming'],
#   'positive'),
#  (['go', 'mary', "'s", 'listening'], 'positive'),
#  ([], 'positive'),
#  (['nodame',
#    'cantabile',
#    'lt',
#    '3.',
#    'think',
#    "'m",
#    'falling',
#    'love',
#    'classical',
#    'music'],
#   'positive'),
#  (['...',
#    'ordered',
#    'copy',
#    'hardcore',
#    'underground',
#    '3',
#    'love',
#    'love',
#    'canary',
#    'skinny',
#    'jeans',
#    'going',
#    'balls',
#    'deep'],
#   'positive'),
#  (['amp',
#    'dinner',
#    'menu',
#    'week',
#    'something',
#    'pasta-y',
#    'cheese',
#    'also',
#    'chicken',
#    'noodle',
#    'soup'],
#   'positive'),
#  (['new', 'jersey', 'come'], 'positive'),
#  (['facebook'], 'positive'),
#  (['good',
#    'point',
#    '2',
#    'draw',
#    '2',
#    "n't",
#    'nice',
#    'quote',
#    'though',
#    'like'],
#   'positive'),
#  (['goodnight'], 'positive'),
#  (['lead', 'cross', 'one', 'favorites', 'great', 'job'], 'positive'),
#  (['got',
#    'back',
#    'starbucks..',
#    'tried',
#    'tea',
#    'lemonade',
#    'good',
#    'miss',
#    'gg',
#    'already',
#    '1st',
#    'one'],
#   'positive'),
#  (['boom', 'boom', 'pow-oops'], 'positive'),
#  (['super', 'red', 'diva', 'stupid', 'university'], 'positive'),
#  (['latest', 'episode', 'newnownext', 'like', 'full', 'awesome'], 'positive'),
#  (['want',
#    'things',
#    'end',
#    'remember',
#    'faith',
#    'one',
#    'day',
#    "'s",
#    'going',
#    'alright'],
#   'positive'),
#  (['pbnjen',
#    'thanks',
#    'great',
#    'tour',
#    'making',
#    'even',
#    'excited',
#    'work',
#    'pr',
#    'rock',
#    'amp',
#    'b-would',
#    'love',
#    'work'],
#   'positive'),
#  (['give', 'joy', '...', '.and', 'years', 'amazing', 'man', 'lucky', 'know'],
#   'positive'),
#  (['check', "n't", 'dictionary', 'visual', 'vocabulary', 'come', 'fun'],
#   'positive'),
#  (['artistic', 'affirmation', 'drunk', 'lady', 'kinda', 'needed'], 'positive'),
#  (['honey',
#    'goodnight',
#    'really',
#    'early',
#    'morning',
#    'busy',
#    'day',
#    'catch',
#    'later',
#    'tomorrow'],
#   'positive'),
#  (['je',
#    'kakï¿½en',
#    'rip',
#    'od',
#    'trenutek',
#    'resnice',
#    'link',
#    'link',
#    'link'],
#   'positive'),
#  (['lamb',
#    'chowmein',
#    'dinner',
#    'tonight',
#    '...',
#    'hhhmmm',
#    'slightly',
#    'roasted',
#    'buttered',
#    'dinner',
#    'rolls',
#    'yum',
#    'yum',
#    'yum',
#    '...',
#    'hungry'],
#   'positive'),
#  (['tweeting', 'brand', 'new', 'sony', 'psp', '...'], 'positive'),
#  (['hey',
#    'go',
#    'tour',
#    'sometime',
#    'brother',
#    'metro',
#    'station',
#    'freakin',
#    'awesome'],
#   'positive'),
#  (['well',
#    'tweeps',
#    'im',
#    'got',
#    'ta',
#    'shower',
#    'go',
#    'get',
#    'haircut',
#    'good',
#    'bye',
#    'everyone'],
#   'positive'),
#  (["'ve",
#    'seen',
#    'flickr',
#    "'ve",
#    'fallen',
#    'love',
#    'wonderful',
#    'awesome',
#    '...'],
#   'positive'),
#  (['sorry', "n't", 'wrath', 'khan', 'made'], 'positive'),
#  (['juggernaut',
#    'dr.',
#    'doom',
#    'magneto',
#    'amp',
#    'xavier',
#    'ahahah',
#    'today',
#    'good',
#    'day',
#    'n__n'],
#   'positive'),
#  (["'ll",
#    'geek',
#    'next',
#    'time',
#    'tahoe',
#    'need',
#    'get',
#    'miss',
#    'vicky',
#    'jay',
#    'reciting',
#    'star',
#    'wars'],
#   'positive'),
#  (['aww', 'dont', 'make', 'blush'], 'positive'),
#  (['trying', 'figure', 'thing'], 'positive'),
#  (['watching', 'quot', 'princess', 'bride', 'quot', 'want', 'wesley'],
#   'positive'),
#  (['buy', 'fiances', 'duplex', 'terwillegar'], 'positive'),
#  (['could',
#    'really',
#    'eat',
#    'cheese',
#    'hankering',
#    'austrian',
#    'smoked',
#    'cheese',
#    'yum'],
#   'positive'),
#  (['fucking', 'jealous', 'girl', 'fun', 'though', 'xxx'], 'positive'),
#  (['bunnys', 'name', 'lucy', 'go', 'ahead', 'guess', 'named', 'lmao'],
#   'positive'),
#  (['updates', 'iphone', 'os', '3.0', 'yet', 'miss', 'guys'], 'positive'),
#  (['denise', 'love'], 'positive')]

# %%
# Process Test Set
preprocessedTestSet = tweetProcessor.processTweets(test_ls)

# %%
import nltk 

def buildVocabulary(preprocessedTrainingData):
    all_words = []
    
    for (words, sentiment) in preprocessedTrainingData:
        all_words.extend(words)

    wordlist = nltk.FreqDist(all_words)
    word_features = wordlist.keys()
    
    return word_features

# %%
def extract_features(tweet):
    tweet_words = set(tweet)
    features = {}
    for word in word_features:
        features['contains(%s)' % word] = (word in tweet_words)
    return features

# %%
word_features = buildVocabulary(preprocessedTrainingSet)
trainingFeatures = nltk.classify.apply_features(extract_features, preprocessedTrainingSet)

# %%
trainingFeatures
# Out:
# [({'contains(awww)': True, "contains('s)": True, 'contains(bummer)': True, 'contains(shoulda)': True, 'contains(got)': True, 'contains(david)': True, 'contains(carr)': True, 'contains(third)': True, 'contains(day)': True, 'contains(upset)': False, 'contains(ca)': False, "contains(n't)": False, 'contains(update)': False, 'contains(facebook)': False, 'contains(texting)': False, 'contains(...)': False, 'contains(might)': False, 'contains(cry)': False, 'contains(result)': False, 'contains(school)': False, 'contains(today)': False, 'contains(also)': False, 'contains(blah)': False, 'contains(dived)': False, 'contains(many)': False, 'contains(times)': False, 'contains(ball)': False, 'contains(managed)': False, 'contains(save)': False, 'contains(50)': False, 'contains(rest)': False, 'contains(go)': False, 'contains(bounds)': False, 'contains(whole)': False, 'contains(body)': False, 'contains(feels)': False, 'contains(itchy)': False, 'contains(like)': False, 'contains(fire)': False, 'contains(behaving)': False, "contains('m)": False, 'contains(mad)': False, 'contains(see)': False, 'contains(crew)': False, 'contains(need)': False, 'contains(hug)': False, 'contains(hey)': False, 'contains(long)': False, 'contains(time)': False, 'contains(yes..)': False, 'contains(rains)': False, 'contains(bit)': False, 'contains(lol)': False, 'contains(fine)': False, 'contains(thanks)': False, 'contains(nope)': False, 'contains(que)': False, 'contains(muera)': False, 'contains(spring)': False, 'contains(break)': False, 'contains(plain)': False, 'contains(city)': False, 'contains(snowing)': False, 'contains(re-pierced)': False, 'contains(ears)': False, 'contains(could)': False, 'contains(bear)': False, 'contains(watch)': False, 'contains(thought)': False, 'contains(ua)': False, 'contains(loss)': False, 'contains(embarrassing)': False, 'contains(counts)': False, 'contains(idk)': False, 'contains(either)': False, 'contains(never)': False, 'contains(talk)': False, 'contains(anymore)': False, 'contains(would)': False, "contains('ve)": False, 'contains(first)': False, 'contains(gun)': False, 'contains(really)': False, 'contains(though)': False, 'contains(zac)': False, 'contains(snyder)': False, 'contains(doucheclown)': False, 'contains(wish)': False, 'contains(miss)': False, 'contains(premiere)': False, 'contains(hollis)': False, 'contains(death)': False, 'contains(scene)': False, 'contains(hurt)': False, 'contains(severely)': False, 'contains(film)': False, 'contains(wry)': False, 'contains(directors)': False, 'contains(cut)': False, 'contains(file)': False, 'contains(taxes)': False, 'contains(ahh)': False, 'contains(ive)': False, 'contains(always)': False, 'contains(wanted)': False, 'contains(rent)': False, 'contains(love)': False, 'contains(soundtrack)': False, 'contains(oh)': False, 'contains(dear)': False, 'contains(drinking)': False, 'contains(forgotten)': False, 'contains(table)': False, 'contains(drinks)': False, 'contains(get)': False, 'contains(much)': False, 'contains(done)': False, 'contains(one)': False, 'contains(friend)': False, 'contains(called)': False, 'contains(asked)': False, 'contains(meet)': False, 'contains(mid)': False, 'contains(valley)': False, 'contains(*sigh*)': False, 'contains(baked)': False, 'contains(cake)': False, 'contains(ated)': False, 'contains(week)': False, 'contains(going)': False, 'contains(hoped)': False, 'contains(blagh)': False, 'contains(class)': False, 'contains(8)': False, 'contains(tomorrow)': False, 'contains(hate)': False, 'contains(call)': False, 'contains(wake)': False, 'contains(people)': False, 'contains(sleep)': False, 'contains(watching)': False, 'contains(marley)': False, 'contains(im)': False, 'contains(sad)': False, 'contains(miss.lilly)': False, 'contains(ooooh)': False, 'contains(leslie)': False, 'contains(ok)': False, 'contains(wo)': False, 'contains(meh)': False, 'contains(almost)': False, 'contains(lover)': False, 'contains(exception)': False, 'contains(track)': False, 'contains(gets)': False, 'co ...

# %%
DT_Classifier = nltk.classify.DecisionTreeClassifier.train(trainingFeatures, entropy_cutoff=0,support_cutoff=0)

# %%
DTResultLabels = [DT_Classifier.classify(extract_features(tweet[0])) for tweet in preprocessedTestSet]

# %%
DTResultLabels
# Out:
# ['positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative']

# %%
NBayesClassifier = nltk.NaiveBayesClassifier.train(trainingFeatures)

# %%
# Save Pickle
import pickle
save_classifier = open("dt_train_1k.pickle","wb")
pickle.dump(DT_Classifier, save_classifier)
save_classifier.close()

# %%
# Load Pickle
import pickle
classifier_f = open("dt_train_100k.pickle", "rb")
classifier = pickle.load(classifier_f)
classifier_f.close()

# %%
NBResultLabels = [NBayesClassifier.classify(extract_features(tweet[0])) for tweet in preprocessedTestSet]

# get the majority vote
if NBResultLabels.count('positive') > NBResultLabels.count('negative'):
    print("Overall Positive Sentiment")
    print("Positive Sentiment Percentage = " + str(100*NBResultLabels.count('positive')/len(NBResultLabels)) + "%")
else: 
    print("Overall Negative Sentiment")
    print("Negative Sentiment Percentage = " + str(100*NBResultLabels.count('negative')/len(NBResultLabels)) + "%")

# %%
NBResultLabelsPickle = [classifier.classify(extract_features(tweet[0])) for tweet in preprocessedTestSet]

# get the majority vote
if NBResultLabelsPickle.count('positive') > NBResultLabelsPickle.count('negative'):
    print("Overall Positive Sentiment")
    print("Positive Sentiment Percentage = " + str(100*NBResultLabelsPickle.count('positive')/len(NBResultLabelsPickle)) + "%")
else: 
    print("Overall Negative Sentiment")
    print("Negative Sentiment Percentage = " + str(100*NBResultLabelsPickle.count('negative')/len(NBResultLabelsPickle)) + "%")

# %%
for tweet in preprocessedTestSet:
    print(tweet[0])

# %%
test_list_text = [test['text'] for test in test_ls]
# convert twitter time output to real time output
# test_list_time = [time.strftime('%Y-%m-%d %H:%M:%S', time.strptime(test['time'],'%a %b %d %H:%M:%S +0000 %Y')) 
# for test in testDataSet]

# %%
output_list = pd.DataFrame(
    {'Tweet': test_list_text,
#      'Time': test_list_time,
     'Result': DTResultLabels
    })

# %%
output_list

# %%
output_list.to_csv('./outputDT.csv',header=True)
