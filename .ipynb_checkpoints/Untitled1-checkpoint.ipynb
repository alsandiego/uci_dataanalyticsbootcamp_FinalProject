# %%
import twitter
import os
from config import *

# initialize api instance
twitter_api = twitter.Api(consumer_key=consumer_key,
                         consumer_secret=consumer_secret,
                         access_token_key=access_token_key,
                         access_token_secret=access_token_secret)

#print(consumer_key,consumer_secret,access_token_key,access_token_secret)

# test authentication
print(twitter_api.VerifyCredentials())
# print(twitter_api.GetStatus(126402758403305000))
# Out:
# {"created_at": "Wed Jul 20 02:34:27 +0000 2016", "description": "I am Al and I am passionate about technology.", "followers_count": 5, "friends_count": 52, "id": 755591669194514432, "id_str": "755591669194514432", "location": "Tustin, CA", "name": "Al", "profile_background_color": "000000", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "profile_banner_url": "https://pbs.twimg.com/profile_banners/755591669194514432/1469041661", "profile_image_url": "http://pbs.twimg.com/profile_images/755843006062694401/2JikSpJq_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/755843006062694401/2JikSpJq_normal.jpg", "profile_link_color": "1B95E0", "profile_sidebar_border_color": "000000", "profile_sidebar_fill_color": "000000", "profile_text_color": "000000", "screen_name": "alknowstech", "status": {"created_at": "Mon Jul 31 21:38:46 +0000 2017", "favorite_count": 1, "id": 892137484921978880, "id_str": "892137484921978880", "in_reply_to_screen_name": "TechYESCity", "in_reply_to_status_id": 891577872384638976, "in_reply_to_user_id": 1021097054, "lang": "en", "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>", "text": "@TechYESCity thanks for the reply.. is it stable enough to OC to 4ghz on 1700? i plan to use AIO cpu cooler"}, "statuses_count": 5}

# %%
def buildTestSet(search_keyword):
    try:
        tweets_fetched = twitter_api.GetSearch(search_keyword, count = 100)
        
        print("Fetched " + str(len(tweets_fetched)) + " tweets for the term " + search_keyword)
        
        return [{"text":status.text, "label":None} for status in tweets_fetched]
    except:
        print("Unfortunately, something went wrong..")
        return None

# %%
# test search function
search_term = input("Enter a search keyword:")
testDataSet = buildTestSet(search_term)

print(testDataSet[0:10])
# Out:
# Enter a search keyword:google
# Fetched 100 tweets for the term google
# [{'text': 'Are we still pretending that Joe Biden hasn’t lost his marbles? \n\nDo yourselves and Google a video of him from 30 y… https://t.co/IMpcYnQZy7', 'label': None}, {'text': 'Se você jogar no Google Imagens, “Torta de Climão” aparece essa foto #BBB20 https://t.co/RgMXottjVK', 'label': None}, {'text': 'We want you…to vote for #PokemonOfTheYear!\n\nYou’ve got until February 14 to head over to @Google and vote for your… https://t.co/zvA2UdhxML', 'label': None}, {'text': 'RT @kkokka_: #RT 추첨 랜덤 스티커팩 보내드려요 😊\n\n💖 랜덤 스티커팩 판매를 시작합니다 💖\n\n1 set = 배미포 1000 💸\n스티커팩 가격대 : 1000~ 2000 ✨\n\n도안 선택이 불가능한 대신 \n뭘 해도 이득인 조건 ❗️\n\n재고…', 'label': None}, {'text': 'RT @ACESTheWarrior: The wait is over!\nHere are the merchandises for the Engineering Week 2020. Prices are in the photos. To avail, click th…', 'label': None}, {'text': 'RT @Poynter: A new tool from @muckrack — it works just like Google Trends, except for news articles. \n\nhttps://t.co/H16GGGi0Ou', 'label': None}, {'text': 'New: Sunday WEEKLY Plan w Me | meal prep, workouts, inside my google calendar. Check it out! https://t.co/2iRwYgcWl4', 'label': None}, {'text': 'RT @luminous941224: 😁😆喜喜樂樂 𝙘𝙝𝙚𝙚𝙧𝙞𝙣𝙜 𝙠𝙞𝙩\n➖\n\n ✔️선입금 기간 ~ 02/14\n ✔️전체입금 기간 ~ 02/26\n  ✔배송 3월 초 \n\n 이 글을 rt 해주시는 3분을 추첨하여 슬로건을 드립니다☺ \n\n자세한 공지 및 입…', 'label': None}, {'text': 'RT @paranormal_2ch: Googleアースで、凄いの見つけてしまった… https://t.co/LkLVVCAvZF', 'label': None}, {'text': 'RT @rtwlz: This guy walked a wagon full of phones around Berlin and created traffic jams on Google Maps https://t.co/5PRO8Y89yO', 'label': None}]

# %% [markdown]
# # Start preprocessing of training data

# %%
import pandas as pd
import numpy as np

traindata140 = os.path.join(".","trainingandtestdata_sentiment140","training.csv")
testdata140 = os.path.join(".","trainingandtestdata_sentiment140","test.csv")

# %%
#read the csv file command
train_df = pd.read_csv(traindata140, header=None, usecols=[0,5], names=['polarity of the tweet','text'], encoding="ISO-8859-1")

# %%
test_df = pd.read_csv(testdata140, header=None, usecols=[0,5],
                      names=['polarity of the tweet', 'text'],encoding="ISO-8859-1")
conditions_test = [
    (test_df['polarity of the tweet'] == 0),
    (test_df['polarity of the tweet'] == 2),
    (test_df['polarity of the tweet'] == 4)]
choices_test = ['negative', 'neutral', 'positive']
test_df['label'] = np.select(conditions_test, choices_test)
test_df.head()
# Out:
#    polarity of the tweet                                               text  \
# 0                      4  @stellargirl I loooooooovvvvvveee my Kindle2. ...
# 1                      4  Reading my kindle2...  Love it... Lee childs i...
# 2                      4  Ok, first assesment of the #kindle2 ...it fuck...
# 3                      4  @kenburbary You'll love your Kindle2. I've had...
# 4                      4  @mikefish  Fair enough. But i have the Kindle2...
#
#       label
# 0  positive
# 1  positive
# 2  positive
# 3  positive
# 4  positive

# %%
test_ls = test_df.to_dict('records')

# %%
train_df.head()
# (0 = negative, 2 = neutral, 4 = positive)
# Out:
#    polarity of the tweet                                               text
# 0                      0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1                      0  is upset that he can't update his Facebook by ...
# 2                      0  @Kenichan I dived many times for the ball. Man...
# 3                      0    my whole body feels itchy and like its on fire
# 4                      0  @nationwideclass no, it's not behaving at all....

# %%
train_df.groupby('polarity of the tweet').count()
# Out:
#                          text
# polarity of the tweet
# 0                      800000
# 4                      800000

# %%
train_df_filtered = train_df[train_df['polarity of the tweet'].isin([0, 4])]
train_df_filtered.head()
# Out:
#    polarity of the tweet                                               text
# 0                      0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1                      0  is upset that he can't update his Facebook by ...
# 2                      0  @Kenichan I dived many times for the ball. Man...
# 3                      0    my whole body feels itchy and like its on fire
# 4                      0  @nationwideclass no, it's not behaving at all....

# %%
train_df_filtered.groupby('polarity of the tweet').count()
# Out:
#                          text
# polarity of the tweet
# 0                      800000
# 4                      800000

# %%
conditions_filtered = [
    (train_df_filtered['polarity of the tweet'] == 0),
    (train_df_filtered['polarity of the tweet'] == 2),
    (train_df_filtered['polarity of the tweet'] == 4)]
choices_filtered = ['negative', 'neutral', 'positive']
train_df_filtered['label'] = np.select(conditions_filtered, choices_filtered)
train_df_filtered.head()
# Out:
#    polarity of the tweet                                               text  \
# 0                      0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1                      0  is upset that he can't update his Facebook by ...
# 2                      0  @Kenichan I dived many times for the ball. Man...
# 3                      0    my whole body feels itchy and like its on fire
# 4                      0  @nationwideclass no, it's not behaving at all....
#
#       label
# 0  negative
# 1  negative
# 2  negative
# 3  negative
# 4  negative

# %%
train_ls_filtered = train_df_filtered.to_dict('records')

# %%
conditions = [
    (train_df['polarity of the tweet'] == 0),
    (train_df['polarity of the tweet'] == 2),
    (train_df['polarity of the tweet'] == 4)]
choices = ['negative', 'neutral', 'positive']
train_df['label'] = np.select(conditions, choices)
train_df.head()
# Out:
#    polarity of the tweet    tweet_id  \
# 0                      0  1467810369
# 1                      0  1467810672
# 2                      0  1467810917
# 3                      0  1467811184
# 4                      0  1467811193
#
#                                                 text     label
# 0  @switchfoot http://twitpic.com/2y1zl - Awww, t...  negative
# 1  is upset that he can't update his Facebook by ...  negative
# 2  @Kenichan I dived many times for the ball. Man...  negative
# 3    my whole body feels itchy and like its on fire   negative
# 4  @nationwideclass no, it's not behaving at all....  negative

# %%
train_ls = train_df.to_dict('records')

# %%
print(train_ls_filtered[0:10])
# Out:
# [{'polarity of the tweet': 0, 'text': "@switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D", 'label': 'negative'}, {'polarity of the tweet': 0, 'text': "is upset that he can't update his Facebook by texting it... and might cry as a result  School today also. Blah!", 'label': 'negative'}, {'polarity of the tweet': 0, 'text': '@Kenichan I dived many times for the ball. Managed to save 50%  The rest go out of bounds', 'label': 'negative'}, {'polarity of the tweet': 0, 'text': 'my whole body feels itchy and like its on fire ', 'label': 'negative'}, {'polarity of the tweet': 0, 'text': "@nationwideclass no, it's not behaving at all. i'm mad. why am i here? because I can't see you all over there. ", 'label': 'negative'}, {'polarity of the tweet': 0, 'text': '@Kwesidei not the whole crew ', 'label': 'negative'}, {'polarity of the tweet': 0, 'text': 'Need a hug ', 'label': 'negative'}, {'polarity of the tweet': 0, 'text': "@LOLTrish hey  long time no see! Yes.. Rains a bit ,only a bit  LOL , I'm fine thanks , how's you ?", 'label': 'negative'}, {'polarity of the tweet': 0, 'text': "@Tatiana_K nope they didn't have it ", 'label': 'negative'}, {'polarity of the tweet': 0, 'text': '@twittera que me muera ? ', 'label': 'negative'}]

# %%
import re
from nltk.tokenize import word_tokenize
from string import punctuation 
from nltk.corpus import stopwords 
import nltk
nltk.download('punkt')

class PreProcessTweets:
    def __init__(self):
        self._stopwords = set(stopwords.words('english') + list(punctuation) + ['AT_USER','URL'])
        
    def processTweets(self, list_of_tweets):
        processedTweets=[]
        for tweet in list_of_tweets:
            processedTweets.append((self._processTweet(tweet["text"]),tweet["label"]))
        return processedTweets
    
    def _processTweet(self, tweet):
        tweet = tweet.lower() # convert text to lower-case
        tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+))', 'URL', tweet) # remove URLs
        tweet = re.sub('@[^\s]+', 'AT_USER', tweet) # remove usernames
        tweet = re.sub(r'#([^\s]+)', r'\1', tweet) # remove the # in #hashtag
        tweet = word_tokenize(tweet) # remove repeated characters (helloooooooo into hello)
        return [word for word in tweet if word not in self._stopwords]
    
tweetProcessor = PreProcessTweets()
preprocessedTrainingSet = tweetProcessor.processTweets(train_ls_filtered)
preprocessedTestSet = tweetProcessor.processTweets(testDataSet)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/al.sandiego/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import nltk 

def buildVocabulary(preprocessedTrainingData):
    all_words = []
    
    for (words, sentiment) in preprocessedTrainingData:
        all_words.extend(words)

    wordlist = nltk.FreqDist(all_words)
    word_features = wordlist.keys()
    
    return word_features

# %%
def extract_features(tweet):
    tweet_words = set(tweet)
    features = {}
    for word in word_features:
        features['contains(%s)' % word] = (word in tweet_words)
    return features

# %%
word_features = buildVocabulary(preprocessedTrainingSet)
trainingFeatures = nltk.classify.apply_features(extract_features, preprocessedTrainingSet)

# %%
NBayesClassifier = nltk.NaiveBayesClassifier.train(trainingFeatures)

# %%
import pickle
save_classifier = open("naivebayes_train.pickle","wb")
pickle.dump(NBayesClassifier, save_classifier)
save_classifier.close()

# %%
import pickle
classifier_f = open("naivebayes.pickle", "rb")
classifier = pickle.load(classifier_f)
classifier_f.close()

# %%
NBResultLabels = [NBayesClassifier.classify(extract_features(tweet[0])) for tweet in preprocessedTestSet]

# get the majority vote
if NBResultLabels.count('positive') > NBResultLabels.count('negative'):
    print("Overall Positive Sentiment")
    print("Positive Sentiment Percentage = " + str(100*NBResultLabels.count('positive')/len(NBResultLabels)) + "%")
else: 
    print("Overall Negative Sentiment")
    print("Negative Sentiment Percentage = " + str(100*NBResultLabels.count('negative')/len(NBResultLabels)) + "%")
# Out:
# Overall Positive Sentiment
# Positive Sentiment Percentage = 62.0%

# %%
NBResultLabelsPickle = [classifier.classify(extract_features(tweet[0])) for tweet in preprocessedTestSet]

# get the majority vote
if NBResultLabelsPickle.count('positive') > NBResultLabelsPickle.count('negative'):
    print("Overall Positive Sentiment")
    print("Positive Sentiment Percentage = " + str(100*NBResultLabelsPickle.count('positive')/len(NBResultLabelsPickle)) + "%")
else: 
    print("Overall Negative Sentiment")
    print("Negative Sentiment Percentage = " + str(100*NBResultLabelsPickle.count('negative')/len(NBResultLabelsPickle)) + "%")
# Out:
# Overall Negative Sentiment
# Negative Sentiment Percentage = 58.0%

# %%
for tweet in preprocessedTrainingSet:
    print(tweet[0])
# Out:
# ['loooooooovvvvvveee', 'kindle2', 'dx', 'cool', '2', 'fantastic', 'right']
# ['reading', 'kindle2', '...', 'love', '...', 'lee', 'childs', 'good', 'read']
# ['ok', 'first', 'assesment', 'kindle2', '...', 'fucking', 'rocks']
# ["'ll", 'love', 'kindle2', "'ve", 'mine', 'months', 'never', 'looked', 'back', 'new', 'big', 'one', 'huge', 'need', 'remorse']
# ['fair', 'enough', 'kindle2', 'think', "'s", 'perfect']
# ['big', "'m", 'quite', 'happy', 'kindle2']
# ['fuck', 'economy', 'hate', 'aig', 'non', 'loan', 'given', 'asses']
# ['jquery', 'new', 'best', 'friend']
# ['loves', 'twitter']
# ['love', 'obama', 'makes', 'jokes']
# ['check', 'video', '--', 'president', 'obama', 'white', 'house', 'correspondents', 'dinner']
# ['firmly', 'believe', 'obama/pelosi', 'zero', 'desire', 'civil', "'s", 'charade', 'slogan', 'want', 'destroy', 'conservatism']
# ['house', 'correspondents', 'dinner', 'last', 'night', 'whoopi', 'barbara', 'amp', 'sherri', 'went', 'obama', 'got', 'standing', 'ovation']
# ['watchin', 'espn..jus', 'seen', 'new', 'nike', 'commerical', 'puppet', 'lebron..sh*t', 'hilarious', '...', 'lmao']
# ['dear', 'nike', 'stop', 'flywire', 'shit', 'waste', 'science', 'ugly', 'love']
# ['lebron', 'best', 'athlete', 'generation', 'time', 'basketball', 'related', "n't", 'want', 'get', 'inter-sport', 'debates', '__1/2']
# ['talking', 'guy', 'last', 'night', 'telling', 'die', 'hard', 'spurs', 'fan', 'also', 'told', 'hates', 'lebron', 'james']
# ['love', 'lebron']
# ['lebron', 'beast', "'m", 'still', 'cheering', '4', 'a..til', 'end']
# ['lebron', 'boss']
# ['lebron', 'hometown', 'hero', 'lol', 'love', 'lakers', 'let', "'s", 'go', 'cavs', 'lol']
# ['lebron', 'zydrunas', 'awesome', 'duo']
# ['lebron', 'beast', '...', 'nobody', 'nba', 'comes', 'even', 'close']
# ['downloading', 'apps', 'iphone', 'much', 'fun', 'literally', 'app', 'anything']
# ['good', 'news', 'call', 'visa', 'office', 'saying', 'everything', 'fine', '...', '..what', 'relief', 'sick', 'scams', 'stealing']
# ['awesome', 'come', 'back', 'via']
# ['montreal', 'long', 'weekend', 'r', 'amp', 'r.', 'much', 'needed']
# ['booz', 'allen', 'hamilton', 'bad', 'ass', 'homegrown', 'social', 'collaboration', 'platform', 'way', 'cool', 'ttiv']
# ['mluc09', 'customer', 'innovation', 'award', 'winner', 'booz', 'allen', 'hamilton', '--']
# ['current', 'use', 'nikon', 'd90', 'love', 'much', 'canon', '40d/50d', 'chose', 'd90', 'video', 'feature', 'mistake']
# ['need', 'suggestions', 'good', 'ir', 'filter', 'canon', '40d', '...', 'got', 'pls', 'dm']
# ['checked', 'google', 'business-', 'blip', 'shows', 'second', 'entry', 'huh', 'good', 'ba', '...']
# ['google', 'always', 'good', 'place', 'look', "'ve", 'mentioned', 'worked', 'mustang', 'w/', 'dad']
# ['played', 'android', 'google', 'phone', 'slide', 'screen', 'scares', 'would', 'break', 'fucker', 'fast', 'still', 'prefer', 'iphone']
# ['us', 'planning', 'resume', 'military', 'tribunals', 'guantanamo', 'bay', '...', 'time', 'trial', 'aig', 'execs', 'chrysler', 'debt', 'holders']
# ['omg', 'bored', 'amp', 'tattoooos', 'itchy', 'help', 'aha']
# ["'m", 'itchy', 'miserable']
# ["'m", 'itchy', 'maybe', 'later', 'lol']
# ['rt', 'love', 'nerdy', 'stanford', 'human', 'biology', 'videos', 'makes', 'miss', 'school']
# ['bit', 'crazy', 'steep', 'learning', 'curve', 'lyx', 'really', 'good', 'long', 'docs', 'anything', 'shorter', 'would', 'insane']
# ["'m", 'listening', '``', 'p.y.t', "''", 'danny', 'gokey', 'lt', '3', 'lt', '3', 'lt', '3', 'aww', "'s", 'amazing', 'lt', '3', 'much']
# ['going', 'sleep', 'bike', 'ride']
# ['cant', 'sleep', '...', 'tooth', 'aching']
# ['blah', 'blah', 'blah', 'old', 'old', 'plans', 'today', 'going', 'back', 'sleep', 'guess']
# ['glad', 'didnt', 'bay', 'breakers', 'today', "'s", '1000', 'freaking', 'degrees', 'san', 'francisco', 'wtf']
# ['san', 'francisco', 'bay', 'breakers']
# ['landed', 'san', 'francisco']
# ['san', 'francisco', 'today', 'suggestions']
# ['obama', 'administration', 'must', 'stop', 'bonuses', 'aig', 'ponzi', 'schemers', '...']
# ['started', 'think', 'citi', 'really', 'deep', 'amp', '^t', 'gon', 'na', 'survive', 'turmoil', 'gon', 'na', 'next', 'aig']
# ['shaunwoo', 'hate', 'n', 'aig']
# ['regret', 'going', 'see', 'star', 'trek', 'awesome']
# ['way', 'see', 'star', 'trek', 'esquire']
# ['going', 'see', 'star', 'trek', 'soon', 'dad']
# ['annoying', 'new', 'trend', 'internets', 'people', 'picking', 'apart', 'michael', 'lewis', 'malcolm', 'gladwell', 'nobody', 'wants', 'read']
# ['bill', 'simmons', 'conversation', 'malcolm', 'gladwell']
# ['highly', 'recommend', 'malcolm', 'gladwell']
# ['blink', 'malcolm', 'gladwell', 'amazing', 'book', 'tipping', 'point']
# ['malcolm', 'gladwell', 'might', 'new', 'man', 'crush']
# ['omg', 'commercials', 'alone', 'espn', 'going', 'drive', 'nuts']
# ['playing', 'twitter', 'api', 'sounds', 'fun', 'may', 'need', 'take', 'class', 'find', 'new', 'friend', 'like', 'generate', 'results', 'api', 'code']
# ['playing', 'curl', 'twitter', 'api']
# ['hello', 'twitter', 'api']
# ['playing', 'java', 'twitter', 'api']
# ['twitter', 'api', 'slow', 'client', "'s", "n't", 'good']
# ['yahoo', 'answers', 'butt', 'sometimes']
# ['scrapbooking', 'nic', '=d']
# ['rt', 'five', 'things', 'wolfram', 'alpha', 'better', 'vastly', 'different', 'google']
# ['changed', 'default', 'pic', 'nike', 'basketball', 'cause', 'bball', 'awesome']
# ['nike', 'owns', 'nba', 'playoffs', 'ads', 'w/', 'lebron', 'kobe', 'carmelo', 'adidas', 'billups', 'howard', 'marketing', 'branding']
# ["'next", 'time', "'ll", 'call', 'nike']
# ['new', 'blog', 'post', 'nike', 'sb', 'dunk', 'low', 'premium', "'white", 'gum']
# ['rt', 'told', 'nike', 'layoffs', 'started', 'today']
# ['back', 'worked', 'nike', 'one', 'fav', 'word']
# ['way', "'m", 'totally', 'inspired', 'freaky', 'nike', 'commercial']
# ['giving', 'weka', 'app', 'engine', 'interface', 'using', 'bird', 'strike', 'data', 'tests', 'logo', 'given']
# ['brand', 'new', 'canon', 'eos', '50d', '15mp', 'dslr', 'camera', 'canon', '17-85mm', 'lens', '...', 'web', 'technology', 'thread', 'brand', 'new', 'canon', 'eos', '5..']
# ['class', '...', '50d', 'supposed', 'come', 'today']
# ['needs', 'someone', 'explain', 'lambda', 'calculus']
# ['took', 'graduate', 'field', 'exam', 'computer', 'science', 'today', 'nothing', 'makes', 'feel', 'like', 'idiot', 'lambda', 'calculus']
# ['shout', 'outs', 'east', 'palo', 'alto', 'buildin', 'karizmakaze', '50cal', 'gta', 'also', 'thanks', 'profits', 'doom', 'universal', 'hempz', 'cracka', '...', '...']
# ['yeahhhhhhhhh', 'would', "n't", 'really', 'lived', 'east', 'palo', 'alto', 'could', 'avoided', 'guess', "'s", 'summer']
# ['great', 'stanford', 'course', 'thanks', 'making', 'available', 'public', 'really', 'helpful', 'informative', 'starting']
# ['nvidia', 'names', 'stanford', "'s", 'bill', 'dally', 'chief', 'scientist', 'vp', 'research']
# ['new', 'blog', 'post', 'harvard', 'versus', 'stanford', 'wins']
# ['work', 'til', '6pm', '...', 'lets', 'go', 'lakers']
# ['damn', 'north', 'korea']
# ['go', 'ahead', 'blow', 'north', 'korea', 'map', 'already']
# ['north', 'korea', 'please', 'cease', 'douchebaggery', 'china', "n't", 'even', 'like', 'anymore']
# ['hell', 'pelosi', 'freakin', 'china', 'whose', 'dime']
# ['burning', 'cash', 'chrysler', 'gm', 'stop', 'financial', 'tsunami', '``', 'bailout', "''", 'means', 'taking', 'handout']
# ['insects', 'infected', 'spinach', 'plant']
# ['wish', 'could', 'catch', 'every', 'mosquito', 'world', 'n', 'burn', 'em', 'slowly.they', 'bitin', 'shit', 'outta', '2day.mosquitos', 'assholes', 'insects']
# ['got', 'back', 'church', 'totally', 'hate', 'insects']
# ['got', 'mcdonalds', 'goddam', 'eggs', 'make', 'sick', 'yeah', 'laker', 'date', 'go', 'lakers', 'much', 'update', 'well', "'s", 'true', 'suck']
# ['omgg', 'ohhdee', 'want', 'mcdonalds', 'damn', 'wonder', 'open', 'lol']
# ['history', 'exam', 'studying', 'ugh']
# ['hate', 'revision', "'s", 'boring', 'totally', 'unprepared', 'exam', 'tomorrow', 'things', 'looking', 'good', '...']
# ['higher', 'physics', 'exam', 'tommorow', 'lookin', 'forward', 'much']
# ["'s", 'bank', 'holiday', 'yet', "'m", 'work', 'exam', 'season', 'sucks']
# ['cheney', 'bush', 'real', 'culprits']
# ['life', 'bitch', 'dick', 'cheney', 'p2', 'bipart', 'tlot', 'tcot', 'hhrs', 'gop', 'dnc']
# ['dick', 'cheney', "'s", 'dishonest', 'speech', 'torture', 'terror', 'obama', '-fred', 'kaplan', 'slate']
# ['``', 'republican', 'party', 'bunch', 'anti-abortion', 'zealots', 'could', "n't", 'draw', 'flies', 'dump', "''", '--', 'neal', 'boortz', 'radio']
# ['twitter', "'s", 'connections', 'api', 'broken', 'tweets', "n't", 'make', 'twitter', '...']
# ['srsly', 'hate', 'stupid', 'twitter', 'api', 'timeout', 'thing', 'soooo', 'annoying']
# ['really', 'liked', '``', 'learning', 'jquery', "''", 'book', 'worth', 'look']
# ['jquery', 'ui', '1.6', 'book', 'review']
# ['interesting', 'ad', 'adobe', 'goodby', 'silverstein', 'amp', 'partners', 'youtube', 'adobe', 'cs4', 'le', 'sens', 'propre']
# ['goodby', 'silverstein', 'agency', 'new', 'site', 'great']
# ['rt', 'goodby', 'silverstein', "'s", 'new', 'site', 'enjoy', '*nice', 'find']
# ['ever', 'amazing', 'psyop', 'goodby', 'silverstein', 'amp', 'partners', 'hp', 'go', 'play', 'effects']
# ['top', 'ten', 'watched', 'viral-video', 'chart', 'love', 'nike', 'mostvaluablepuppets', 'campaign', 'wieden', 'amp', 'kennedy']
# ['zomg', 'g2']
# ['ok', 'lots', 'buzz', 'io2009', 'lucky', 'free', 'g2']
# ['got', 'free', 'g2', 'android', 'google', 'i/o']
# ['guess', "'ll", 'retiring', 'g1', 'start', 'using', 'developer', 'g2', 'woot', 'googleio']
# ['gwt', 'fireside', 'chat']
# ['happy', 'philip', 'googleio', 'today']
# ['lakers', 'played', 'great', 'wait', 'thursday', 'night', 'lakers', 'vs']
# ['hi', 'anyone', 'great', 'source', 'advice', 'viral', 'marketing', '...']
# ['judd', 'apatow', 'creates', 'fake', 'sitcom', 'nbc.com', 'market', 'new', 'movie', '...', 'viral', 'marketing', 'best']
# ["'s", 'case', 'study', 'use', 'viral', 'marketing', 'add', '10,000', 'people', 'list']
# ['viral', 'marketing', 'fail', 'acia', 'pills', 'brand', 'oughta', 'get', 'shut', 'hacking', 'people', "'s", 'messenger', "'s", 'get', '5-6', 'msgs', 'day', 'arrrgh']
# ['watching', 'night', 'museum', 'lmao']
# ['loved', 'night', 'museum']
# ['going', 'see', 'new', 'night', 'museum', 'movie', 'family', 'oh', 'boy', 'three', 'year', 'old', 'movies', 'fuin']
# ['got', 'back', 'movies', 'went', 'see', 'new', 'night', 'museum', 'rachel', 'good']
# ['saw', 'new', 'night', 'museum', 'movie', '...', '...', 'okay', '...', 'lol', '7\\10']
# ['going', 'see', 'night', 'museum', '2', 'tall', 'boy']
# ['take', 'date', 'see', 'night', 'museum', '2', 'whenever', 'want', '...', 'looks', 'soooooo', 'good']
# ['watching', 'night', 'museum', 'getting', 'really', 'good']
# ['night', 'museum', 'wolverine', 'junk', 'food', 'perfect', 'monday']
# ['saw', 'night', 'museum', '2', 'last', 'night..', 'pretty', 'crazy', 'movie..', 'cast', 'awesome', 'well', 'worth', 'robin', 'williams', 'forever']
# ['saw', 'night', 'museum', 'battle', 'swithsonian', 'today', 'okay', 'typical', 'kids', 'ben', 'stiller', 'movie']
# ['taking', 'katie', 'see', 'night', 'museum', 'picked']
# ['night', 'museum', 'tonite', 'instead', 'oh', 'well', '4', 'yr', 'old', 'better', 'enjoy', 'lol']
# ['gm', 'says', 'expects', 'announcment', 'sale', 'hummer', 'soon', 'reuters', 'wdsugm', 'says', 'expects', 'announcment', 'sale', 'hummer', '..']
# ["'s", 'unfortunate', 'stimulus', 'plan', 'put', 'place', 'twice', 'help', 'gm', 'back', 'american', 'people', 'led', 'inevitable']
# ['tell', 'giving', 'gm', 'use', 'programs', 'support', 'unemployed']
# ['oh', 'yes', 'gm', 'dies', 'worth', 'boo', 'hahaha']
# ['time', 'warner', 'cable', '3rd', 'time', 'since', 'memorial', 'day', 'bummer']
# ['would', 'rather', 'pay', 'reasonable', 'yearly', 'taxes', '``', 'free', "''", 'fast', 'internet', 'get', 'gouged', 'time', 'warner', 'slow', 'connection']
# ['nooooooo', 'dvr', 'died', 'half', 'way', 'ea', 'presser', 'hate', 'time', 'warner']
# ['f*ck', 'time', 'warner', 'cable', 'f*cking', 'suck', 'balls', '700', 'hd', 'tv', 'amp', 'damn', 'hd', 'channels', 'hardly', 'ever', 'come', 'bullshit']
# ['time', 'warner', 'worse', 'customer', 'service', 'ever', 'never', 'use']
# ['time', 'warner', 'devil', 'worst', 'possible', 'time', 'internet', 'go']
# ['fuck', 'internet', 'damn', 'time', 'warner']
# ['time', 'warner', 'really', 'picks', 'worst', 'time', 'work', 'want', 'get', 'mtv.com', 'watch', 'hills', 'wtfffff']
# ['hate', 'time', 'warner', 'soooo', 'wish', 'vios', 'cant', 'watch', 'fricken', 'mets', 'game', 'w/o', 'buffering', 'feel', 'like', 'im', 'watching', 'free', 'internet', 'porn']
# ['ahh', '...', 'got', 'rid', 'stupid', 'time', 'warner', 'today', 'amp', 'taking', 'nap', 'roomies', 'cook', 'pretty', 'good', 'end', 'monday']
# ['time', 'warner', "'s", 'hd', 'line', 'crap']
# ['fucked', 'time', 'warner', 'cable', 'didnt', 'know', 'modems', 'could', 'explode', 'susan', 'boyle', 'sucks']
# ['time', 'warner', 'cable', 'pulls', 'plug', "'the", 'girlfriend', 'experience']
# ['time', 'warner', 'cable', 'slogan', 'calling', 'day', '2pm', 'happens']
# ['rocawear', 'heads', 'china', 'building', '300', 'stores']
# ['climate', 'focus', 'turns', 'beijing', 'united', 'nations', 'us', 'european', 'governments', 'called', 'china', 'co-o..']
# ['myfoxdc', 'barrie', 'students', 'back', 'trip', 'china', 'silver', 'spring', 'high', 'school', "'s", 'class', 'trip', 'china', 'en..']
# ['three', 'china', 'aerospace', 'giants', 'develop', 'tianjin', 'binhai', 'new', 'area', '22.9', 'b', 'yuan', 'invested']
# ['gm', 'ceo', 'china', 'continue', 'key', 'partner']
# ['rt', 'time', 'buy', 'gm', 'car']
# ['recovering', 'surgery..wishing']
# ['wrist', 'still', 'hurts', 'get', 'looked', 'hate', 'dr/dentist/scary', 'places', 'time', 'watch', 'eagle', 'eye', 'want', 'join', 'txt']
# ['dentist', 'tomorrow', 'brush', 'well', 'morning', 'like', 'make', 'hair', 'nice', 'get', 'cut']
# ['dentist', 'lied', '``', 'u', 'wo', "n't", 'feel', 'discomort', 'prob', 'wo', "n't", 'even', 'need', 'pain', 'pills', "''", 'man', 'u', 'twippin', 'shit', 'hurt', 'many', 'pills', 'take']
# ['dentist', 'great', "'s", 'expensive', '...']
# ['pet', 'dentist']
# ['studing', 'math', 'tomorrow', 'exam', 'dentist']
# ['dentist', 'wrong', '...', 'wrong']
# ['going', 'dentist', 'later']
# ['son', 'looking', 'cars', 'online', 'hate', 'car', 'shopping', 'would', 'rather', 'go', 'dentist', 'anyone', 'good', 'car', 'good', 'price', 'sell']
# ['ncaa', 'baseball', 'super', 'regional', 'rams', 'club']
# ['started', 'playing', 'major', 'league', 'baseball', '2k9']
# ['cardinals', 'baseball', 'advance', 'super', 'regionals', 'face', 'cs-fullerton', 'friday']
# ['sony', 'coupon', 'code..', 'expires', 'soon..']
# ['waiting', 'line', 'safeway']
# ['luke', 'got', 'stopped', 'walking', 'safeway', 'asked', 'empty', 'pockets', 'lift', 'shirts', 'jacked']
# ['realize', 'gym', 'safeway']
# ['three', 'words', '``', 'safeway', 'dot', 'com', "''"]
# ['safeway', 'rock', 'n', 'roll', 'tonight']
# ['bout', 'hit', 'safeway', 'got', 'ta', 'eat']
# ['jake', "'s", 'going', 'safeway']
# ['found', 'safeway', 'picking', 'staples']
# ['safeway', 'super-marketing', 'via', 'mobile', 'coupons']
# ['safeway', 'bathroom', 'still', 'smells', 'like', 'ass']
# ['safeway', 'elkhorn', 'move', 'like', "'re", 'dead']
# ['normal', 'weight', 'get', 'normal', 'eating', 'blog']
# ['eating', 'watching', 'movies', '...']
# ['eating', 'sashimi']
# ['eating', 'home', 'made', 'yema']
# ['eating', 'cake']
# ['love', 'dwight', 'howard', "'s", 'vitamin', 'water', 'commercial', '...', 'wish', 'nike', 'adidas', 'lol']
# ['found', 'nothing', 'nike', 'factory', 'banana', 'republic', 'outlet']
# ['iphone', 'may', 'get', 'radio', 'tagging', 'nike', 'recently-released', 'itunes', 'version', '8.2', 'suggests', 'voiceover', 'functional..']
# ['lovin', 'nike', 'already', "'s", 'running', 'spot', 'bedroom']
# ['launched', 'imgsearch', 'ajax', 'jquery', 'webapp']
# ['finally', 'got', 'around', 'using', 'jquery', 'make', 'bio', 'collapse', 'yay', 'slide', 'animations']
# ['rt', 'ultimate', 'jquery', 'list']
# ['extracted', 'open-sourced', 'jquery', 'plugin', 'stormweight', 'highlight', 'text', 'regular', 'expression']
# ['php', 'jquery', 'hack']
# ['jquery', 'cheat', 'sheet']
# ['beginning', 'javascript', 'css', 'development', 'jquery', 'javascript', 'css', 'jquery']
# ['right', 'lol', "'ll", 'get', 'high', 'expectations', 'warren', 'buffet', 'style']
# ['rt', 'rt', 'great', '``', 'someone', "'s", 'sitting', 'shade', 'today', 'someone', 'planted', 'tree', 'long', 'time', 'ago', '``', 'warren', 'buffet']
# ['warren', 'buffet', 'economy']
# ['warren', 'buffet', 'became', 'time', 'richest', 'man', 'united', 'states', 'working', 'investing', '1', 'big', 'idea', 'lead', 'fortune']
# ['according', 'create', 'school', 'notre', 'dame', '7', 'receivers', 'ncaa', '10', '84', 'higher', 'rating', '*sweet*']
# ['all-star', 'basketball', 'classic', 'tuesday', 'features', 'top', 'talent', 'chattanooga', "'s", 'notre', 'dame', 'high', 'school', 'play', 'host..']
# ["'s", 'definitely', 'warranty', 'amp', 'experience', 'amazon', 'support', 'kindle', 'great', 'contact', 'kindle2']
# ['rt', 'look', 'available', 'amazon', 'kindle2', 'amp', 'kindle', 'dx', 'get', 'top', 'electronic', 'book', 'reader', 'period', 'free', '2', 'day', 'ship', '...']
# ['time', 'warner', 'road', 'runner', 'customer', 'support', 'absolutely', 'blows', 'hate', 'high-speed', 'net', 'options', "'m", 'ready', 'go', 'nuclear']
# ['time', 'warner', 'cable', 'phone', 'reps', 'r', 'dumber', 'nails', 'ugh', 'cable', 'working', '10', 'mins', 'ago', 'wtf']
# ['tried', 'time', 'warner', "n't", 'nice', 'recorded', 'today']
# ['omg', 'time', 'warner', "f'ed", 'internet', 'install', 'instead', 'today', 'next', 'saturday', 'another', 'week', 'w/o', 'internet', 'amp', '*ehfa^v9fhg', 'fml']
# ['wth..i', 'never', 'seen', 'line', 'loooong', 'time', 'warner', 'ugh']
# ['impatiently', 'awaiting', 'arrival', 'time', 'warner', 'guy', "'s", 'way', 'pretty', 'inside', 'afternoon']
# ['man', 'accosts', 'roger', 'federer', 'french', 'open']
# ['naive', 'bayes', 'using', 'em', 'text', 'classification', 'really', 'frustrating', '...']
# ['went', 'stanford', 'university', 'today', 'got', 'tour', 'made', 'want', 'go', 'back', 'college', "'s", 'also', 'decided', 'kids', 'go']
# ['investigation', 'pending', 'death', 'stanford', 'cs', 'prof', 'google', 'mentor', 'rajeev', 'motwani', 'tip']
# ["'m", 'going', 'bed', 'successful', 'weekend', 'stanford', 'come']
# ["'re", 'harassed', 'calls', 'car', 'warranty', 'changing', 'number', 'wo', "n't", 'fix', 'call', 'every', 'number', 'd-bags']
# ['blocked', 'united', 'blood', 'services', 'using', 'google', 'voice', 'call', 'car', 'warranty', 'guys']
# ['amp', 'complete', 'fail']
# ['oh', 'snap', 'work', 'amp', "n't"]
# ['really', 'dont', 'want', 'amp', 'phone', 'service..they', 'suck', 'comes', 'signal']
# ['say', 'cut', 'small', 'talk', 'amp', "'s", 'new', 'slogan', 'f__k', 'give', 'us', 'money', 'apologies', 'bob', 'geldof']
# ['pissed', 'amp', "'s", 'mid-contract', 'upgrade', 'price', 'iphone', "'s", '200', "'m", 'going', 'pay', '499', 'something', 'thought', '299']
# ['safari', '4', 'fast', 'even', 'shitty', 'amp', 'tethering']
# ['amp', 'fucking']
# ['amp', 'dropped', 'ball', "n't", 'supporting', 'crap', 'new', 'iphone', '3.0', '...', 'fail', 'att', 'sucks']
# ['yay', 'glad', 'got', 'phone', 'still', 'damn', 'amp']
# ['google', 'wave', 'developer', 'sandbox', 'account', 'request']
# ['talk', 'cheap', 'bing', 'stick', 'google']
# ['wtf', 'point', 'deleting', 'tweets', 'still', 'found', 'summize', 'searches', 'twitter', 'please', 'fix', 'thanks', 'bye']
# ['google', 'profiles', 'stopped', 'showing', 'searches', 'cant', 'see', 'anymore']
# ['love', 'google', 'translator', 'good', 'day', 'mate']
# ['reading', 'new', 'kindle2']
# ['kindle2', 'came', 'love']
# ['loving', 'new', 'kindle2', 'named', 'kendra', 'case', 'u', 'wondering', '``', 'cookbook', "''", 'tool', 'cuz', 'tells', 'u', 'tricks', 'best', 'gift', 'evr']
# ['real', 'aig', 'scandal']
# ['twitter', 'aprs', 'apps', 'yet']
# ['45', 'pros', 'following', 'twitter']
# ['obama', 'quite', 'good', 'comedian', 'check', 'dinner', 'speech', 'cnn', 'funny', 'jokes']
# ['barack', 'obama', 'shows', 'funny', 'side', '``', 'gt', 'gt', 'great', 'speech..']
# ['like', 'guy', 'barack', 'obama', 'shows', 'funny', 'side', '``', 'gt', 'gt']
# ['obama', "'s", 'speech', 'pretty', 'awesome', 'last', 'night']
# ['reading', '``', 'bill', 'clinton', 'fail', 'obama', 'win', "''"]
# ['obama', 'popular', 'u.s.', 'among', 'arabs', 'survey', 'president', 'barack', 'obama', "'s", 'popularity', 'leading', 'arab', 'countries', '..']
# ['obama', "'s", 'got', 'jokes', 'haha', 'got', 'watch', 'bit', 'dinner', 'speech', 'last', 'night', '...', "'m", 'love', 'mr.', 'president']
# ['lebron', 'james', 'got', 'car', 'accident', 'guess..just', 'heard', 'evening', 'news', '...', 'wow', 'cant', 'believe', 'it..will', 'ok']
# ['best', 'playoffs', 'years', 'oh', 'yea', 'lebron', 'melo', 'finals']
# ['lebron', 'best']
# ['lebron', 'cool', 'like', 'personality', '...', 'good', 'character']
# ['watching', 'lebron', 'highlights', 'damn', 'niggas', 'good']
# ['lebron', 'murdering', 'shit']
# ['lebron', 'monsta', '24.', 'smh', 'world', 'ai', "n't", 'ready']
# ['lebron', 'done', 'nba', 'probably', 'greater', 'kobe', 'like', 'u', 'said', 'kobe', 'good', 'alot', "'good", 'players']
# ['kobe', 'good', 'bt', 'lebron', 'vote']
# ['kobe', 'best', 'world', 'lebron']
# ['world', 'cup', '2010', 'access', 'damn', "'s", 'good', 'look']
# ['bought', 'tickets', '2010', 'fifa', 'world', 'cup', 'south', 'africa', 'going', 'great', 'summer']
# ['share', 'disruption', '...', 'fred', 'wilson', "'s", 'slides', 'talk', 'google', 'hq']
# ['go', 'booz', 'allen', 'hamilton', '2hr', 'meeting', 'get', 'go', 'home']
# ['great', 'indian', 'tamasha', 'truly', 'unfold', 'may', '16', 'result', 'day', 'indian', 'general', 'election']
# ['kindle2', "'ve", 'seen', 'pictures', 'dx', "n't", 'seen', 'person', 'love', 'kindle', "'m", 'everyday']
# ['awesome', 'idea', 'continual', 'learning', 'program', 'kindle2']
# ['ok..', 'nothing..', 'thinking', '40d']
# ['ooooh', 'model', 'getting', '40d', 'love', 'love', 'love', 'love']
# ['times', 'india', 'wonder', 'india', "'s", 'election']
# ['good', 'video', 'google', 'using', 'search', 'options']
# ['lol', 'ah', 'skin', 'itchy', 'damn', 'lawnmowing']
# ['itchy', 'back', 'dont', 'ya', 'hate']
# ['stanford', 'charity', 'fashion', 'show', 'top', 'draw']
# ['stanford', 'university', 'facebook', 'profile', 'one', 'popular', 'official', 'university', 'pages']
# ['lyx', 'cool']
# ['sooo', 'dissapointed', 'sent', 'danny', 'gokey', 'home', '...', 'still', 'rock', '...', 'danny', '...', 'hometown', 'hero', 'yeah', 'milrockee']
# ['rt', "'american", 'idol', 'fashion', 'adam', 'lambert', 'tones', 'danny', 'gokey', 'cute', '...']
# ['love', 'danny', 'gokey']
# ['rt', 'rt', 'gm', 'onstar', 'instantly', 'sends', 'accident', 'location', 'coordinates', '911', 'gps', 'obsessed']
# ['tired', "n't", 'sleep', 'well', 'last', 'night']
# ['boarding', 'plane', 'san', 'francisco', '1', 'hour', '6', 'hr', 'flight', 'blech']
# ['bonjour', 'san', 'francisco', 'back', 'hurts', 'last', 'night..']
# ['breakers', 'san', 'francisco', 'ca']
# ['heading', 'san', 'francisco']
# ['best', 'girl', 'hours', 'san', 'francisco', 'mmmmmfamily', 'wonderful']
# ['f***', 'big', 'go', 'home', 'aig']
# ['went', 'see', 'star', 'trek', 'movie', 'last', 'night', 'satisfying']
# ['ca', "n't", 'wait', 'going', 'see', 'star', 'trek', 'tonight']
# ['star', 'trek', 'good', 'everyone', 'said']
# ['loving', 'new', 'malcolm', 'gladwell', 'book', 'outliers']
# ['highly', 'recommend', 'malcolm', 'gladwell', "'s", "'the", 'tipping', 'point', 'next', 'audiobook', 'probably', 'one', 'well']
# ['malcolm', 'gladwell', 'genius', 'tricking', 'people', 'realizing', "'s", 'fucking', 'idiot']
# ['hey', 'offense', 'malcolm', 'gladwell', 'pretenious', 'annoying', 'cunt', 'brings', 'cant', 'read', 'shit']
# ['rt', 'great', 'article', 'malcolm', 'gladwell']
# ['seriously', 'underestimated', 'malcolm', 'gladwell', 'want', 'meet', 'dude']
# ['hate', 'comcast', 'right', 'everything', 'cable', 'internet', 'amp', 'phone', '...', '.ughh']
# ['comcast', 'sucks']
# ['day', 'never', 'deal', 'comcast', 'rank', 'one', 'best', 'days', 'life']
# ['comcast', 'fail']
# ['use', 'twitter', 'api', '...']
# ['curses', 'twitter', 'api', 'limit']
# ['see', 'dave', 'winer', 'screams', 'lack', 'twitter', 'api', 'limitations', 'access', 'throttles']
# ['testing', 'twitter', 'api']
# ['arg', 'twitter', 'api', 'making', 'crazy']
# ['testing', 'twitter', 'api', 'remote', 'update']
# ["'m", 'really', 'loving', 'new', 'search', 'site', 'wolfram/alpha', 'makes', 'google', 'seem', '...', 'quaint']
# ['wolfram', 'alpha', 'sucks', 'even', 'researchers', 'information', 'provided', 'less', 'get', 'google', 'wikipedia', 'totally', 'useless']
# ['nike', 'factory']
# ['new', 'nike', 'muppet', 'commercials', 'pretty', 'cute', 'live', 'together']
# ['new', 'blog', 'post', 'nike', 'zoom', 'lebron', 'soldier', '3', 'iii', 'white', 'black', 'teal']
# ['new', 'blog', 'post', 'nike', 'trainer', '1']
# ['oh', 'awesome', 'wish', "n't", 'owned', 'nike']
# ['awesome', 'seeing', 'show', 'friday', 'shoreline', 'amphitheatre', 'never', 'seen', 'nin', 'ca', "n't", 'wait', '...']
# ['arhh', "'s", 'weka', 'bug', "''", 'spent', 'almost', 'two', 'hours', 'find', 'crappy']
# ['hey', 'bud', 'np', 'love', '50d', 'although', "'d", 'love', '5d', 'mkii']
# ['got', 'us', '50d', 'office']
# ['picked', 'new', 'canon', '50d', '...', "'s", 'beautiful', 'prepare', 'seriously', 'awesome', 'photography']
# ['got', 'new', 'toy', 'canon', '50d', 'love', 'love', 'love']
# ['learning', 'lambda', 'calculus']
# ['jobs', 'sittercity', 'help', 'taking', 'care', 'sick', 'child', 'east', 'palo', 'alto', 'ca']
# ["'m", 'moving', 'east', 'palo', 'alto']
# ['atebits', 'finished', 'watching', 'stanford', 'iphone', 'class', 'session', 'really', 'appreciate', 'rock']
# ['hi', 'saw', 'stanford', 'talk', 'really', 'liked', 'advice', 'saying', 'hi', 'singapore', 'yes', 'videos', 'get', 'around']
# ['mba', 'admissions', 'tips', 'stanford', 'gsb', 'deadlines', 'essay', 'topics', '2009-2010']
# ['ethics', 'nonprofits', 'stanford', 'socialentrepreneurship']
# ['lakers', 'tonight', 'let', "'s", 'go']
# ['lakers', 'kick', 'nuggets', 'ass', 'tonight']
# ['oooooooh', '...', 'north', 'korea', 'troubleeeee']
# ['wat', 'heck', 'north', 'korea', 'conducted', 'powerful', 'nuclear', 'tests', 'follow', 'link']
# ['listening', 'obama', '...', 'friggin', 'north', 'korea', '...']
# ['realized', 'three', 'monkeys', 'white', 'obama.biden', 'pelosi', 'sarah', 'palin', '2012']
# ['pelosi', 'stay', 'china', 'never', 'come', 'back']
# ['nancy', 'pelosi', 'gave', 'worst', 'commencement', 'speech', "'ve", 'ever', 'heard', 'yes', "'m", 'still', 'bitter']
# ['ugh', 'amount', 'times', 'stupid', 'insects', 'bitten', 'grr..']
# ['prettiest', 'insects', 'ever', 'pink', 'katydids']
# ['got', 'barraged', 'horde', 'insects', 'hungry', 'kitchen', 'light', 'scary']
# ['mcdonalds', 'dinner', 'goooood', 'big', 'mac', 'meal']
# ['ahh', 'yes', 'lol', 'ima', 'tell', 'hubby', 'go', 'get', 'sum', 'mcdonalds']
# ['stopped', 'lunch', 'mcdonalds', 'chicken', 'nuggetssss', 'yummmmmy']
# ['could', 'go', 'lot', 'mcdonalds', 'mean', 'lot']
# ['exam', 'went', 'good', 'prayers', 'worked']
# ['one', 'exam', 'left', 'happy']
# ['math', 'review', 'im', 'going', 'fail', 'exam']
# ['colin', 'powell', 'rocked', 'yesterday', 'cbs', 'cheney', 'needs', 'shut', 'hell', 'go', 'home.powell', 'man', 'honor', 'served', 'country', 'proudly']
# ['obviously', 'siding', 'cheney']
# ['absolutely', 'hilarious']
# ['never', 'thank', 'including', 'top', '100', 'twitter', 'authors', 'rock', 'amp', 'new', 'wave', '-d']
# ['learning', 'jquery', '1.3', 'book', 'review']
# ['rt', 'awesome', 'jquery', 'reference', 'book', 'coda', 'webdesign']
# ["'ve", 'sending', 'e-mails', 'like', 'crazy', 'today', 'contacts', '...', 'anyone', 'contact', 'goodby', 'silverstein', '...', "'d", 'love', 'speak']
# ['adobe', 'cs4', 'commercial', 'goodby', 'silverstein']
# ['goodby', 'silverstein', "'s", 'new', 'site', '...', 'enjoy']
# ['wow', 'everyone', 'google', 'i/o', 'conference', 'got', 'free', 'g2', "'s", 'month', 'unlimited', 'service']
# ['dood', 'got', 'free', 'google', 'android', 'phone', 'i/o', 'conference', 'g2']
# ['g2', 'amazing', 'btw', 'huge', 'improvement', 'g1']
# ['html', '5', 'demos', 'lots', 'great', 'stuff', 'come', 'yes', "'m", 'excited', 'io2009', 'googleio']
# ['yay', 'happy', 'place', 'place', 'place', 'love', 'google']
# ['googleio', 'o3d', 'bringing', '3d', 'graphics', 'browser', 'nice', 'tbh', 'funfun']
# ['awesome', 'viral', 'marketing', '``', 'funny', 'people', "''"]
# ['watching', 'programme', 'life', 'hitler', 'enhancing', 'geekiness', 'history']
# ['saw', 'night', 'museum', 'sheer', 'desperation', 'funding', 'movies']
# ['night', 'museum', '2', 'pretty', 'furkin', 'good']
# ['watching', 'night', 'museum', 'giggling']
# ['jenna', 'went', 'see', 'night', 'museum', '2', 'today', 'surprised', 'see', 'three', 'cast', 'members', 'office', '...']
# ['watch', 'night', 'museum', 'ryan', 'stacy']
# ['getting', 'ready', 'go', 'watch', 'night', 'museum', '2.', 'dum', 'dum', 'give', 'gum', 'gum']
# ['back', 'seeing', "'star", 'trek', "'night", 'museum', "'star", 'trek', 'amazing', "'night", 'museum', 'eh']
# ['watched', 'night', 'museum', '2', 'stinkin', 'cute']
# ['night', 'museum', '2', 'awesome', 'much', 'better', 'part', '1.', 'next', 'weekend', "'ll", 'see']
# ['think', 'may', 'new', 'favorite', 'restaurant', 'way', 'see', '``', 'night', 'museum', '2', "''"]
# ['sold', "'m", 'seeing', 'night', 'museum', '2.', "'m", '__', 'years', 'old']
# ['saw', 'new', 'night', 'museum', 'loved', 'next', 'go', 'see', '3d']
# ['shame', 'gm', 'forced', 'make', 'cars', 'white', 'house', 'thinks', 'sell', 'think']
# ['u', 'may', 'noticed', 'happy', 'gm', 'situation', 'aig', 'lehman', 'et', 'al']
# ['obama', 'nationalization', 'gm', 'short-term', 'ap']
# ['gm', 'good', 'riddance', 'sad', 'though']
# ['never', 'buy', 'government', 'motors', 'vehicle', 'recently', 'drove', 'gm', 'cars', 'since', '1988', 'bought', '..']
# ['old', 'coca-cola', 'guy', 'gm', 'board', 'stupid', 'heck', 'tcot', 'ala']
# ['rantsandraves', 'worst', 'thing', 'gm', 'concord', 'pleasant', 'hill', 'martinez', 'fucking', 'uaw', '..']
# ['give', 'man', 'fish', 'u', 'feed', 'day', 'teach', 'fish', 'u', 'feed', 'life', 'buy', 'gm', 'u', 'f**k', 'good']
# ['hear', 'gm', 'thing', 'angry', 'get', 'billions', 'wasted', 'bullshit', 'something', 'like', '40k', 'employees', 'the..']
# ['gm', 'car', 'junk', 'far', 'quality', 'compared', 'honda']
# ['sad', 'day', '...', 'bankrupt', 'gm']
# ['upset', 'whole', 'gm', 'thing', 'life', 'know', 'screwed']
# ['whoever', 'running', 'time', 'warner', 'needs', 'repeatedly', 'raped', 'rhino', 'understand', 'consequences', 'putting', 'shitty', 'cable', 'svcs']
# ['time', 'warner', 'ceo', 'hints', 'online', 'fees', 'magazines', 'ap', 'read', 'mountain', 'view', 'united', 'states', 'views', '16209']
# ['wftb', 'joining', 'bit', 'late', 'connection', 'boo', 'time', 'warner']
# ['cox', 'time', 'warner', 'cox', 'cheaper', 'gets', 'b', 'dslreports', 'tw', 'expensive', 'gets', 'c']
# ['furious', 'time', 'warner', 'phone', 'promotions']
# ['got', 'home', 'chick-fil-a', 'boys', 'damn', 'internets', 'stupid', 'time', 'warner']
# ['could', 'time-warner', 'cable', 'suck']
# ['pissed', 'time', 'warner', 'causin', 'slow', 'internet', 'problems']
# ['ummm', 'time', 'warner', 'problems']
# ['guys', 'see', 'time', 'warner', 'suck', 'much', 'ass', 'really', 'wish', 'could', 'get', 'u-verse', 'apartment']
# ['rt', 'upside', 'time', 'warner', 'unhelpful', 'phone', 'operators', 'superslow', 'on-site', 'service', 'crap', "'s", 'upside']
# ['rt', 'new', 'time', 'warner', 'slogan', '``', 'time', 'warner', 'make', 'long', 'days', 'cable', "''"]
# ['confirmed', "'s", 'time', 'warner', "'s", 'fault', 'facebook', "'s", 'fb', 'taking', '3', 'minutes', 'load', 'tempted', 'switch', 'verizon', '=/']
# ['time', 'warner', 'epic', 'fail']
# ['lawson', 'head', 'newedge', 'hong', 'kong', 'business', 'china']
# ['weird', 'piano', 'guitar', 'house', 'china']
# ['send', 'us', 'gm/chevy', 'photos']
# ['know', 'sad', 'rt', '1st', 'day', 'hurricane', 'season', "'s", 'less', 'scarey', 'govt', 'taking', 'gm']
# ['gm', 'files', 'bankruptcy', 'good', 'sign', '...']
# ['yankees', 'mets', 'lost', 'good', 'day']
# ['dentist', 'appt', 'today', 'actually', 'quite', 'enjoyable']
# ['hate', 'effing', 'dentist']
# ['dentist', 'appt', 'morning', 'conversation']
# ['hate', 'going', 'dentist..']
# ['hate', 'dentist', '...', '.who', 'invented', 'anyways']
# ['dentist', "'s", 'office', 'cold']
# ['check', 'video', '--', 'david', 'dentist']
# ['first', 'dentist', 'appointment', 'years', 'wednesday', 'possibly']
# ['tom', 'shanahan', "'s", 'latest', 'column', 'sdsu', 'ncaa', 'baseball', 'regional', 'appearance']
# ['baseballamerica.com', 'blog', 'baseball', 'america', 'prospects', 'blog', 'blog', '...']
# ['portland', 'city', 'politics', 'may', 'undo', 'baseball', 'park']
# ['rt', 'ca', 'merced', "'s", 'water', 'bottled', 'safeway', 'resold', 'profit', 'wells', 'drying', 'across', 'county']
# ['dropped', 'broccoli', 'walking', 'home', 'safeway', 'depressed']
# ["n't", 'safeway']
# ['applied', 'safeway', 'yeeeee']
# ['safeway', 'place', 'nightmare', 'right', 'bumming']
# ['safeway', 'dad']
# ['hate', 'safeway', 'select', 'green', 'tea', 'icecream', 'bought', 'two', 'cartons', 'waste', 'money', 'gt', 'lt']
# ['safeway', 'marvin', 'janelle', 'auntie', 'lhu']
# ['safeway', 'offering', 'mobile', 'coupons']
# ['phillies', 'driving', 'cadillac', 'top', 'cali', 'win', '5-3']
# ['saved', 'money', 'opting', 'grocery', 'store', 'trip', 'stocking', 'food', 'hotel', 'room', 'fridge', 'vs.', 'eating', 'every', 'night', 'town']
# ['lounging', 'around', 'eating', 'taco', 'bell', 'watching', 'ncis', 'work', 'tonight', 'need', 'help', 'staying', 'awake']
# ['eating', 'breakfast', 'school']
# ['still', 'hungry', 'eating', '...']
# ['10', 'tips', 'healthy', 'eating', 'resultsby', 'fitness', 'blog', 'fitness', '...']
# ['boyfriend', 'eating', 'quesadilla']
# ['eating', 'dinner', 'meat', 'chips', 'risotto']
# ['got', 'new', 'pair', 'nike', 'shoes', 'pics', 'later']
# ['nike', 'sb', 'blazer', 'high', '``', 'acg', "''", 'custom', 'brad', 'douglas']
# ['nike', 'rocks', "'m", 'super', 'grateful', "'ve", 'done', 'amp', 'european', 'division', 'nike', 'beyond']
# ['nike', 'air', 'yeezy', 'khaki/pink', 'colorway', 'release']
# ['tried', 'nike', 'v.', 'addictive']
# ['looks', 'awful', 'lot', 'like', 'one', 'nike', "'s", 'private', 'jets', '...', '.i', "'m", 'sayin', '...']
# ['nike', 'training', 'club', 'beta', 'iphone', 'app', 'looks', 'interesting']
# ['argghhhh', 'wo', "n't", 'jquery', 'appear', 'safari', 'bad', 'safari']
# ['devsnippets', 'jquery', 'tools', 'javascript', 'ui', 'components', 'web', '...']
# ['ajax', 'jquery', 'css', 'javascript', '...', 'many', 'examples']
# ["'m", 'ready', 'drop', 'pretenses', 'forever', 'love', 'jquery', 'want', 'marry', 'sorry', 'ladies', 'nerd', 'jquery.spokenfor.js']
# ['cold..', 'looking', 'google', "'s", 'chart//visualization', 'api', 'found', 'jquery', '``', 'wrapper', "''", 'api', '...']
# ['spent', 'day', 'reading', 'jquery', 'book', 'start', 'drinking', 'delirium', 'tremens']
# ['jquery', 'selectors']
# ['implement', 'news', 'ticker', 'jquery', 'ten', 'lines', 'code']
# ["'s", 'buffet', 'warren', 'buffett', 'kicks', 'butt', 'battle', 'boots', 'posted', 'alex', 'crippe..']
# ['super', 'investors', 'great', 'weekend', 'read', 'warren', 'buffet', 'oldie', 'goodie']
# ["'m", 'truly', 'braindead', 'could', "n't", 'come', 'warren', 'buffet', "'s", 'name', 'save', 'soul']
# ['reading', 'michael', 'palin', 'book', 'python', 'years', '...', 'great', 'book', 'also', 'recommend', 'warren', 'buffet', 'amp', 'nelson', 'mandela', "'s", 'bio']
# ['mean', "'m", 'notre', 'dame', "'s", 'good', 'school', "'d", 'closer', 'dan', "'d", 'enjoy']
# ['ca', "n't", 'watch', 'tv', 'without', 'tivo', 'years', 'time/warner', 'dvr', 'still', 'sucks']
# ["'d", 'say', 'sports', 'writers', 'idiots', 'saying', 'roger', 'federer', 'one', 'best', 'ever', 'tennis', 'roger', 'federer', 'best', 'ever', 'tennis']
# ['still', 'love', 'kindle2', 'reading', 'new', 'york', 'times', 'feel', 'natural', 'miss', 'bloomingdale', 'ads']
# ['love', 'kindle2', 'stacks', 'books', 'trip', 'way', 'loo']
# ['although', 'today', "'s", 'keynote', 'rocked', 'every', 'great', 'announcement', 'amp', 'shit', 'us', 'little', 'bit']
# ['much', 'obsession', 'cell', 'phones', 'iphone', "'m", 'slave', 'amp', 'forever']
# ['oh', 'see', 'thought', 'amp', '900mhz', 'wcdma']
# ['read', 'tethering', 'support', 'phil', 'amp', 'o2', 'joining']
# ['fuzzball', 'fun', 'amp', 'p']
# ['today', 'good', 'day', 'dislike', 'amp', 't.', 'vote', 'office', 'indeed']
# ['got', 'wave', 'sandbox', 'invite', 'extra', 'excited', 'bad', 'class', '...', "'ll", 'play', 'soon', 'enough', 'io2009', 'wave']
# ['looks', 'like', 'summize', 'gone', 'many', 'tweets', 'wwdc', 'perhaps']
# ['hope', 'girl', 'work', 'buys', 'kindle2']
# ['missed', 'insight-filled', 'may', 'column', 'one', 'smart', 'guy', 'looking', 'closely', "'s", 'impressed', 'kindle2']
# ['thanks', 'much', '...', 'one', '*very*', 'happy', 'kindle2', 'winners', 'surprised', 'fabulous', 'thank', 'best', 'kathleen']
# ['man', 'kinda', 'dislike', 'apple', 'right', 'case', 'point', 'iphone', '3gs', 'wish', 'video', 'recorder', 'app', 'please']
# ['kindle2', 'amp', 'sony', 'prs-500', 'like', 'physical', 'device', 'feels', 'good', 'font', 'nice', 'pg', 'turns', 'snappy', 'enuf', 'ui', 'little', 'klunky']
# ['kindle2', 'seems', 'best', 'ereader', 'work', 'uk', 'get', 'one']
# ['google', 'addiction', 'thank', 'pointing', 'hahaha']
# ['primary', 'debit', 'card', 'visa', 'electron']
# ['bank', 'get', 'new', 'visa', 'platinum', 'card']
# ['dearest', 'rich', 'bastards', 'visa', 'card', 'sent', "n't", 'work', 'screw', 'little', 'guy', 'like']
# ['date', 'bobby', 'flay', 'gut', 'fieri', 'food', 'network']
# ['excited', 'seeing', 'bobby', 'flay', 'guy', 'fieri', 'tomorrow', 'great', 'american', 'food', 'amp', 'music', 'fest']
# ['gon', 'na', 'go', 'see', 'bobby', 'flay', '2moro', 'shoreline', 'eat', 'drink', 'gon', 'na', 'good']
# ['ca', "n't", 'wait', 'great', 'american', 'food', 'music', 'festival', 'shoreline', 'tomorrow', 'mmm', '...', 'katz', 'pastrami', 'bobby', 'flay', 'yes', 'please']
# ['dad', 'ny', 'day', 'ate', 'mesa', 'grill', 'last', 'night', 'met', 'bobby', 'flay', 'much', 'fun', 'except', 'completely', 'lost', 'voice', 'today']
# ['fighting', 'latex', '...']
# ['love', "n't", 'want', 'die', 'latex', 'devil']
# ['7', 'hours', '7', 'hours', 'inkscape', 'crashing', 'normally', 'solid', 'rock', '7', 'hours', 'latex', 'complaining', 'slightest', 'thing', 'ca', "n't", 'take']
# ['track', 'iran', 'social', 'media']
# ['shit', "'s", 'hitting', 'fan', 'iran', '...', 'craziness', 'indeed', 'iranelection']
# ['monday', 'already', 'iran', 'may', 'implode', 'kitchen', 'disaster', 'seems', 'happy', 'nice', 'weekend', 'great', 'whoop']
# ['twitter', 'stock', 'buzz', 'aapl', 'es_f', 'spy', 'spx', 'palm', 'updated', '12:00', 'pm']
# ['getting', 'ready', 'test', 'burger', 'receipes', 'weekend', 'bobby', 'flay', 'great', 'receipes', 'try', 'thanks', 'bobby']
# ['bobby', 'flay', 'joining']
# ['lam', 'love', 'bobby', 'flay', '...', 'favorite', 'rt', 'need', 'place', 'phoenix', 'great', 'peppers']
# ['created', 'first', 'latex', 'file', 'scratch', "n't", 'work', 'well', 'see', "'s", 'great', 'time', 'waster']
# ['using', 'linux', 'loving', 'much', 'nicer', 'windows', '...', 'looking', 'forward', 'using', 'wysiwyg', 'latex', 'editor']
# ['using', 'latex', 'lot', 'typeset', 'mathematics', 'looks', 'hideous']
# ['ask', 'programming', 'latex', 'indesign', 'submitted', 'calcio1', 'link', '1', 'comment']
# ['note', 'hate', 'word', 'hate', 'pages', 'hate', 'latex', 'said', 'hate', 'latex', 'texn3rds', 'come', 'kill']
# ['ahhh', '...', 'back', '*real*', 'text', 'editing', 'environment', 'lt', '3', 'latex']
# ['trouble', 'iran', 'see', 'hmm', 'iran', 'iran', 'far', 'away', 'flockofseagullsweregeopoliticallycorrect']
# ['reading', 'tweets', 'coming', 'iran', '...', 'whole', 'thing', 'terrifying', 'incredibly', 'sad', '...']

# %%
trainingFeatures
# Out:
# [({'contains(loooooooovvvvvveee)': True, 'contains(kindle2)': True, 'contains(dx)': True, 'contains(cool)': True, 'contains(2)': True, 'contains(fantastic)': True, 'contains(right)': True, 'contains(reading)': False, 'contains(...)': False, 'contains(love)': False, 'contains(lee)': False, 'contains(childs)': False, 'contains(good)': False, 'contains(read)': False, 'contains(ok)': False, 'contains(first)': False, 'contains(assesment)': False, 'contains(fucking)': False, 'contains(rocks)': False, "contains('ll)": False, "contains('ve)": False, 'contains(mine)': False, 'contains(months)': False, 'contains(never)': False, 'contains(looked)': False, 'contains(back)': False, 'contains(new)': False, 'contains(big)': False, 'contains(one)': False, 'contains(huge)': False, 'contains(need)': False, 'contains(remorse)': False, 'contains(fair)': False, 'contains(enough)': False, 'contains(think)': False, "contains('s)": False, 'contains(perfect)': False, "contains('m)": False, 'contains(quite)': False, 'contains(happy)': False, 'contains(fuck)': False, 'contains(economy)': False, 'contains(hate)': False, 'contains(aig)': False, 'contains(non)': False, 'contains(loan)': False, 'contains(given)': False, 'contains(asses)': False, 'contains(jquery)': False, 'contains(best)': False, 'contains(friend)': False, 'contains(loves)': False, 'contains(twitter)': False, 'contains(obama)': False, 'contains(makes)': False, 'contains(jokes)': False, 'contains(check)': False, 'contains(video)': False, 'contains(--)': False, 'contains(president)': False, 'contains(white)': False, 'contains(house)': False, 'contains(correspondents)': False, 'contains(dinner)': False, 'contains(firmly)': False, 'contains(believe)': False, 'contains(obama/pelosi)': False, 'contains(zero)': False, 'contains(desire)': False, 'contains(civil)': False, 'contains(charade)': False, 'contains(slogan)': False, 'contains(want)': False, 'contains(destroy)': False, 'contains(conservatism)': False, 'contains(last)': False, 'contains(night)': False, 'contains(whoopi)': False, 'contains(barbara)': False, 'contains(amp)': False, 'contains(sherri)': False, 'contains(went)': False, 'contains(got)': False, 'contains(standing)': False, 'contains(ovation)': False, 'contains(watchin)': False, 'contains(espn..jus)': False, 'contains(seen)': False, 'contains(nike)': False, 'contains(commerical)': False, 'contains(puppet)': False, 'contains(lebron..sh*t)': False, 'contains(hilarious)': False, 'contains(lmao)': False, 'contains(dear)': False, 'contains(stop)': False, 'contains(flywire)': False, 'contains(shit)': False, 'contains(waste)': False, 'contains(science)': False, 'contains(ugly)': False, 'contains(lebron)': False, 'contains(athlete)': False, 'contains(generation)': False, 'contains(time)': False, 'contains(basketball)': False, 'contains(related)': False, "contains(n't)": False, 'contains(get)': False, 'contains(inter-sport)': False, 'contains(debates)': False, 'contains(__1/2)': False, 'contains(talking)': False, 'contains(guy)': False, 'contains(telling)': False, 'contains(die)': False, 'contains(hard)': False, 'contains(spurs)': False, 'contains(fan)': False, 'contains(also)': False, 'contains(told)': False, 'contains(hates)': False, 'contains(james)': False, 'contains(beast)': False, 'contains(still)': False, 'contains(cheering)': False, 'contains(4)': False, 'contains(a..til)': False, 'contains(end)': False, 'contains(boss)': False, 'contains(hometown)': False, 'contains(hero)': False, 'contains(lol)': False, 'contains(lakers)': False, 'contains(let)': False, 'contains(go)': False, 'contains(cavs)': False, 'contains(zydrunas)': False, 'contains(awesome)': False, 'contains(duo)': False, 'contains(nobody)': False, 'contains(nba)': False, 'contains(comes)': False, 'contains(even)': False, 'contains(close)': False, 'contains(downloading)': False, 'contains(apps)': False, 'contains(iphone)': False, 'contains(much)': False, 'contains(fun)': False, 'contains(literally)': False, 'contains(app)': ...
