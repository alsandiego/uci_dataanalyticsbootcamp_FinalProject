# %%
import twitter
import os
from config import *
import time

# initialize api instance
twitter_api = twitter.Api(consumer_key=consumer_key,
                         consumer_secret=consumer_secret,
                         access_token_key=access_token_key,
                         access_token_secret=access_token_secret,
                        cache=None,tweet_mode='compat')

#print(consumer_key,consumer_secret,access_token_key,access_token_secret)

# test authentication
print(twitter_api.VerifyCredentials())
# print(twitter_api.GetStatus(126402758403305000))
# Out:
# {"created_at": "Wed Jul 20 02:34:27 +0000 2016", "description": "I am Al and I am passionate about technology.", "followers_count": 5, "friends_count": 52, "id": 755591669194514432, "id_str": "755591669194514432", "location": "Tustin, CA", "name": "Al", "profile_background_color": "000000", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "profile_banner_url": "https://pbs.twimg.com/profile_banners/755591669194514432/1469041661", "profile_image_url": "http://pbs.twimg.com/profile_images/755843006062694401/2JikSpJq_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/755843006062694401/2JikSpJq_normal.jpg", "profile_link_color": "1B95E0", "profile_sidebar_border_color": "000000", "profile_sidebar_fill_color": "000000", "profile_text_color": "000000", "screen_name": "alknowstech", "status": {"created_at": "Mon Jul 31 21:38:46 +0000 2017", "favorite_count": 1, "id": 892137484921978880, "id_str": "892137484921978880", "in_reply_to_screen_name": "TechYESCity", "in_reply_to_status_id": 891577872384638976, "in_reply_to_user_id": 1021097054, "lang": "en", "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>", "text": "@TechYESCity thanks for the reply.. is it stable enough to OC to 4ghz on 1700? i plan to use AIO cpu cooler"}, "statuses_count": 5}

# %%
def buildTestSet(search_keyword):
    try:
        tweets_fetched = twitter_api.GetSearch(search_keyword, count = 100,
                                               lang='en',result_type='recent')
        
        print("Fetched " + str(len(tweets_fetched)) + " tweets for the term " + search_keyword)
        
        return [{"text":status.text, "label":None, "user":status.user.screen_name, "time":status.created_at} for status in tweets_fetched]
    except:
        print("Unfortunately, something went wrong..")
        return None

# %%
# test search function
search_term = input("Enter a search keyword:")
testDataSet = buildTestSet(search_term)

print(testDataSet[0:10])
# Out:
# Enter a search keyword:tacobell
# Fetched 100 tweets for the term tacobell
# [{'text': 'Unbelievable. @tacobell https://t.co/pHIZWIUnRD', 'label': None, 'user': 'itstarynmarieG', 'time': 'Thu Feb 13 04:09:52 +0000 2020'}, {'text': '@tacobell please bring back the chalupa box, it was the best thing y’all had. Fry box ain’t it.', 'label': None, 'user': 'SulleySolomon', 'time': 'Thu Feb 13 04:09:44 +0000 2020'}, {'text': 'I went to #TacoBell 🌮🛎 again. Had to "Run for the Border". #LOVE💘 their #Burritos🌯 #Tacos🌮  #Nachos &amp; their #Cheese… https://t.co/CG2RKqaXjI', 'label': None, 'user': 'MsCeeAngel', 'time': 'Thu Feb 13 04:08:58 +0000 2020'}, {'text': '@tyvid5 @tacobell @StubHub @Rebecca_Mich If only I was closer I would come! Break a leg!', 'label': None, 'user': 'willsbradford', 'time': 'Thu Feb 13 04:07:16 +0000 2020'}, {'text': 'Umm @tacobell you wanna chime in about this, tell us what is going on? #WednesdayThoughts #tacobell https://t.co/dYYHDyRqMr', 'label': None, 'user': 'DuchessInBoston', 'time': 'Thu Feb 13 04:07:00 +0000 2020'}, {'text': '@tacobell Do you ever intend to open a location in Miami Beach???', 'label': None, 'user': 'Artistnyc1', 'time': 'Thu Feb 13 04:06:38 +0000 2020'}, {'text': '@tacobell My sister went through your drive thru in Cortez, CO and it looks like the whole team needs to be trained… https://t.co/KqPwD29oNE', 'label': None, 'user': 'williamschusta', 'time': 'Thu Feb 13 04:06:06 +0000 2020'}, {'text': 'RT @xlilhuddy: . @tacobell hey boo', 'label': None, 'user': 'Natycast6', 'time': 'Thu Feb 13 04:05:42 +0000 2020'}, {'text': 'RT @GrizzliesOnFSSE: Just stop it, @JaMorant. \n\n@tacobell // #GrindCity https://t.co/yVwhvPI8y1', 'label': None, 'user': 'corybrown514', 'time': 'Thu Feb 13 04:05:15 +0000 2020'}, {'text': '@RunDaltonRun @tacobell thought I’d share. This @tacobell location is literally an inside joke between my girlfrien… https://t.co/U8OGoq8yHd', 'label': None, 'user': 'iDuLicious', 'time': 'Thu Feb 13 04:04:46 +0000 2020'}]

# %% [markdown]
# # Use to test twitter api

# %%
tweets_fetched = twitter_api.GetSearch('disney', count = 100, lang='en')
[{"text":status.text, "label":None, "user":status.user.screen_name} for status in tweets_fetched]
# Out:
# [{'text': 'Be sure and tell us how that works out Mickey!  But hey Joe when you get finished you and Corn Pop can go to Disney… https://t.co/n2PY25a8o7',
#   'label': None,
#   'user': 'GovMikeHuckabee'},
#  {'text': "Ryan Reynolds got matched up with his perfect Disney character, and no it wasn't Deadpool 😜\n\n(via @VancityReynolds… https://t.co/ohko3jXX2B",
#   'label': None,
#   'user': 'getFANDOM'},
#  {'text': "'Mulan' star Liu Yifei did 90% of her own stunts in the Disney movie, according to the cinematographer https://t.co/KDWbJQfNo2",
#   'label': None,
#   'user': 'EntInsider'},
#  {'text': 'RT @DisneylandToday: #DidYouKnow Walt Disney is credited with inventing the first Audio-Animatronics®? Among the most popular firsts are Ab…',
#   'label': None,
#   'user': '8a_a33'},
#  {'text': '@AdamCSharp Is he created by Disney?',
#   'label': None,
#   'user': 'kathryn_hankey'},
#  {'text': 'RT @Disney: Good friends stick together like hunny! Happy 20th Anniversary to The Tigger Movie. https://t.co/bZEWF1vSUE',
#   'label': None,
#   'user': 're_laxer39'},
#  {'text': "RT @itsKajolD: Soooooo many memories. So much fun from Nysa's first Disney trip to seeing the history of San Fran up close and personal wit…",
#   'label': None,
#   'user': 'nripesh_kashyap'},
#  {'text': 'RT @60daylanguages: @Lcdot711 @Strickalator @AngelaBelcamino @realDonaldTrump Pocohantas was a real person and lived in England. Her father…',
#   'label': None,
#   'user': 'Strickalator'},
#  {'text': 'RT @MirellaBelle: I just found out that the actor who played Jar Jar Binks considered suicide bc he got death threats &amp; was bullied mercile…',
#   'label': None,
#   'user': 'ashv1110'},
#  {'text': 'RT @kirst188: Johnny Depp was fired from Disney based on accusations alone. Now the truth has come out, Amanda Heard is a PROVEN liar/abuse…',
#   'label': None,
#   'user': 'MalexHeart'},
#  {'text': "RT @itsKajolD: Soooooo many memories. So much fun from Nysa's first Disney trip to seeing the history of San Fran up close and personal wit…",
#   'label': None,
#   'user': 'chocogirl__'},
#  {'text': "RT @itsKajolD: Soooooo many memories. So much fun from Nysa's first Disney trip to seeing the history of San Fran up close and personal wit…",
#   'label': None,
#   'user': 'iamsksrk'},
#  {'text': 'RT @PimpMasterYoda1: A future where Disney remakes the Star Wars prequels. https://t.co/265oHpCPAV',
#   'label': None,
#   'user': 'Genji_TioBlack'},
#  {'text': '@IGN A prequel to a prequel where everybody died in the end. Who thought this would be a good idea?\n\nDisney better… https://t.co/O3psIYRY6i',
#   'label': None,
#   'user': 'DAMAGEincluded'},
#  {'text': 'RT @LiberalCEO: Shaun - NBC, CNN, and ABC are owned by Comcast, AT&amp;T, and Disney.\n\nThe media is bought and paid for by people who are anath…',
#   'label': None,
#   'user': 'bluedottx'},
#  {'text': 'Florida Live Cams is your #1 spot for you virtual Florida vacation. Disney, Spring Break, beaches, white sands, cru… https://t.co/1G9SUfy6xv',
#   'label': None,
#   'user': 'DisneyLiveCams'},
#  {'text': '@GlamandGore Disney is a monopoly, are we surprised?',
#   'label': None,
#   'user': 'fuckinsmile32'},
#  {'text': "RT @wishfultaem: hi! i'm taemin from shinee and you're watching disney channel 💫✨💎 https://t.co/wdR7XHI9S3",
#   'label': None,
#   'user': 'YaaMazz'},
#  {'text': '@latimes Dammm Disney is already making millions on their movies yet they want more SMH greedy mfs reasons why not… https://t.co/iqghZx7wHG',
#   'label': None,
#   'user': 'GustavoMX92'},
#  {'text': "RT @itsKajolD: Soooooo many memories. So much fun from Nysa's first Disney trip to seeing the history of San Fran up close and personal wit…",
#   'label': None,
#   'user': 'DevSRKian228'},
#  {'text': 'RT @RealGsPatton007: WOW 😳😳😳\n\n.@realDonaldTrump @POTUS Lines for his RALLY’s are Bigger than at Disney World 🌎 \n\n👇👇👇👇👇🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸\n\nhttps://t…',
#   'label': None,
#   'user': 'michael_legero'},
#  {'text': 'HA! Well you can SUCK MY DICK DISNEY! Hell nah! Looks I’m never going to Disneyland 🙅\u200d♂️@Handsandhead… https://t.co/wtK22VP6vR',
#   'label': None,
#   'user': 'ChipWhitehouse'},
#  {'text': 'RT @GSVarley: Disney Parks Casting... https://t.co/MtavJPYKGb',
#   'label': None,
#   'user': 'hay_ells'},
#  {'text': 'RT @DiscussingFilm: Gugu Mbatha-Raw has joined the cast of ‘LOKI’ on Disney+. \n\n(Source: https://t.co/kZZrBb3Tx5) https://t.co/1hFixRez1R',
#   'label': None,
#   'user': 'krisbenwuh'},
#  {'text': 'RT @MirellaBelle: I just found out that the actor who played Jar Jar Binks considered suicide bc he got death threats &amp; was bullied mercile…',
#   'label': None,
#   'user': 'ShoutNatalia'},
#  {'text': 'RT @CurtisScoon: Remember 2 years ago people were acting as if the movie Black Panther was a watershed moment in black history?  🤡🤡\n\nDisney…',
#   'label': None,
#   'user': 'fabledchap'},
#  {'text': 'what disney channel movie is this https://t.co/zpVi0zh4vW',
#   'label': None,
#   'user': 'cantaplan'},
#  {'text': 'RT @ReemDepp: 10 days left to #MINAMATA world premiere at @berlinale 😍😍 February 21 2020... #JohnnyDepp #JusticeForJohnnyDepp https://t.co/…',
#   'label': None,
#   'user': 'disney_newjack'},
#  {'text': "RT @getFANDOM: Ryan Reynolds got matched up with his perfect Disney character, and no it wasn't Deadpool 😜\n\n(via @VancityReynolds | Instagr…",
#   'label': None,
#   'user': 'brade1991'},
#  {'text': 'okay disney prince  https://t.co/W2JTeMul8B',
#   'label': None,
#   'user': 'finelineoverhs1'},
#  {'text': "RT @itsKajolD: Soooooo many memories. So much fun from Nysa's first Disney trip to seeing the history of San Fran up close and personal wit…",
#   'label': None,
#   'user': 'shank_giri'},
#  {'text': "RT @itsKajolD: Soooooo many memories. So much fun from Nysa's first Disney trip to seeing the history of San Fran up close and personal wit…",
#   'label': None,
#   'user': 'AnjeliSodhi'},
#  {'text': '@GlamandGore They have a limit to how many people they can have in the park so they jack up the prices to limit how… https://t.co/5d7ZwOJpMx',
#   'label': None,
#   'user': 'RamosTwinner1'},
#  {'text': "RT @itsKajolD: Soooooo many memories. So much fun from Nysa's first Disney trip to seeing the history of San Fran up close and personal wit…",
#   'label': None,
#   'user': 'LOVERBOYOFPC'},
#  {'text': "RT @itsKajolD: Soooooo many memories. So much fun from Nysa's first Disney trip to seeing the history of San Fran up close and personal wit…",
#   'label': None,
#   'user': 'tanveerkhan1401'},
#  {'text': "RT @St1_GrrnJay95: one gotta go: the totally unnecessary but also underrated collection that is the disney's early 00's lineup https://t.co…",
#   'label': None,
#   'user': 'LofiBeatsAKI'},
#  {'text': "RT @itsKajolD: Soooooo many memories. So much fun from Nysa's first Disney trip to seeing the history of San Fran up close and personal wit…",
#   'label': None,
#   'user': 'kapadia_pranay'},
#  {'text': 'What better way to celebrate #valentines than with #mickey and #minnie ? Shop now so it reaches you in time for… https://t.co/pXFnrfj5Mn',
#   'label': None,
#   'user': 'Quancious'},
#  {'text': 'RT @dovelungs: - coco was mediocre\n- treasure planet is easily one of the best Disney movies ever, they should’ve done more to hype it\n- fr…',
#   'label': None,
#   'user': 'Ich_bin_Amal'},
#  {'text': '@thediegocrespo did you see? https://t.co/DaojZ7qJDk',
#   'label': None,
#   'user': 'datlatteboi'},
#  {'text': 'RT @VogtRoberts: I like to imagine someone at Capcom calls Disney every single day trying to make a MARVEL VS. CAPCOM movie.',
#   'label': None,
#   'user': 'K_of_Cydonia'},
#  {'text': "RT @Autism_updates: Robin Williams's Daughter Gets Sweet Surprise From Disney Character Filter On Instagram \nhttps://t.co/YGawZJvFKt #autism",
#   'label': None,
#   'user': 'docherty_brett'},
#  {'text': '@josephj @PridefulSinss @BrandonDavisBD @akasan Disney added a half assed deleted scene so endgame made a few more… https://t.co/Yw77oFN68f',
#   'label': None,
#   'user': 'kalissiuchis'},
#  {'text': 'this is mad... frozen walt disney is a enemy of liberalism?',
#   'label': None,
#   'user': 'KillbotX'},
#  {'text': 'RT @RealGsPatton007: WOW 😳😳😳\n\n.@realDonaldTrump @POTUS Lines for his RALLY’s are Bigger than at Disney World 🌎 \n\n👇👇👇👇👇🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸\n\nhttps://t…',
#   'label': None,
#   'user': 'swedeev'},
#  {'text': 'RT @SMHFConvoy: Disney needs a space princess but I suppose that means creating original content as opposed to mining fairytales.',
#   'label': None,
#   'user': 'Absurd_Penguin'},
#  {'text': 'RT @KylieJenner: storm’s first disney trip ☑️🦋⚡️ https://t.co/rnRSejM9AC',
#   'label': None,
#   'user': '_callmezee'},
#  {'text': 'What better way to celebrate #valentines than with #mickey and #minnie ? Shop now so it reaches you in time for… https://t.co/V6YS6wjxWt',
#   'label': None,
#   'user': 'Quancious'},
#  {'text': 'RT @lilramenz: the disney store mirrors discriminated against me n my height &gt;:( https://t.co/uGP379Yl1Z',
#   'label': None,
#   'user': 'AVEFOUR4'},
#  {'text': "RT @itsKajolD: Soooooo many memories. So much fun from Nysa's first Disney trip to seeing the history of San Fran up close and personal wit…",
#   'label': None,
#   'user': 'iamshanu555'},
#  {'text': 'RT @millymouse_x: Me when there’s Disney drama and I don’t know what it is: https://t.co/FCRjT50Z0g',
#   'label': None,
#   'user': 'kingdomcorona'},
#  {'text': 'RT @Disney: Good friends stick together like hunny! Happy 20th Anniversary to The Tigger Movie. https://t.co/bZEWF1vSUE',
#   'label': None,
#   'user': 'rinrin_ds'},
#  {'text': "RT @itsKajolD: Soooooo many memories. So much fun from Nysa's first Disney trip to seeing the history of San Fran up close and personal wit…",
#   'label': None,
#   'user': 'bhavnidhi_k'},
#  {'text': "RT @itsKajolD: Soooooo many memories. So much fun from Nysa's first Disney trip to seeing the history of San Fran up close and personal wit…",
#   'label': None,
#   'user': 'ranjishein'},
#  {'text': 'RT @isamidala1: #BringBenSoloBack @Disney because if #reylo is reverse #anidala, #BenSolo shouldn’t die !',
#   'label': None,
#   'user': 'PitaGonzalezMe'},
#  {'text': 'RT @RikRankin: @TimDownie1 @Disney I believe! Let’s go pitch them?',
#   'label': None,
#   'user': 'lulabelle826'},
#  {'text': '@TheCEOofRuSa If people are gonna give you hate for liking Disney movies, imagine what they’d do to me if they foun… https://t.co/QfbNWcyJcj',
#   'label': None,
#   'user': 'johtoash'},
#  {'text': 'RT @Delinda_Arts: Those Disney/Marvel bags just different',
#   'label': None,
#   'user': 'GracesChild_'},
#  {'text': "RT @itsKajolD: Soooooo many memories. So much fun from Nysa's first Disney trip to seeing the history of San Fran up close and personal wit…",
#   'label': None,
#   'user': 'myself_shahrukh'},
#  {'text': 'RT @summersnoqueen: idina’s really two disney princesses at once, isn’t she?',
#   'label': None,
#   'user': 'Juliana_Javier_'},
#  {'text': 'RT @jieundeux: hi! I’m baekhyun from exo, and you’re watching disney channel 💫 https://t.co/BC7suLC8jh',
#   'label': None,
#   'user': 'jqv0T0K3JnfqgMt'},
#  {'text': 'These #DisneyParks PEZ dispensers are the perfect souvenirs for any Disney vacation: https://t.co/N4voxxCUVg https://t.co/tEIHOJmXkG',
#   'label': None,
#   'user': 'laughing_place'},
#  {'text': 'RT @pinkhedonist: Implying that women need quotas to attain the jobs of their desires is literally an insult to female intelligence.\n\nSo wh…',
#   'label': None,
#   'user': 'disney__tasthic'},
#  {'text': 'RT @MattMcMuscles: Nice. So Disney saved you from never having to pay your employees for another project. https://t.co/pBLMBrGoqN',
#   'label': None,
#   'user': 'SirSideChar'},
#  {'text': "RT @itsKajolD: Soooooo many memories. So much fun from Nysa's first Disney trip to seeing the history of San Fran up close and personal wit…",
#   'label': None,
#   'user': 'SRK_Worshipper'},
#  {'text': '@Disney_Alli @LuLaRoe @ironfistclothng Oooo I really like the heart heels 🔥🔥🔥',
#   'label': None,
#   'user': 'blundy61'},
#  {'text': "RT @itsKajolD: Soooooo many memories. So much fun from Nysa's first Disney trip to seeing the history of San Fran up close and personal wit…",
#   'label': None,
#   'user': 'justhope65'},
#  {'text': 'Check out what I just added to my closet on Poshmark: Disney Bambi thumper bunny T-shirt size Small.… https://t.co/nSUAaCe09w',
#   'label': None,
#   'user': 'Jessii_Terra'},
#  {'text': 'RT @RiseFallNick: THIS SHOW DESERVES A FINAL SEASON. DISNEY+ YOU GAVE CLONE WARS A SENDOFF, DO THE RIGHT THING. https://t.co/TgudZhJSAV',
#   'label': None,
#   'user': 'CrackerTower'},
#  {'text': "RT @itsKajolD: Soooooo many memories. So much fun from Nysa's first Disney trip to seeing the history of San Fran up close and personal wit…",
#   'label': None,
#   'user': '__Nishu_'},
#  {'text': "RT @wishfultaem: hi! i'm taemin from shinee and you're watching disney channel 💫✨💎 https://t.co/wdR7XHI9S3",
#   'label': None,
#   'user': 'svtcaretvernon'},
#  {'text': 'RT @anchors_ahoy: Disney will never be able to top this https://t.co/xbHUcRUdcl',
#   'label': None,
#   'user': 'deszszs'},
#  {'text': 'RT @SASTheatreCo: See anyone you know??? Well come on down to dawn of a new day Saturday at 7!!!! We will be singing some classic Disney hi…',
#   'label': None,
#   'user': 'lenrams18'},
#  {'text': "RT @itsKajolD: Soooooo many memories. So much fun from Nysa's first Disney trip to seeing the history of San Fran up close and personal wit…",
#   'label': None,
#   'user': 'AdilSid94551687'},
#  {'text': 'RT @markabaigar: @ all my Disney people🥺 https://t.co/uLSuhGyBME',
#   'label': None,
#   'user': 'QuirozJocely'},
#  {'text': "RT @itsKajolD: Soooooo many memories. So much fun from Nysa's first Disney trip to seeing the history of San Fran up close and personal wit…",
#   'label': None,
#   'user': '_textless_'},
#  {'text': "RT @wishfultaem: hi! i'm taemin from shinee and you're watching disney channel 💫✨💎 https://t.co/wdR7XHI9S3",
#   'label': None,
#   'user': 'Mirallos_'},
#  {'text': 'It’s 1:20 AM and I’m watching the Hannah Montana : Miley Cyrus Best of Both Words Concert of Disney+ 🙂',
#   'label': None,
#   'user': 'Tameka_Warren7'},
#  {'text': 'RT @pureshad0wxyz: Little sneak peek for 3 new upcoming illustrations called: "Their Final Moments"\n\n#sketch #traditionalart #teaser #kingd…',
#   'label': None,
#   'user': 'MisoraRyuu0921'},
#  {'text': 'Disney needs a space princess but I suppose that means creating original content as opposed to mining fairytales.',
#   'label': None,
#   'user': 'SMHFConvoy'},
#  {'text': 'RT @themeparkalex: Unfortunately Disney AP’s are not affordable for everyone. You pay a premium price for a premium product, the same way y…',
#   'label': None,
#   'user': 'tehillahjoy321'},
#  {'text': "RT @itsKajolD: Soooooo many memories. So much fun from Nysa's first Disney trip to seeing the history of San Fran up close and personal wit…",
#   'label': None,
#   'user': 'myselfrafik'},
#  {'text': 'RT @kirst188: Johnny Depp was fired from Disney based on accusations alone. Now the truth has come out, Amanda Heard is a PROVEN liar/abuse…',
#   'label': None,
#   'user': 'Sumbulfa1'},
#  {'text': "RT @itsKajolD: Soooooo many memories. So much fun from Nysa's first Disney trip to seeing the history of San Fran up close and personal wit…",
#   'label': None,
#   'user': 'Srk_ash1'},
#  {'text': 'RT @HiddlesFashion: Man Tom Hiddleston has been playing the long game with the Loki series... first he gave us Owen Wilson as Loki (7 years…',
#   'label': None,
#   'user': 'ShadowOfScorn'},
#  {'text': "RT @Daily_Express: Queen Elizabeth II 'cringing' as Prince Harry 'sells Meghan Markle off to highest bidder' https://t.co/kKtdjYU7zT https:…",
#   'label': None,
#   'user': 'Chapperswalsall'},
#  {'text': "RT @itsKajolD: Soooooo many memories. So much fun from Nysa's first Disney trip to seeing the history of San Fran up close and personal wit…",
#   'label': None,
#   'user': 'sunshine_dina'},
#  {'text': 'RT @getFANDOM: Which Disney animation was the crowning glory of the 2010s? 👑 https://t.co/zTygAeh3R6',
#   'label': None,
#   'user': 'WhiteBartz'},
#  {'text': 'RT @Yester_World: I can’t remember the last time I had so much fun working on an episode. There’s just something so cynically joyful about…',
#   'label': None,
#   'user': 'MegMeg00670507'},
#  {'text': 'That’s So Raven ... Black History Month Episode..... 🖤🙌🏾\n\nAnd... thats Disney Channel ... y’all ✊🏾',
#   'label': None,
#   'user': 'officialbabygrl'},
#  {'text': "RT @itsKajolD: Soooooo many memories. So much fun from Nysa's first Disney trip to seeing the history of San Fran up close and personal wit…",
#   'label': None,
#   'user': 'theIostperson'},
#  {'text': 'RT @SaveTheOA: In support of the #FandomsAlliance camaraderie 🤝 &amp; the spirit of community – a key theme in our beloved shows, #SaveTheOA &amp;…',
#   'label': None,
#   'user': 'asaterecc'},
#  {'text': "Ok, I'm in. https://t.co/7EIYJdyYCq",
#   'label': None,
#   'user': 'DonnieJeep'},
#  {'text': 'RT @kirst188: Johnny Depp was fired from Disney based on accusations alone. Now the truth has come out, Amanda Heard is a PROVEN liar/abuse…',
#   'label': None,
#   'user': 'SamsonDonovan1'},
#  {'text': '@AddyPottle Except on Disney+. I don’t know how but I’ve found numerous typos with their subtitles.\n\nInterestingly… https://t.co/3yHI7pLr9m',
#   'label': None,
#   'user': 'TheNimanator'},
#  {'text': '@FrshBakedDisney It’s no big surprise about the price boosts for admission.\nDisney is still going to be the shinnin… https://t.co/ygnP6HZgsa',
#   'label': None,
#   'user': 'nissmokid'},
#  {'text': 'RT @Disney: Good friends stick together like hunny! Happy 20th Anniversary to The Tigger Movie. https://t.co/bZEWF1vSUE',
#   'label': None,
#   'user': 'aisafragile'},
#  {'text': 'RT @hazyybby: y’all love Disneyland so much but forget about the overpriced tickets/ food, gentrification in Anaheim &amp; surrounding cities,…',
#   'label': None,
#   'user': '1_papajojo'},
#  {'text': "RT @itsKajolD: Soooooo many memories. So much fun from Nysa's first Disney trip to seeing the history of San Fran up close and personal wit…",
#   'label': None,
#   'user': 'mandipkumar31'},
#  {'text': 'Can I catch a ride? @disneyfrozen @alittlejelee .\n#Disneyland #Disney #hollywood #LA #indiefilm #writer #director… https://t.co/dkbb5Vjkhm',
#   'label': None,
#   'user': 'erikpcarlson'}]

# %% [markdown]
# # Start preprocessing of training data

# %%
import pandas as pd
import numpy as np

traindata140 = os.path.join(".","trainingandtestdata_sentiment140","training.csv")
testdata140 = os.path.join(".","trainingandtestdata_sentiment140","test.csv")

# %%
#read the csv file command
train_df = pd.read_csv(traindata140, header=None, usecols=[0,5], names=['polarity of the tweet','text'], 
                       encoding="ISO-8859-1")
train_df.head()
# (0 = negative, 2 = neutral, 4 = positive)
# Out:
#    polarity of the tweet                                               text
# 0                      0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1                      0  is upset that he can't update his Facebook by ...
# 2                      0  @Kenichan I dived many times for the ball. Man...
# 3                      0    my whole body feels itchy and like its on fire
# 4                      0  @nationwideclass no, it's not behaving at all....

# %% [markdown]
# # Test code

# %%
test_df = pd.read_csv(testdata140, header=None, usecols=[0,5],
                      names=['polarity of the tweet', 'text'],encoding="ISO-8859-1")
conditions_test = [
    (test_df['polarity of the tweet'] == 0),
    (test_df['polarity of the tweet'] == 2),
    (test_df['polarity of the tweet'] == 4)]
choices_test = ['negative', 'neutral', 'positive']
test_df['label'] = np.select(conditions_test, choices_test)
test_df.head()

# %%
test_ls = test_df.to_dict('records')

# %% [markdown]
# # Test Df Validation

# %%
test_df = pd.read_csv(testdata140, header=None, usecols=[0,5],
                      names=['polarity of the tweet', 'text'],encoding="ISO-8859-1")
conditions_test = [
    (test_df['polarity of the tweet'] == 0),
    (test_df['polarity of the tweet'] == 2),
    (test_df['polarity of the tweet'] == 4)]
choices_test = ['negative', 'neutral', 'positive']
test_df['label'] = np.select(conditions_test, choices_test)
test_df.head()
# Out:
#    polarity of the tweet                                               text  \
# 0                      4  @stellargirl I loooooooovvvvvveee my Kindle2. ...
# 1                      4  Reading my kindle2...  Love it... Lee childs i...
# 2                      4  Ok, first assesment of the #kindle2 ...it fuck...
# 3                      4  @kenburbary You'll love your Kindle2. I've had...
# 4                      4  @mikefish  Fair enough. But i have the Kindle2...
#
#       label
# 0  positive
# 1  positive
# 2  positive
# 3  positive
# 4  positive

# %%
test_ls = test_df.to_dict('records')

# %%
print(test_ls[0:10])
# Out:
# [{'polarity of the tweet': 4, 'text': '@stellargirl I loooooooovvvvvveee my Kindle2. Not that the DX is cool, but the 2 is fantastic in its own right.', 'label': 'positive'}, {'polarity of the tweet': 4, 'text': 'Reading my kindle2...  Love it... Lee childs is good read.', 'label': 'positive'}, {'polarity of the tweet': 4, 'text': 'Ok, first assesment of the #kindle2 ...it fucking rocks!!!', 'label': 'positive'}, {'polarity of the tweet': 4, 'text': "@kenburbary You'll love your Kindle2. I've had mine for a few months and never looked back. The new big one is huge! No need for remorse! :)", 'label': 'positive'}, {'polarity of the tweet': 4, 'text': "@mikefish  Fair enough. But i have the Kindle2 and I think it's perfect  :)", 'label': 'positive'}, {'polarity of the tweet': 4, 'text': "@richardebaker no. it is too big. I'm quite happy with the Kindle2.", 'label': 'positive'}, {'polarity of the tweet': 0, 'text': 'Fuck this economy. I hate aig and their non loan given asses.', 'label': 'negative'}, {'polarity of the tweet': 4, 'text': 'Jquery is my new best friend.', 'label': 'positive'}, {'polarity of the tweet': 4, 'text': 'Loves twitter', 'label': 'positive'}, {'polarity of the tweet': 4, 'text': 'how can you not love Obama? he makes jokes about himself.', 'label': 'positive'}]

# %%
train_df_negative = train_df.loc[train_df['polarity of the tweet']==0]

# %%
train_df_positive = train_df.loc[train_df['polarity of the tweet']==4]

# %%
frames = [train_df_negative.iloc[0:50000,:],train_df_positive.iloc[0:50000,:]]

# %%
result = pd.concat(frames)

# %%
conditions = [
    (result['polarity of the tweet'] == 0),
    (result['polarity of the tweet'] == 2),
    (result['polarity of the tweet'] == 4)]
choices = ['negative', 'neutral', 'positive']
result['label'] = np.select(conditions, choices)
result.head()
# Out:
#    polarity of the tweet                                               text  \
# 0                      0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1                      0  is upset that he can't update his Facebook by ...
# 2                      0  @Kenichan I dived many times for the ball. Man...
# 3                      0    my whole body feels itchy and like its on fire
# 4                      0  @nationwideclass no, it's not behaving at all....
#
#       label
# 0  negative
# 1  negative
# 2  negative
# 3  negative
# 4  negative

# %%
train_ls = result.to_dict('records')

# %%
import re
from nltk.tokenize import word_tokenize
from string import punctuation 
from nltk.corpus import stopwords 
import nltk
# nltk.download('punkt')

class PreProcessTweets:
    def __init__(self):
        self._stopwords = set(stopwords.words('english') + list(punctuation) + ['AT_USER','URL'])
        
    def processTweets(self, list_of_tweets):
        processedTweets=[]
        for tweet in list_of_tweets:
            processedTweets.append((self._processTweet(tweet["text"]),tweet["label"]))
        return processedTweets
    
    def _processTweet(self, tweet):
        tweet = tweet.lower() # convert text to lower-case
        tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+))', 'URL', tweet) # remove URLs
        tweet = re.sub('@[^\s]+', 'AT_USER', tweet) # remove usernames
        tweet = re.sub(r'#([^\s]+)', r'\1', tweet) # remove the # in #hashtag
        tweet = word_tokenize(tweet) # remove repeated characters (helloooooooo into hello)
        return [word for word in tweet if word not in self._stopwords]
    
tweetProcessor = PreProcessTweets()

# %%
# Process Training Set
preprocessedTrainingSet = tweetProcessor.processTweets(train_ls)

# %%
# Process Test Set
preprocessedTestSet = tweetProcessor.processTweets(testDataSet)

# %%
import nltk 

def buildVocabulary(preprocessedTrainingData):
    all_words = []
    
    for (words, sentiment) in preprocessedTrainingData:
        all_words.extend(words)

    wordlist = nltk.FreqDist(all_words)
    word_features = wordlist.keys()
    
    return word_features

# %%
def extract_features(tweet):
    tweet_words = set(tweet)
    features = {}
    for word in word_features:
        features['contains(%s)' % word] = (word in tweet_words)
    return features

# %%
word_features = buildVocabulary(preprocessedTrainingSet)
trainingFeatures = nltk.classify.apply_features(extract_features, preprocessedTrainingSet)

# %%
NBayesClassifier = nltk.NaiveBayesClassifier.train(trainingFeatures)

# %%
# Save Pickle
import pickle
save_classifier = open("naivebayes_train_100k.pickle","wb")
pickle.dump(NBayesClassifier, save_classifier)
save_classifier.close()

# %%
# Load Pickle
import pickle
classifier_f = open("naivebayes_train_100k.pickle", "rb")
classifier = pickle.load(classifier_f)
classifier_f.close()

# %%
NBResultLabels = [NBayesClassifier.classify(extract_features(tweet[0])) for tweet in preprocessedTestSet]

# get the majority vote
if NBResultLabels.count('positive') > NBResultLabels.count('negative'):
    print("Overall Positive Sentiment")
    print("Positive Sentiment Percentage = " + str(100*NBResultLabels.count('positive')/len(NBResultLabels)) + "%")
else: 
    print("Overall Negative Sentiment")
    print("Negative Sentiment Percentage = " + str(100*NBResultLabels.count('negative')/len(NBResultLabels)) + "%")

# %%
NBResultLabelsPickle = [classifier.classify(extract_features(tweet[0])) for tweet in preprocessedTestSet]

# get the majority vote
if NBResultLabelsPickle.count('positive') > NBResultLabelsPickle.count('negative'):
    print("Overall Positive Sentiment")
    print("Positive Sentiment Percentage = " + str(100*NBResultLabelsPickle.count('positive')/len(NBResultLabelsPickle)) + "%")
else: 
    print("Overall Negative Sentiment")
    print("Negative Sentiment Percentage = " + str(100*NBResultLabelsPickle.count('negative')/len(NBResultLabelsPickle)) + "%")
# Out:
# Overall Positive Sentiment
# Positive Sentiment Percentage = 77.0%

# %%
for tweet in preprocessedTestSet:
    print(tweet[0])
# Out:
# ['unbelievable']
# ['please', 'bring', 'back', 'chalupa', 'box', 'best', 'thing', '’', 'fry', 'box', '’']
# ['went', 'tacobell', '🌮🛎', '``', 'run', 'border', "''", 'love💘', 'burritos🌯', 'tacos🌮', 'nachos', 'amp', 'cheese…']
# ['closer', 'would', 'come', 'break', 'leg']
# ['umm', 'wan', 'na', 'chime', 'tell', 'us', 'going', 'wednesdaythoughts', 'tacobell']
# ['ever', 'intend', 'open', 'location', 'miami', 'beach']
# ['sister', 'went', 'drive', 'thru', 'cortez', 'co', 'looks', 'like', 'whole', 'team', 'needs', 'trained…']
# ['rt', 'hey', 'boo']
# ['rt', 'stop', '//', 'grindcity']
# ['thought', '’', 'share', 'location', 'literally', 'inside', 'joke', 'girlfrien…']
# ['’', 'bad', 'day', 'continue', 'reading', 'went', 'go', 'pick', 'calizone', 'cory', 'ordered', 'phone', 'acci…']
# ['rt', 'keep', 'dunk', 'repeat', 'please', 'thank', '//', 'truetoatlanta']
# ['hi', 'im', 'simpin', 'buffalo', 'chicken', 'burrito', '-thx', '’', 'text']
# ['rt', 'myles', 'hits', '3', 'double', 'digits', 'first', 'half', 'pacers']
# ["'ll", 'never', 'able', 'thank', 'enough', 'breakfast', 'crunchwrap', '...']
# ['finally', 'man', 'culture', 'best', 'sauce']
# ['crushing', 'past', 'presidents', 'panel', 'tacobell']
# ['yo', 'new', 'spicy', 'cheese', 'fries', 'bomb']
# ['nutcracker', 'ultimate', 'fave']
# ['rt', 'hey', 'boo']
# ['yes', 'went', '’', 'sandiego']
# ['yeah', 'go', 'one', 'occasionally', "'s", 'way']
# ['best', 'fast', 'food', 'ever', '😊😉']
# ['young', 'goat']
# ['nice', 'profile', 'picture', '💀']
# ['rt', 'bro', 'want', 'fat', 'juicy', 'thick', 'nacho', 'fries', 'box', 'baja', 'blast', 'drink', 'dozen', 'glazed…']
# ['new', 'york', '✊🏻😂']
# ['apple', 'maps', 'thinks', 'local', '7-eleven', '“', 'home', '”']
# ['rt', 'everyone', 'expecting', 'lavish', 'gifts', 'expensive', 'meals', 'valentine', "'s", 'day', '...', 'want', 'roses', 'i…']
# ['real', 'ones', 'know']
# ['imagine', 'going', 'taco', 'bell', 'getting', 'beef', 'gg']
# ['rt', 'hey', 'boo']
# ['’', 'fucking', 'disappointed', 'got', 'everything', 'hard', '😒😪']
# ['got', 'u.', 'gim', '2', 'weeks']
# ['hour', 'everyone', 'packed', 'together', 'subway/bus', 'amp', 'body', 'odor', 'mix', 'together', 'something', 'special', '🤔']
# ['rt', 'stop', '//', 'grindcity']
# ['rt', 'hey', 'boo']
# ['anyone', 'eat', 'thing']
# ['bro', 'one', 'known', 'consistently', 'take', '6', 'years', 'go', 'one', 'eastmoor', 'double…']
# ['rt', 'hey', 'boo']
# ['rt', 'hey', 'boo']
# ['bro', 'want', 'fat', 'juicy', 'thick', 'nacho', 'fries', 'box', 'baja', 'blast', 'drink', 'dozen', 'gl…']
# ['people', 'brag', 'starbucks', 'drive', 'thru', 'person', '’', 'really', 'thing', 'spent', 'like', '6', 'minutes', 'chit', 'cha…']
# ['u', 'like', 'softish', 'tacos']
# ['need']
# ['rt', '.AT_USER', 'tracks', 'back', 'reject', '7-footer', 'rudy', 'gobert', '⬆️⬆️🖐🖐', '🏀', 'live', 'fox', 'sports', 'sun', '📺', 'l', 'fox', 'sports', 'go…']
# ['omg', 'claire', 'taco', 'bell', 'valentine', '’', 'day', 'last', 'year', '😆']
# ['.AT_USER', 'beanball', '🍒', '🍅', '🍏']
# ["'ve", 'dinner', 'week', 'tonight', "'ll", 'eat', 'also', '~1', 'hour', 'eating', 'could', 'go', 'right']
# ['would', 'fuck', 'potato', 'tacobell']
# ['n', 'legends', 'mom', 'pop', 'burger', 'stand', 'tommys', 'burger', 'red', 'shack', 'logo', 'tacobell…']
# ['okay', 'remember', 'dunkaroos', 'like', 'certain', 'taco', 'bell…']
# ['got', 'married', 'past', 'weekend', 'ate', 'burritos', 'whirlpool', 'life', 'never', 'complete❤️🌯']
# ['locations', 'totally', 'fine', "'s", 'one', 'location', 'nearest', 'see…']
# ['tweeting', 'drive', 'thru', 'bring', 'back', 'grilled', 'stuffed', 'nacho']
# ['nacho', 'party', 'pack', 'alone', '😛']
# ['thank', 'satisfying', 'boyfriend', '’', 'hunger', '100/10', 'love', 'please', 'sponsor', 'okay', 'thank', '😚']
# ['bruh', 'one', 'time', 'taco', 'bell', 'us', '30', 'minute', 'wait', '2am', 'wrote', 'receipts…']
# ['wife']
# ['rt', 'wow', 'paying', 'someone', 'bring', 'u', 'tacobell', 'live', 'society']
# ['rt', '.AT_USER', 'tracks', 'back', 'reject', '7-footer', 'rudy', 'gobert', '⬆️⬆️🖐🖐', '🏀', 'live', 'fox', 'sports', 'sun', '📺', 'l', 'fox', 'sports', 'go…']
# ['chillito', 'gt', 'gt', 'gt']
# ['rt', 'hey', 'boo']
# ['rt', '.AT_USER', 'tracks', 'back', 'reject', '7-footer', 'rudy', 'gobert', '⬆️⬆️🖐🖐', '🏀', 'live', 'fox', 'sports', 'sun', '📺', 'l', 'fox', 'sports', 'go…']
# ['rt', '.AT_USER', 'support', 'policy', 'libertarian', 'candidate', 'president', 'declare', 'every', 'tuesday', 'taco', 'supreme', 'tuesday']
# ['’', 'fucking', 'crying']
# ['rt', 'know', '’', 'day', 'order', '26', 'dinner']
# ['stop', 'cheap', 'nasty', '5', 'layer', 'bs']
# ['please', 'know', 'looking', 'matter', 'right', 'away', 'thank', 'alerting', 'us', '-kb']
# ['rt', 'everyone', 'expecting', 'lavish', 'gifts', 'expensive', 'meals', 'valentine', "'s", 'day', '...', 'want', 'roses', 'i…']
# ['rt', 'hey', 'boo']
# ['’', 'put', 'tomatoes', 'supreme', 'tacos', 'aka', 'favorite', 'part', 'taco', '’', 'sad']
# ['rt', 'welcome', 'team']
# ['many', 'retweets']
# ['location', 'south', 'sf', 'consistently', 'slow', 'awful', 'waiting', '15', 'minutes', 'order…']
# ['rt', 'everyone', 'expecting', 'lavish', 'gifts', 'expensive', 'meals', 'valentine', "'s", 'day', '...', 'want', 'roses', 'i…']
# ['nobody', 'gabe', 'tacobell', 'ok', 'else', 'want']
# ['rt', 'video', '4', 'dark', 'angels', 'amp', 'pretty', 'freaks', 'podcast', '302', '“', 'taco', 'bell', 'crazy', '”', 'married', 'couple', 'napa', 'ca', 'chatting', 'life', '…']
# ['rt', 'everyone', 'expecting', 'lavish', 'gifts', 'expensive', 'meals', 'valentine', "'s", 'day', '...', 'want', 'roses', 'i…']
# ['place', '’', 'sell', 'fries', 'best', 'fast', 'food', 'fries', 'along', 'w', 'checkers', 'fight', 'ab']
# ['rt', '.AT_USER', 'tracks', 'back', 'reject', '7-footer', 'rudy', 'gobert', '⬆️⬆️🖐🖐', '🏀', 'live', 'fox', 'sports', 'sun', '📺', 'l', 'fox', 'sports', 'go…']
# ['guys', 'need', 'chihuahua', 'commercials']
# ['probably', 'little', 'late', 'finally', 'tried', 'buffalo', 'chicken', 'nacho', 'fries', 'let', 'just…']
# ['never', 'lol']
# ['course', '’', 'spend', 'valentine', '’', 'day', 'thx', 'asking']
# ['rt', 'plz', '’', 'ghost']
# ['must', 'constipated', 'sum']
# ['know', '’', 'day', 'order', '26', 'dinner']
# ['back', "y'all", 'want']
# ['...', 'take', 'ppl', '10', 'mins', 'order', 'thru', 'drive', 'thru', 'tacobell', '...', 'mean', "c'mon", 'man', '...', 'took', '15', 'seconds']
# ['yeah', 'need', 'political', 'parry..', 'create', 'one', 'make', 'rule…']
# ['see', '...', 'taking', 'away', 'beefy', 'mini', 'quesadilla', 'thing', 'fold', 'lit…']
# ['rt', 'video', '4', 'dark', 'angels', 'amp', 'pretty', 'freaks', 'podcast', '302', '“', 'taco', 'bell', 'crazy', '”', 'married', 'couple', 'napa', 'ca', 'chatting', 'life', '…']
# ['video', '4', 'dark', 'angels', 'amp', 'pretty', 'freaks', 'podcast', '302', '“', 'taco', 'bell', 'crazy', '”', 'married', 'couple', 'napa', 'ca', 'chatting', 'about…']
# ['grilled', 'stuffed', 'burrito']
# ['probably', 'best', 'fast', 'food', 'commercial', 'ive', 'ever', 'seen', 'nachofries']
# []
# ['rt', 'hey', 'boo']
# ['teh', 'caballrs', 'r', 'sinistr', 'conspiracy', 'began', 'america', 'durin', 'teh', 'roosevelt', 'administrashun', 'catspiracy', 'tacobell']
# ['rt', 'heading', 'nazaré', 'tow', 'surfing', 'challenge', 'big', 'wave', 'phenom', 'joined', 'lineup', 'pod', 'talk', '🌊', 'nazaré', 'vs', 'jaws', '💯', 't…']

# %%
# had to add space before tweet text to eliminate csv issue with tweets that begins with @
# list comprehension
test_list_text = [' '+test['text'] for test in testDataSet]
# convert twitter time output to real time output
test_list_time = [time.strftime('%Y-%m-%d %H:%M:%S', time.strptime(test['time'],'%a %b %d %H:%M:%S +0000 %Y')) 
for test in testDataSet]

# %%
output_list = pd.DataFrame(
    {'Tweet': test_list_text,
     'Time': test_list_time,
     'Result': NBResultLabelsPickle
    })

# %%
output_list
# Out:
#                                                 Tweet                 Time  \
# 0     Unbelievable. @tacobell https://t.co/pHIZWIUnRD  2020-02-13 04:09:52
# 1    @tacobell please bring back the chalupa box, ...  2020-02-13 04:09:44
# 2    I went to #TacoBell 🌮🛎 again. Had to "Run for...  2020-02-13 04:08:58
# 3    @tyvid5 @tacobell @StubHub @Rebecca_Mich If o...  2020-02-13 04:07:16
# 4    Umm @tacobell you wanna chime in about this, ...  2020-02-13 04:07:00
# 5    @tacobell Do you ever intend to open a locati...  2020-02-13 04:06:38
# 6    @tacobell My sister went through your drive t...  2020-02-13 04:06:06
# 7                  RT @xlilhuddy: . @tacobell hey boo  2020-02-13 04:05:42
# 8    RT @GrizzliesOnFSSE: Just stop it, @JaMorant....  2020-02-13 04:05:15
# 9    @RunDaltonRun @tacobell thought I’d share. Th...  2020-02-13 04:04:46
# 10   If you’re having a bad day, continue reading:...  2020-02-13 04:03:35
# 11   RT @HawksOnFSSE: Can we keep this @jcollins20...  2020-02-13 04:03:19
# 12   hi im simpin for the @tacobell buffalo chicke...  2020-02-13 04:02:55
# 13   RT @FSIndiana: Myles hits the 3 and is into d...  2020-02-13 04:02:51
# 14   I'll never be able to thank @tacobell enough ...  2020-02-13 04:02:25
# 15   @Poofesure @tacobell finally a man of culture...  2020-02-13 04:01:58
# 16   @Richa_Anand_ crushing it @csufprssa Past Pre...  2020-02-13 04:00:10
# 17   Yo @tacobell those new spicy cheese fries are...  2020-02-13 04:00:01
# 18       @xo_tacobell Nutcracker was my ultimate FAVE  2020-02-13 03:59:40
# 19                 RT @xlilhuddy: . @tacobell hey boo  2020-02-13 03:59:04
# 20   @melissaabufkaa @MaddieMcNee05 @lucyrosete2 @...  2020-02-13 03:58:44
# 21   @iDuLicious @tacobell Yeah I go to that one o...  2020-02-13 03:57:16
# 22   Is it just me or is  @tacobell the best fast ...  2020-02-13 03:55:06
# 23   @DireVegod @tacobell its the young goat @thic...  2020-02-13 03:55:04
# 24    @tendowastaken @tacobell Nice profile picture 💀  2020-02-13 03:54:11
# 25   RT @davidcleland65: bro i want a fat juicy th...  2020-02-13 03:54:00
# 26                @TacoBell_Lord Only in New York ✊🏻😂  2020-02-13 03:53:55
# 27   @rarediseasemom @tacobell Apple Maps thinks m...  2020-02-13 03:53:21
# 28   RT @BrookeRadio: Everyone is out here expecti...  2020-02-13 03:53:17
# 29              @BrookeRadio @tacobell Real ones know  2020-02-13 03:53:14
# ..                                                ...                  ...
# 70                 RT @xlilhuddy: . @tacobell hey boo  2020-02-13 03:33:31
# 71   @tacobell didn’t put tomatoes on my supreme t...  2020-02-13 03:33:14
# 72   RT @Suns: Welcome to the team, @Jonahbolden43...  2020-02-13 03:33:02
# 73   How many retweets, @tacobell? https://t.co/s8...  2020-02-13 03:32:56
# 74   This @tacobell location in South SF is consis...  2020-02-13 03:32:20
# 75   RT @BrookeRadio: Everyone is out here expecti...  2020-02-13 03:32:07
# 76   Nobody:\nGabe @ tacobell: ok but what ELSE do...  2020-02-13 03:31:01
# 77   RT @DAPFpodcast: Video 4 Dark Angels &amp; Pr...  2020-02-13 03:30:01
# 78   RT @BrookeRadio: Everyone is out here expecti...  2020-02-13 03:30:01
# 79   for a place that doesn’t sell fries @tacobell...  2020-02-13 03:29:00
# 80   RT @FOXSportsFL: .@nunnbetter_ tracks back to...  2020-02-13 03:27:21
# 81   @tacobell do you guys need a chihuahua for co...  2020-02-13 03:26:39
# 82   Probably a little late to this, but I finally...  2020-02-13 03:25:38
# 83                      @magiclae @tacobell Never lol  2020-02-13 03:25:04
# 84   Of course I’ll spend my Valentine’s Day with ...  2020-02-13 03:24:38
# 85   RT @MattMillerHeard: @tacobell plz don’t ghos...  2020-02-13 03:24:19
# 86   @DireVegod @tacobell You must be constipated ...  2020-02-13 03:24:07
# 87   You know it’s been a day when I order $26 at ...  2020-02-13 03:23:25
# 88   Back at it again, what y'all want? @tacobell ...  2020-02-13 03:22:41
# 89   ... why does it take ppl 10 mins to order thr...  2020-02-13 03:22:18
# 90   @RaniaKhalek @justinsanesolo Yeah you just ne...  2020-02-13 03:20:19
# 91   @tacobell @tacobell  I see you... taking away...  2020-02-13 03:18:32
# 92   RT @DAPFpodcast: Video 4 Dark Angels &amp; Pr...  2020-02-13 03:18:30
# 93   Video 4 Dark Angels &amp; Pretty Freaks #Podc...  2020-02-13 03:18:00
# 94                  @tacobell grilled stuffed burrito  2020-02-13 03:16:33
# 95   @tacobell That was probably the best fast foo...  2020-02-13 03:16:12
# 96   @Big_Bayn @DrewVencill @doingthefavor @BFROST...  2020-02-13 03:16:11
# 97                 RT @xlilhuddy: . @tacobell hey boo  2020-02-13 03:15:21
# 98   TEH CABALLRS R SINISTR AN THEIR CONSPIRACY BE...  2020-02-13 03:14:56
# 99   RT @wsl: Before heading to the Nazaré Tow Sur...  2020-02-13 03:14:11
#
#       Result
# 0   positive
# 1   positive
# 2   positive
# 3   negative
# 4   positive
# 5   positive
# 6   negative
# 7   positive
# 8   positive
# 9   negative
# 10  negative
# 11  positive
# 12  positive
# 13  positive
# 14  positive
# 15  positive
# 16  positive
# 17  positive
# 18  positive
# 19  positive
# 20  positive
# 21  positive
# 22  positive
# 23  positive
# 24  positive
# 25  positive
# 26  positive
# 27  positive
# 28  positive
# 29  positive
# ..       ...
# 70  positive
# 71  negative
# 72  positive
# 73  positive
# 74  negative
# 75  positive
# 76  positive
# 77  positive
# 78  positive
# 79  positive
# 80  positive
# 81  negative
# 82  positive
# 83  positive
# 84  positive
# 85  positive
# 86  negative
# 87  positive
# 88  negative
# 89  negative
# 90  positive
# 91  positive
# 92  positive
# 93  positive
# 94  negative
# 95  positive
# 96  positive
# 97  positive
# 98  positive
# 99  positive
#
# [100 rows x 3 columns]

# %%
output_list.to_csv('./output4.csv',header=True,
                              index=False,encoding="utf-8",date_format=)
